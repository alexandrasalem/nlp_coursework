# %% [markdown]
# # Homework 3: RNNs
#
# In this assignment, you will use PyTorch and RNNs to solve two NLP problems:
#
# 1. Language identification
# 2. Language modeling
#
# In the first, you will train a classifier to distinguish between English and Spanish sentences, and will essentially be creating a working version of the classifier demonstrated at the end of the PyTorch walkthrough from week 3's lecture. In the second you will train a neural language model to generate new British place names. For the second part, you will find Chapter 17 of the Goldberg text to be a useful reference.
#
# **Note:** The networks that you will be training in this assignment are relatively simple, and the amounts of data are relatively small. That said, _**they will take time to train**_. On my laptop, the various networks take on the order of ≈5 minutes to train. Make sure not to wait until the last minute to do this assignment, as you will need to do a fair bit of experimentation and tinkering, and you won't want to find yourself running out of time.

# %% [markdown]
# ## Part 0: Setup
#
# In addition to Jupyter and `nose`, you will need to have `pytorch`, `numpy`, `pandas`, and Scikit-Learn installed for this assignment. As in HW2, most of your actual coding will take place in the `hw3_utils` module, and we will use unit tests to verify that things are working appropriately.

# %%
import nose
import torch
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
from importlib import reload

# %% [markdown]
# One other important thing to do is to set the random number generation seed. This will ensure deterministic results: each time you re-run the notebook, you should get the same random numbers. This is vital for ensuring reproducible results.

# %%
np.random.seed(42);
torch.manual_seed(42);

# %% [markdown]
# As before, let's check and see what versions of the libraries you've got installed:

# %%
print("My library versions:")
print(f"PyTorch: {torch.__version__}")
print(f"Pandas: {pd.__version__}")
print(f"Numpy: {np.__version__}")
print(f"matplotlib: {matplotlib.__version__}")
print(f"nose: {nose.__version__}")
print(f"sklearn: {sklearn.__version__}")
# Out:
# My library versions:
# PyTorch: 1.0.0
# Pandas: 0.23.4
# Numpy: 1.16.0
# matplotlib: 3.0.2
# nose: 1.3.7
# sklearn: 0.20.0

# %% [markdown]
# And we can run our tests as before:

# %%
! nosetests tests/test_environment.py
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# Tips from Steven:
# - mess around with pytorch to figure out dimensions stuff
# - pytorch documentation is very good
# - experiment a lot--give yourself time
# - leave time to figure out what can be adopted from the language model and what can't
# - office hours Friday

# %% [markdown]
# ## Part 1: Preprocessing
#
# ### Vocabulary construction
#
# As in the last part of HW2, we will be representing our input as numeric vectors. As such, we need a way to map tokens (characters, in the case of this assignment) to numeric indices. `hw3_utils.vocab` will contain functions to do this sort of transformation. The first such function will be `build_vocab`, and will take as input a corpus of sentences and as output produce mapping dictionaries. `vocab` includes special `BOS_SYM` and `EOS_SYM` symbols, to represent the beginning and end of string, respectively- make sure that the vocabularies that your implementation builds includes these characters.
#
# * **Deliverable 1.1:** Complete the `vocab.build_vocab()` function
# * **Test:** `nosetests tests/test_vocab.py:test_d1_1_char_vocab`
#
# _Hint_: Remember that you can split a string into its sequence of characters using the `list` function. For _this_ assignment, you may ignore issues of Unicode decomposition and normalization, but in "real life" you would absolutely need to worry about such things!

# %%
from hw3_utils import vocab
reload(vocab);

# %%
tiny_corpus = ["This is a sentence.", "This is another sentence.", "Here is a third."]
c2i, i2c = vocab.build_vocab(tiny_corpus)

# %%
"T" == i2c[c2i["T"]]
# Out:
# True

# %%
# !nosetests tests/test_vocab.py:test_d1_1_char_vocab
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# ### Sentence representation
#
# In addition to a character inventory, we'll need a way to convert a sentence into a list of indicies. Ordinarily, one would need to worry about how to handle missing vocabulary entries (i.e., OOV words or symbols); _for this assignment_, we are ignoring this problem.
#
# * **Deliverable 1.2:** Complete the `vocab.sentence_to_vector()` function
# * **Test:** `nosetests tests/test_vocab.py:test_d1_2_sentence_vector`

# %%
reload(vocab);

# %%
s = "This is a sentence."
s_vec = vocab.sentence_to_vector(s, c2i)
print(s_vec)
# Out:
# [15, 13, 16, 3, 6, 16, 3, 6, 8, 6, 3, 9, 4, 12, 9, 4, 14, 9, 10]

# %%
[i2c[c] for c in s_vec]
# Out:
# ['T',
#  'h',
#  'i',
#  's',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  ' ',
#  's',
#  'e',
#  'n',
#  't',
#  'e',
#  'n',
#  'c',
#  'e',
#  '.']

# %%
# !nosetests tests/test_vocab.py:test_d1_2_sentence_vector
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# PyTorch wants its input as `torch.Tensor` objects, not as Python `list`s, so we'll need to write one more short function to do that conversion. We'll want our tensors to be of size $(1,n)$, where $n$ is the length of the sentence in characters.
#
# * **Deliverable 1.3:** Complete the `sentence_to_tensor()` function
# * **Test:** `nosetests tests/test_vocab.py:test_d1_3_sentence_tensor`

# %%
reload(vocab);

# %%
s = "This is a sentence."
s_tens = vocab.sentence_to_tensor(s, c2i)
print(s_tens)
print(s_tens.size())
# Out:
# tensor([[15., 13., 16.,  3.,  6., 16.,  3.,  6.,  8.,  6.,  3.,  9.,  4., 12.,
#           9.,  4., 14.,  9., 10.]])
# torch.Size([1, 19])

# %%
# !nosetests tests/test_vocab.py:test_d1_3_sentence_tensor
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# ### Label lookup table
#
# Just as we need to be able to represent characters as indices, we also need to be able to map _labels_ to indicies. The logic for this is very similar to what we did before for characters, but without the tokenization step.
#
# * **Deliverable 1.4:** Complete the `vocab.build_label_vocab()` function
# * **Test:** `nosetests tests/test_vocab.py:test_d1_4_label_vocab`

# %%
reload(vocab);

# %%
labels = ["eng","eng","spa","eng","deu"]
l2i, i2l = vocab.build_label_vocab(labels)

# %%
l2i['spa']
# Out:
# 1

# %%
i2l[2]
# Out:
# 'eng'

# %%
[l2i[l] for l in labels]
# Out:
# [2, 2, 1, 2, 0]

# %%
# !nosetests tests/test_vocab.py:test_d1_4_label_vocab
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# ## Part 2: Language identification
#
# Language identification is often one of the first steps of an NLP pipeline, and is a foundational task in NLP. _[Automatic Language Identification in Texts: A Survey](https://arxiv.org/pdf/1804.08186.pdf)_, by Jauhiainen et al., gives an excellent overview of the task and its rich history in our field, and I would _strongly_ recommend taking a few minutes to read it before beginning this part of the assignment.
#
# Formally, we can craft language ID as a classification problem, given text sample $x$ and language $l \in L$, we want to find:
#
# $$ \operatorname*{argmax}_{l} P(l | x ) $$
#
# This can be done in a variety of ways. One common (and well-performing) technique is to use trigram character frequencies, or other character-level features (writing system, etc.); some approaches rely on or incorporate word-level features. The difficulty of the task depends on a number of factors:
#
# * How much training data one has from each language of interest (often an issue)
# * How similar the languages are to one another (Spanish and Italian are more difficult to differentiate than are English and Arabic)
# * How much ["code-switching"](https://en.wikipedia.org/wiki/Code-switching) is present in the language of interest
#
# The last point is a major one: many texts of interest (tweets, etc.) contain a mix of languages, which can cause trouble both at the time of _training_ a language identification system as well as at the time of _inference_ (i.e., when you're actually trying to _use_ your system). The problem can be compounded by mixed writing systems: due to limitations of text-entry systems, users of some non-Latin scripts often will often write e.g. Arabic using English orthography. Names of places, brands, individuals, etc. can also cause script-level code switching. Fortunately, for this assignment, you will not need to worry about this issue.
#
# We will be using [data](https://tatoeba.org/eng/downloads) from [Tatoeba](https://tatoeba.org), an online crowd-sourced language learning platform. Users collaboratively develop parallel corpora of sentences in a wide variety of languages. For this assignment, I have prepared two data sets based on Tatoeba's data:
#
# * [sentences_bilingual.csv](./data/sentences_bilingual.csv): 10,000 random English and 10,000 random Spanish sentences
# * [sentences_multilingual.csv](./data/sentences_multilingual.csv): 10,000 random sentences from each of English, Spanish, German, Italian, and French

# %% [markdown]
# ## Getting Started
#
# We'll begin with the bilingual (english/spanish) data:

# %%
bi_text = pd.read_csv("data/sentences_bilingual.csv")
bi_text.head()
# Out:
#         id lang                                           sentence
# 0  6733426  eng                Tom wasn't able to change anything.
# 1   256835  eng      I saw the sights of Kyoto during my vacation.
# 2  1404674  eng  And where are the aliens, the flying saucers, ...
# 3  4833334  eng      Is the water in the Black Sea actually black?
# 4  7241028  eng         I know a lot of people who don't eat meat.

# %% [markdown]
# Step 1 is _always_ to look at your data. Verify how many entries we have, and of what languages:

# %%
print(f"Total entries: {len(bi_text)}")
# Out:
# Total entries: 20000

# %%
bi_text.groupby('lang').count()
# Out:
#          id  sentence
# lang
# eng   10000     10000
# spa   10000     10000

# %% [markdown]
# Now, build a character inventory/vocabulary for our data:

# %%
c2i, i2c = vocab.build_vocab(bi_text.sentence.values)
l2i, i2l = vocab.build_label_vocab(bi_text.lang.values)

# %% [markdown]
# And now let's make a 80/20 training-test split:

# %%
from sklearn.model_selection import train_test_split
bi_text_train, bi_text_test = train_test_split(bi_text, test_size=0.2)

# %% [markdown]
# What is the resulting class distribution?

# %%
bi_text_train.groupby('lang').count()
# Out:
#         id  sentence
# lang
# eng   7981      7981
# spa   8019      8019

# %%
bi_text_test.groupby('lang').count()
# Out:
#         id  sentence
# lang
# eng   2019      2019
# spa   1981      1981

# %% [markdown]
# That's close enough to equal to be usable!

# %% [markdown]
# ## Building a model

# %% [markdown]
# You should see that the data set is _balanced_ between two categories, English and Spanish.
#
# The classification model you will build will first project sparse character representations to a dense learned embedding representation (as in Goldberg 4.8), feed the result into an LSTM, and then use the LSTM's output as the input into a softmax classifier to predict the language of the input. Note that we want to use the _final_ LSTM output for classification. More formally:
#
# $$ \hat{y} = \operatorname*{softmax} \mathbf{o}^{(n)} $$
#
# $$ \mathbf{o} = \mathbf{h} \mathbf{W}_o^T + b_o $$
#
# $$ \mathbf{h} = LSTM(\mathbf{x})$$
#
# $$ \mathbf{x}_{1:n} = \mathbf{E}[w_1], ... , \mathbf{E}[w_n] $$
#
# Where $\mathbf{E}$ is an embedding layer, with its own learned weights, etc. We can use PyTorch's [`nn.Embedding`](https://pytorch.org/docs/stable/nn.html#embedding) layer class to take care of this part of our network- it takes as input a character index (just like the ones produced by our vocabulary function above). Similarly, we can use [`nn.LSTM`](https://pytorch.org/docs/stable/nn.html#lstm), [`nn.Linear`](https://pytorch.org/docs/stable/nn.html#linear), and [`nn.LogSoftmax`](https://pytorch.org/docs/stable/nn.html#logsoftmax) to create the rest of the layers.
#
# This architecture has several hyperparameters that you must specify:
#
# 0. How many distinct characters do you need to represent ($n$)?
# 1. How many dimensions to use for embedding (representing) the characters ($e$)?
# 2. How many dimensions (hidden units) should the LSTM have ($h$)?
# 3. How many layers should the LSTM have?
# 3. How many output classes should the network have ($c$)?
#
# The dimensionality of the layers of the network should then be: $n \times c$ for the embedding layer, $c \times h$ for the LSTM, and $h \times c$ for the output layer.

# %% [markdown]
# For this part of the assignment, I have done much of the work for you, and have provided a skeleton class with completed initialization functions.
#
# * **Deliverable 2.1:** Following the MLP example in the PyTorch walkthrough from Week 3, complete the `forward()` method in the `nn.Module` that is started for you in `hw3_utils.lang_id`.
# * **Test:** `nosetests tests/test_lang_id.py:test_d2_1_forward`
#
#
#
# _Note_: typically, PyTorch networks are trained using minibatch training (see Goldberg 5.2.8); for the sake of keeping this assignment simple, we will not be using the standard PyTorch batching behaviors. Instead, we will be batching "manually"- calling `.backward()` and updating our parameters after a configurable interval. This will make training take a little bit longer, but will make _your_ code simpler. As such, the shape of the input will be slightly different than PyTorch expects by default. You may need to experiment a bit!
#
# Also note that this is a "many-to-one" RNN architecture. Out of the box, `nn.LSTM` is set up for _many-to-many_ architectures where the input and output are synchronized- in other words, if you feed five time points _in_ to the LSTM (i.e., providing a $(1,5)$ input), you'll get a $(1,5)$ _output_ back. Since we only care about the _last_ timepoint's output for our classification problem, at some point you'll need to extract that value.

# %%
from hw3_utils import lang_id

# %% [markdown]
# Here, I am initializing the model with 10 embedding dimensions, 20 hidden dimensions, a single LSTM layer, and two output classes (_`eng`_ and _`spa`_):

# %%
reload(lang_id);

li = lang_id.LangID(
    input_vocab_n=len(c2i),#n
    embedding_dims=10,#e
    hidden_dims=20,#h
    lstm_layers=1,
    output_class_n=2 #c
)

# %% [markdown]
# Now that it's initialized, I can provide it with input and verify that the output is of the dimensionality I expect:

# %%
li(vocab.sentence_to_tensor("this is a sentence", c2i))
# Out:
# tensor([-0.7944, -0.6012], grad_fn=<SelectBackward>)
# tensor([-0.7944, -0.6012], grad_fn=<SelectBackward>)

# %%
li(vocab.sentence_to_tensor("this is a sentence", c2i)).shape
# Out:
# tensor([-0.6907, -0.6956], grad_fn=<SelectBackward>)
# torch.Size([2])

# %%
# !nosetests tests/test_lang_id.py:test_d2_1_forward
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.148s
#
# OK

# %%
np.exp(-.7944) + np.exp(-.6012)
# Out:
# 1.0000057220815086

# %% [markdown]
# **Tip**: I recommend building up the `forward()` method one layer at a time, at each step of the way verifying that the output you are seeing is what you expect.
#
# That output is the raw log-probabilities associated with each class. This is not especially user-friendly, and makes evaluation a bit more difficult than we might care for.
#
# * **Deliverable 2.2:** Implement the `predict_one()` function in `hw3_utils.lang_id`.
# * **Test:** `nosetests tests/test_lang_id.py:test_d2_2_predict_one`

# %%
reload(lang_id);

# %%
lang_id.predict_one(li, "this is a sentence", c2i, i2l)
# Out:
# tensor([-0.7944, -0.6012], grad_fn=<SelectBackward>)
# False
# 'spa'

# %%
# !nosetests tests/test_lang_id.py:test_d2_2_predict_one
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.148s
#
# OK

# %% [markdown]
# ## Training and evaluating model
#
# Next, we need to train and evaluate the model. I have provided a `train_model()` function to do the training for this model, in `hw3_utils.lang_id`. This part of the assignment features fewer automated tests, and involves a little bit more thinking and writing.

# %%
reload(lang_id);

# %%
trained_model = lang_id.train_model(
    model=li, 
    n_epochs=1,
    training_data=bi_text_train,
    c2i=c2i, i2c=i2c,
    l2i=l2i, i2l=i2l
)
# Out:
# tensor([-0.7726, -0.6196], grad_fn=<SelectBackward>)
# 0/16000 average per-item loss: 0.007725908886641264
# tensor([-0.7932, -0.6022], grad_fn=<SelectBackward>)
# tensor([-0.7891, -0.6056], grad_fn=<SelectBackward>)
# tensor([-0.7766, -0.6161], grad_fn=<SelectBackward>)
# tensor([-0.8181, -0.5821], grad_fn=<SelectBackward>)
# tensor([-0.7663, -0.6250], grad_fn=<SelectBackward>)
# tensor([-0.7491, -0.6402], grad_fn=<SelectBackward>)
# tensor([-0.8068, -0.5911], grad_fn=<SelectBackward>)
# tensor([-0.8014, -0.5955], grad_fn=<SelectBackward>)
# tensor([-0.7940, -0.6016], grad_fn=<SelectBackward>)
# tensor([-0.8136, -0.5856], grad_fn=<SelectBackward>)
# tensor([-0.8098, -0.5887], grad_fn=<SelectBackward>)
# tensor([-0.7693, -0.6224], grad_fn=<SelectBackward>)
# tensor([-0.8034, -0.5939], grad_fn=<SelectBackward>)
# tensor([-0.8026, -0.5945], grad_fn=<SelectBackward>)
# tensor([-0.7699, -0.6219], grad_fn=<SelectBackward>)
# tensor([-0.8042, -0.5932], grad_fn=<SelectBackward>)
# tensor([-0.7938, -0.6017], grad_fn=<SelectBackward>)
# tensor([-0.7947, -0.6009], grad_fn=<SelectBackward>)
# tensor([-0.7786, -0.6145], grad_fn=<SelectBackward>)
# tensor([-0.7997, -0.5969], grad_fn=<SelectBackward>)
# tensor([-0.8068, -0.5911], grad_fn=<SelectBackward>)
# tensor([-0.7968, -0.5993], grad_fn=<SelectBackward>)
# tensor([-0.7419, -0.6466], grad_fn=<SelectBackward>)
# tensor([-0.8093, -0.5891], grad_fn=<SelectBackward>)
# tensor([-0.7595, -0.6309], grad_fn=<SelectBackward>)
# tensor([-0.8055, -0.5921], grad_fn=<SelectBackward>)
# tensor([-0.8169, -0.5830], grad_fn=<SelectBackward>)
# tensor([-0.7932, -0.6022], grad_fn=<SelectBackward>)
# tensor([-0.8067, -0.5912], grad_fn=<SelectBackward>)
# tensor([-0.8029, -0.5943], grad_fn=<SelectBackward>)
# tensor([-0.7904, -0.6045], grad_fn=<SelectBackward>)
# tensor([-0.7478, -0.6413], grad_fn=<SelectBackward>)
# tensor([-0.8259, -0.5760], grad_fn=<SelectBackward>)
# tensor([-0.7790, -0.6141], grad_fn=<SelectBackward>)
# tensor([-0.8151, -0.5844], grad_fn=<SelectBackward>)
# tensor([-0.7832, -0.6105], grad_fn=<SelectBackward>)
# tensor([-0.7967, -0.5994], grad_fn=<SelectBackward>)
# tensor([-0.7781, -0.6148], grad_fn=<SelectBackward>)
# tensor([-0.7468, -0.6422], grad_fn=<SelectBackward>)
# tensor([-0.7672, -0.6242], grad_fn=<SelectBackward>)
# tensor([-0.7851, -0.6090], grad_fn=<SelectBackward>)
# tensor([-0.8010, -0.5958], grad_fn=<SelectBackward>)
# tensor([-0.7830, -0.6107], grad_fn=<SelectBackward>)
# tensor([-0.7624, -0.6284], grad_fn=<SelectBackward>)
# tensor([-0.7892, -0.6055], grad_fn=<SelectBackward>)
# tensor([-0.8016, -0.5953], grad_fn=<SelectBackward>)
# tensor([-0.8227, -0.5785], grad_fn=<SelectBackward>)
# tensor([-0.7903, -0.6046], grad_fn=<SelectBackward>)
# tensor([-0.7975, -0.5987], grad_fn=<SelectBackward>)
# tensor([-0.7664, -0.6249], grad_fn=<SelectBackward>)
# tensor([-0.7932, -0.6022], grad_fn=<SelectBackward>)
# tensor([-0.8059, -0.5918], grad_fn=<SelectBackward>)
# tensor([-0.7730, -0.6192], grad_fn=<SelectBackward>)
# tensor([-0.7900, -0.6049], grad_fn=<SelectBackward>)
# tensor([-0.7889, -0.6057], grad_fn=<SelectBackward>)
# tensor([-0.7802, -0.6131], grad_fn=<SelectBackward>)
# tensor([-0.7632, -0.6277], grad_fn=<SelectBackward>)
# tensor([-0.8060, -0.5917], grad_fn=<SelectBackward>)
# tensor([-0.7217, -0.6654], grad_fn=<SelectBackward>)
# tensor([-0.8239, -0.5775], grad_fn=<SelectBackward>)
# tensor([-0.7468, -0.6422], grad_fn=<SelectBackward>)
# tensor([-0.7778, -0.6151], grad_fn=<SelectBackward>)
# tensor([-0.8038, -0.5936], grad_fn=<SelectBackward>)
# tensor([-0.7745, -0.6179], grad_fn=<SelectBackward>)
# tensor([-0.7897, -0.6051], grad_fn=<SelectBackward>)
# tensor([-0.7448, -0.6440], grad_fn=<SelectBackward>)
# tensor([-0.7826, -0.6110], grad_fn=<SelectBackward>)
# tensor([-0.7997, -0.5969], grad_fn=<SelectBackward>)
# tensor([-0.8019, -0.5951], grad_fn=<SelectBackward>)
# tensor([-0.7902, -0.6047], grad_fn=<SelectBackward>)
# tensor([-0.8154, -0.5842], grad_fn=<SelectBackward>)
# tensor([-0.7613, -0.6294], grad_fn=<SelectBackward>)
# tensor([-0.7818, -0.6117], grad_fn=<SelectBackward>)
# tensor([-0.7961, -0.5998], grad_fn=<SelectBackward>)
# tensor([-0.7639, -0.6271], grad_fn=<SelectBackward>)
# tensor([-0.7879, -0.6066], grad_fn=<SelectBackward>)
# tensor([-0.7986, -0.5977], grad_fn=<SelectBackward>)
# tensor([-0.7727, -0.6194], grad_fn=<SelectBackward>)
# tensor([-0.8259, -0.5759], grad_fn=<SelectBackward>)
# tensor([-0.7788, -0.6143], grad_fn=<SelectBackward>)
# tensor([-0.7871, -0.6073], grad_fn=<SelectBackward>)
# tensor([-0.7694, -0.6223], grad_fn=<SelectBackward>)
# tensor([-0.7421, -0.6465], grad_fn=<SelectBackward>)
# tensor([-0.7535, -0.6362], grad_fn=<SelectBackward>)
# tensor([-0.7693, -0.6224], grad_fn=<SelectBackward>)
# tensor([-0.8073, -0.5907], grad_fn=<SelectBackward>)
# tensor([-0.7937, -0.6018], grad_fn=<SelectBackward>)
# tensor([-0.8039, -0.5934], grad_fn=<SelectBackward>)
# tensor([-0.7904, -0.6045], grad_fn=<SelectBackward>)
# tensor([-0.8179, -0.5823], grad_fn=<SelectBackward>)
# tensor([-0.7494, -0.6399], grad_fn=<SelectBackward>)
# tensor([-0.7852, -0.6088], grad_fn=<SelectBackward>)
# tensor([-0.8058, -0.5919], grad_fn=<SelectBackward>)
# tensor([-0.8108, -0.5879], grad_fn=<SelectBackward>)
# tensor([-0.7401, -0.6483], grad_fn=<SelectBackward>)
# tensor([-0.7709, -0.6210], grad_fn=<SelectBackward>)
# tensor([-0.7460, -0.6429], grad_fn=<SelectBackward>)
# tensor([-0.7991, -0.5973], grad_fn=<SelectBackward>)
# tensor([-0.7399, -0.6484], grad_fn=<SelectBackward>)
# tensor([-0.8173, -0.5828], grad_fn=<SelectBackward>)
# tensor([-0.7795, -0.6136], grad_fn=<SelectBackward>)
# tensor([-0.8052, -0.5924], grad_fn=<SelectBackward>)
# tensor([-0.7891, -0.6056], grad_fn=<SelectBackward>)
# tensor([-0.7384, -0.6498], grad_fn=<SelectBackward>)
# tensor([-0.7657, -0.6255], grad_fn=<SelectBackward>)
# tensor([-0.7825, -0.6111], grad_fn=<SelectBackward>)
# tensor([-0.7910, -0.6040], grad_fn=<SelectBackward>)
# tensor([-0.8160, -0.5837], grad_fn=<SelectBackward>)
# tensor([-0.7718, -0.6202], grad_fn=<SelectBackward>)
# tensor([-0.7731, -0.6191], grad_fn=<SelectBackward>)
# tensor([-0.8066, -0.5913], grad_fn=<SelectBackward>)
# tensor([-0.7956, -0.6002], grad_fn=<SelectBackward>)
# tensor([-0.7624, -0.6284], grad_fn=<SelectBackward>)
# tensor([-0.7893, -0.6054], grad_fn=<SelectBackward>)
# tensor([-0.7579, -0.6323], grad_fn=<SelectBackward>)
# tensor([-0.7995, -0.5970], grad_fn=<SelectBackward>)
# tensor([-0.7913, -0.6038], grad_fn=<SelectBackward>)
# tensor([-0.7331, -0.6548], grad_fn=<SelectBackward>)
# tensor([-0.7855, -0.6086], grad_fn=<SelectBackward>)
# tensor([-0.7832, -0.6105], grad_fn=<SelectBackward>)
# tensor([-0.7658, -0.6254], grad_fn=<SelectBackward>)
# tensor([-0.7577, -0.6325], grad_fn=<SelectBackward>)
# tensor([-0.7711, -0.6208], grad_fn=<SelectBackward>)
# tensor([-0.7542, -0.6356], grad_fn=<SelectBackward>)
# tensor([-0.7312, -0.6565], grad_fn=<SelectBackward>)
# tensor([-0.8025, -0.5946], grad_fn=<SelectBackward>)
# tensor([-0.7579, -0.6323], grad_fn=<SelectBackward>)
# tensor([-0.7808, -0.6126], grad_fn=<SelectBackward>)
# tensor([-0.7864, -0.6079], grad_fn=<SelectBackward>)
# tensor([-0.7913, -0.6038], grad_fn=<SelectBackward>)
# tensor([-0.7578, -0.6324], grad_fn=<SelectBackward>)
# tensor([-0.7386, -0.6497], grad_fn=<SelectBackward>)
# tensor([-0.7361, -0.6519], grad_fn=<SelectBackward>)
# tensor([-0.7806, -0.6127], grad_fn=<SelectBackward>)
# tensor([-0.7462, -0.6428], grad_fn=<SelectBackward>)
# tensor([-0.7412, -0.6473], grad_fn=<SelectBackward>)
# tensor([-0.7446, -0.6442], grad_fn=<SelectBackward>)
# tensor([-0.8049, -0.5926], grad_fn=<SelectBackward>)
# tensor([-0.7376, -0.6506], grad_fn=<SelectBackward>)
# tensor([-0.7757, -0.6169], grad_fn=<SelectBackward>)
# tensor([-0.7808, -0.6126], grad_fn=<SelectBackward>)
# tensor([-0.7907, -0.6042], grad_fn=<SelectBackward>)
# tensor([-0.7759, -0.6167], grad_fn=<SelectBackward>)
# tensor([-0.7451, -0.6438], grad_fn=<SelectBackward>)
# tensor([-0.7924, -0.6029], grad_fn=<SelectBackward>)
# tensor([-0.8143, -0.5851], grad_fn=<SelectBackward>)
# tensor([-0.7839, -0.6099], grad_fn=<SelectBackward>)
# tensor([-0.7708, -0.6211], grad_fn=<SelectBackward>)
# tensor([-0.7881, -0.6065], grad_fn=<SelectBackward>)
# tensor([-0.7952, -0.6006], grad_fn=<SelectBackward>)
# tensor([-0.7891, -0.6056], grad_fn=<SelectBackward>)
# tensor([-0.7812, -0.6122], grad_fn=<SelectBackward>)
# tensor([-0.7415, -0.6470], grad_fn=<SelectBackward>)
# tensor([-0.7718, -0.6202], grad_fn=<SelectBackward>)
# tensor([-0.7559, -0.6341], grad_fn=<SelectBackward>)
# tensor([-0.7688, -0.6228], grad_fn=<SelectBackward>)
# tensor([-0.7758, -0.6168], grad_fn=<SelectBackward>)
# tensor([-0.7772, -0.6156], grad_fn=<SelectBackward>)
# tensor([-0.7375, -0.6507], grad_fn=<SelectBackward>)
# tensor([-0.7740, -0.6184], grad_fn=<SelectBackward>)
# tensor([-0.7960, -0.5999], grad_fn=<SelectBackward>)
# tensor([-0.7684, -0.6232], grad_fn=<SelectBackward>)
# tensor([-0.7784, -0.6146], grad_fn=<SelectBackward>)
# tensor([-0.7527, -0.6369], grad_fn=<SelectBackward>)
# tensor([-0.7815, -0.6120], grad_fn=<SelectBackward>)
# tensor([-0.7962, -0.5997], grad_fn=<SelectBackward>)
# tensor([-0.8221, -0.5790], grad_fn=<SelectBackward>)
# tensor([-0.7489, -0.6403], grad_fn=<SelectBackward>)
# tensor([-0.7781, -0.6149], grad_fn=<SelectBackward>)
# tensor([-0.7280, -0.6595], grad_fn=<SelectBackward>)
# tensor([-0.7533, -0.6364], grad_fn=<SelectBackward>)
# tensor([-0.7866, -0.6077], grad_fn=<SelectBackward>)
# tensor([-0.7851, -0.6089], grad_fn=<SelectBackward>)
# tensor([-0.7814, -0.6121], grad_fn=<SelectBackward>)
# tensor([-0.7692, -0.6225], grad_fn=<SelectBackward>)
# tensor([-0.7507, -0.6387], grad_fn=<SelectBackward>)
# tensor([-0.7726, -0.6195], grad_fn=<SelectBackward>)
# tensor([-0.7389, -0.6494], grad_fn=<SelectBackward>)
# tensor([-0.7839, -0.6099], grad_fn=<SelectBackward>)
# tensor([-0.7959, -0.6000], grad_fn=<SelectBackward>)
# tensor([-0.7873, -0.6071], grad_fn=<SelectBackward>)
# tensor([-0.7384, -0.6499], grad_fn=<SelectBackward>)
# tensor([-0.8004, -0.5963], grad_fn=<SelectBackward>)
# tensor([-0.7493, -0.6399], grad_fn=<SelectBackward>)
# tensor([-0.8140, -0.5853], grad_fn=<SelectBackward>)
# tensor([-0.7724, -0.6198], grad_fn=<SelectBackward>)
# tensor([-0.7581, -0.6322], grad_fn=<SelectBackward>)
# tensor([-0.7823, -0.6113], grad_fn=<SelectBackward>)
# tensor([-0.7701, -0.6217], grad_fn=<SelectBackward>)
# tensor([-0.7767, -0.6160], grad_fn=<SelectBackward>)
# tensor([-0.7115, -0.6752], grad_fn=<SelectBackward>)
# tensor([-0.7767, -0.6160], grad_fn=<SelectBackward>)
# tensor([-0.7463, -0.6427], grad_fn=<SelectBackward>)
# tensor([-0.7193, -0.6676], grad_fn=<SelectBackward>)
# tensor([-0.7347, -0.6533], grad_fn=<SelectBackward>)
# tensor([-0.7631, -0.6278], grad_fn=<SelectBackward>)
# tensor([-0.7618, -0.6289], grad_fn=<SelectBackward>)
# tensor([-0.7562, -0.6339], grad_fn=<SelectBackward>)
# tensor([-0.7615, -0.6291], grad_fn=<SelectBackward>)
# tensor([-0.7399, -0.6485], grad_fn=<SelectBackward>)
# tensor([-0.7640, -0.6270], grad_fn=<SelectBackward>)
# tensor([-0.7553, -0.6346], grad_fn=<SelectBackward>)
# tensor([-0.7761, -0.6165], grad_fn=<SelectBackward>)
# tensor([-0.7609, -0.6297], grad_fn=<SelectBackward>)
# tensor([-0.7751, -0.6174], grad_fn=<SelectBackward>)
# tensor([-0.7430, -0.6457], grad_fn=<SelectBackward>)
# tensor([-0.7729, -0.6193], grad_fn=<SelectBackward>)
# tensor([-0.7760, -0.6167], grad_fn=<SelectBackward>)
# tensor([-0.7926, -0.6027], grad_fn=<SelectBackward>)
# tensor([-0.7713, -0.6207], grad_fn=<SelectBackward>)
# tensor([-0.7855, -0.6086], grad_fn=<SelectBackward>)
# tensor([-0.7909, -0.6041], grad_fn=<SelectBackward>)
# tensor([-0.7434, -0.6453], grad_fn=<SelectBackward>)
# tensor([-0.7901, -0.6048], grad_fn=<SelectBackward>)
# tensor([-0.7451, -0.6437], grad_fn=<SelectBackward>)
# tensor([-0.7477, -0.6414], grad_fn=<SelectBackward>)
# tensor([-0.7499, -0.6394], grad_fn=<SelectBackward>)
# tensor([-0.7810, -0.6124], grad_fn=<SelectBackward>)
# tensor([-0.7632, -0.6277], grad_fn=<SelectBackward>)
# tensor([-0.7618, -0.6289], grad_fn=<SelectBackward>)
# tensor([-0.7537, -0.6361], grad_fn=<SelectBackward>)
# tensor([-0.7495, -0.6398], grad_fn=<SelectBackward>)
# tensor([-0.7696, -0.6221], grad_fn=<SelectBackward>)
# tensor([-0.7697, -0.6221], grad_fn=<SelectBackward>)
# tensor([-0.7887, -0.6059], grad_fn=<SelectBackward>)
# tensor([-0.7525, -0.6371], grad_fn=<SelectBackward>)
# tensor([-0.7860, -0.6082], grad_fn=<SelectBackward>)
# tensor([-0.7579, -0.6323], grad_fn=<SelectBackward>)
# tensor([-0.7778, -0.6151], grad_fn=<SelectBackward>)
# tensor([-0.7788, -0.6143], grad_fn=<SelectBackward>)
# tensor([-0.7550, -0.6349], grad_fn=<SelectBackward>)
# tensor([-0.7418, -0.6468], grad_fn=<SelectBackward>)
# tensor([-0.7273, -0.6601], grad_fn=<SelectBackward>)
# tensor([-0.7763, -0.6163], grad_fn=<SelectBackward>)
# tensor([-0.7748, -0.6176], grad_fn=<SelectBackward>)
# tensor([-0.7772, -0.6156], grad_fn=<SelectBackward>)
# tensor([-0.7769, -0.6158], grad_fn=<SelectBackward>)
# tensor([-0.7615, -0.6291], grad_fn=<SelectBackward>)
# tensor([-0.7181, -0.6688], grad_fn=<SelectBackward>)
# tensor([-0.7884, -0.6062], grad_fn=<SelectBackward>)
# tensor([-0.7490, -0.6403], grad_fn=<SelectBackward>)
# tensor([-0.7596, -0.6308], grad_fn=<SelectBackward>)
# tensor([-0.7754, -0.6171], grad_fn=<SelectBackward>)
# tensor([-0.7658, -0.6254], grad_fn=<SelectBackward>)
# tensor([-0.7478, -0.6413], grad_fn=<SelectBackward>)
# tensor([-0.7981, -0.5981], grad_fn=<SelectBackward>)
# tensor([-0.7931, -0.6023], grad_fn=<SelectBackward>)
# tensor([-0.7256, -0.6617], grad_fn=<SelectBackward>)
# tensor([-0.7930, -0.6024], grad_fn=<SelectBackward>)
# tensor([-0.7645, -0.6265], grad_fn=<SelectBackward>)
# tensor([-0.7595, -0.6309], grad_fn=<SelectBackward>)
# tensor([-0.7389, -0.6494], grad_fn=<SelectBackward>)
# tensor([-0.7264, -0.6610], grad_fn=<SelectBackward>)
# tensor([-0.7485, -0.6407], grad_fn=<SelectBackward>)
# tensor([-0.8106, -0.5881], grad_fn=<SelectBackward>)
# tensor([-0.7698, -0.6219], grad_fn=<SelectBackward>)
# tensor([-0.7411, -0.6474], grad_fn=<SelectBackward>)
# tensor([-0.7642, -0.6268], grad_fn=<SelectBackward>)
# tensor([-0.7972, -0.5989], grad_fn=<SelectBackward>)
# tensor([-0.7924, -0.6029], grad_fn=<SelectBackward>)
# tensor([-0.7908, -0.6042], grad_fn=<SelectBackward>)
# tensor([-0.7635, -0.6274], grad_fn=<SelectBackward>)
# tensor([-0.8012, -0.5956], grad_fn=<SelectBackward>)
# tensor([-0.7566, -0.6335], grad_fn=<SelectBackward>)
# tensor([-0.7689, -0.6227], grad_fn=<SelectBackward>)
# tensor([-0.7527, -0.6370], grad_fn=<SelectBackward>)
# tensor([-0.7755, -0.6170], grad_fn=<SelectBackward>)
# tensor([-0.7447, -0.6442], grad_fn=<SelectBackward>)
# tensor([-0.7513, -0.6382], grad_fn=<SelectBackward>)
# tensor([-0.7311, -0.6566], grad_fn=<SelectBackward>)
# tensor([-0.7650, -0.6261], grad_fn=<SelectBackward>)
# tensor([-0.7826, -0.6110], grad_fn=<SelectBackward>)
# tensor([-0.7446, -0.6442], grad_fn=<SelectBackward>)
# tensor([-0.7696, -0.6221], grad_fn=<SelectBackward>)
# tensor([-0.7594, -0.6310], grad_fn=<SelectBackward>)
# tensor([-0.7655, -0.6257], grad_fn=<SelectBackward>)
# tensor([-0.7517, -0.6378], grad_fn=<SelectBackward>)
# tensor([-0.7919, -0.6033], grad_fn=<SelectBackward>)
# tensor([-0.7525, -0.6371], grad_fn=<SelectBackward>)
# tensor([-0.7805, -0.6128], grad_fn=<SelectBackward>)
# tensor([-0.8057, -0.5920], grad_fn=<SelectBackward>)
# tensor([-0.7715, -0.6205], grad_fn=<SelectBackward>)
# tensor([-0.7422, -0.6464], grad_fn=<SelectBackward>)
# tensor([-0.7251, -0.6622], grad_fn=<SelectBackward>)
# tensor([-0.7849, -0.6091], grad_fn=<SelectBackward>)
# tensor([-0.7531, -0.6366], grad_fn=<SelectBackward>)
# tensor([-0.7918, -0.6034], grad_fn=<SelectBackward>)
# tensor([-0.7489, -0.6403], grad_fn=<SelectBackward>)
# tensor([-0.7712, -0.6208], grad_fn=<SelectBackward>)
# tensor([-0.7902, -0.6047], grad_fn=<SelectBackward>)
# tensor([-0.7983, -0.5980], grad_fn=<SelectBackward>)
# tensor([-0.7537, -0.6360], grad_fn=<SelectBackward>)
# tensor([-0.8016, -0.5953], grad_fn=<SelectBackward>)
# tensor([-0.7494, -0.6399], grad_fn=<SelectBackward>)
# tensor([-0.7957, -0.6001], grad_fn=<SelectBackward>)
# tensor([-0.7430, -0.6457], grad_fn=<SelectBackward>)
# tensor([-0.7711, -0.6208], grad_fn=<SelectBackward>)
# tensor([-0.7696, -0.6221], grad_fn=<SelectBackward>)
# tensor([-0.7667, -0.6246], grad_fn=<SelectBackward>)
# tensor([-0.7459, -0.6431], grad_fn=<SelectBackward>)
# tensor([-0.7472, -0.6419], grad_fn=<SelectBackward>)
# tensor([-0.7912, -0.6039], grad_fn=<SelectBackward>)
# tensor([-0.8021, -0.5949], grad_fn=<SelectBackward>)
# tensor([-0.7901, -0.6048], grad_fn=<SelectBackward>)
# tensor([-0.8029, -0.5943], grad_fn=<SelectBackward>)
# tensor([-0.7492, -0.6401], grad_fn=<SelectBackward>)
# tensor([-0.7744, -0.6180], grad_fn=<SelectBackward>)
# tensor([-0.7495, -0.6398], grad_fn=<SelectBackward>)
# tensor([-0.7949, -0.6008], grad_fn=<SelectBackward>)
# tensor([-0.7840, -0.6099], grad_fn=<SelectBackward>)
# tensor([-0.7578, -0.6325], grad_fn=<SelectBackward>)
# tensor([-0.7625, -0.6283], grad_fn=<SelectBackward>)
# tensor([-0.7326, -0.6552], grad_fn=<SelectBackward>)
# tensor([-0.7494, -0.6398], grad_fn=<SelectBackward>)
# tensor([-0.7680, -0.6235], grad_fn=<SelectBackward>)
# tensor([-0.7879, -0.6066], grad_fn=<SelectBackward>)
# tensor([-0.7533, -0.6364], grad_fn=<SelectBackward>)
# tensor([-0.7595, -0.6309], grad_fn=<SelectBackward>)
# tensor([-0.7435, -0.6452], grad_fn=<SelectBackward>)
# tensor([-0.7416, -0.6469], grad_fn=<SelectBackward>)
# tensor([-0.7824, -0.6112], grad_fn=<SelectBackward>)
# tensor([-0.7482, -0.6410], grad_fn=<SelectBackward>)
# tensor([-0.7768, -0.6160], grad_fn=<SelectBackward>)
# tensor([-0.7498, -0.6396], grad_fn=<SelectBackward>)
# tensor([-0.7540, -0.6357], grad_fn=<SelectBackward>)
# tensor([-0.7562, -0.6338], grad_fn=<SelectBackward>)
# tensor([-0.7673, -0.6241], grad_fn=<SelectBackward>)
# tensor([-0.7825, -0.6111], grad_fn=<SelectBackward>)
# tensor([-0.7826, -0.6110], grad_fn=<SelectBackward>)
# tensor([-0.7413, -0.6472], grad_fn=<SelectBackward>)
# tensor([-0.7468, -0.6422], grad_fn=<SelectBackward>)
# tensor([-0.7751, -0.6174], grad_fn=<SelectBackward>)
# tensor([-0.7628, -0.6280], grad_fn=<SelectBackward>)
# tensor([-0.7722, -0.6199], grad_fn=<SelectBackward>)
# tensor([-0.7342, -0.6537], grad_fn=<SelectBackward>)
# tensor([-0.7748, -0.6177], grad_fn=<SelectBackward>)
# tensor([-0.7779, -0.6150], grad_fn=<SelectBackward>)
# tensor([-0.7515, -0.6380], grad_fn=<SelectBackward>)
# tensor([-0.7433, -0.6454], grad_fn=<SelectBackward>)
# tensor([-0.7524, -0.6373], grad_fn=<SelectBackward>)
# tensor([-0.7511, -0.6384], grad_fn=<SelectBackward>)
# tensor([-0.7520, -0.6375], grad_fn=<SelectBackward>)
# tensor([-0.7945, -0.6012], grad_fn=<SelectBackward>)
# tensor([-0.7622, -0.6286], grad_fn=<SelectBackward>)
# tensor([-0.7631, -0.6277], grad_fn=<SelectBackward>)
# tensor([-0.7790, -0.6141], grad_fn=<SelectBackward>)
# tensor([-0.7424, -0.6462], grad_fn=<SelectBackward>)
# tensor([-0.7927, -0.6026], grad_fn=<SelectBackward>)
# tensor([-0.7366, -0.6515], grad_fn=<SelectBackward>)
# tensor([-0.7790, -0.6141], grad_fn=<SelectBackward>)
# tensor([-0.7769, -0.6158], grad_fn=<SelectBackward>)
# tensor([-0.7858, -0.6083], grad_fn=<SelectBackward>)
# tensor([-0.7636, -0.6273], grad_fn=<SelectBackward>)
# tensor([-0.7750, -0.6175], grad_fn=<SelectBackward>)
# tensor([-0.7610, -0.6296], grad_fn=<SelectBackward>)
# tensor([-0.7586, -0.6317], grad_fn=<SelectBackward>)
# tensor([-0.7646, -0.6264], grad_fn=<SelectBackward>)
# tensor([-0.7921, -0.6031], grad_fn=<SelectBackward>)
# tensor([-0.7400, -0.6484], grad_fn=<SelectBackward>)
# tensor([-0.7732, -0.6190], grad_fn=<SelectBackward>)
# tensor([-0.7374, -0.6507], grad_fn=<SelectBackward>)
# tensor([-0.7756, -0.6170], grad_fn=<SelectBackward>)
# tensor([-0.7406, -0.6479], grad_fn=<SelectBackward>)
# tensor([-0.7627, -0.6281], grad_fn=<SelectBackward>)
# tensor([-0.7435, -0.6452], grad_fn=<SelectBackward>)
# tensor([-0.7309, -0.6568], grad_fn=<SelectBackward>)
# tensor([-0.7877, -0.6068], grad_fn=<SelectBackward>)
# tensor([-0.7864, -0.6079], grad_fn=<SelectBackward>)
# tensor([-0.7518, -0.6378], grad_fn=<SelectBackward>)
# tensor([-0.7911, -0.6040], grad_fn=<SelectBackward>)
# tensor([-0.7575, -0.6327], grad_fn=<SelectBackward>)
# tensor([-0.7836, -0.6102], grad_fn=<SelectBackward>)
# tensor([-0.7842, -0.6097], grad_fn=<SelectBackward>)
# tensor([-0.7705, -0.6213], grad_fn=<SelectBackward>)
# tensor([-0.7532, -0.6365], grad_fn=<SelectBackward>)
# tensor([-0.7735, -0.6188], grad_fn=<SelectBackward>)
# tensor([-0.7925, -0.6028], grad_fn=<SelectBackward>)
# tensor([-0.7638, -0.6272], grad_fn=<SelectBackward>)
# tensor([-0.7340, -0.6539], grad_fn=<SelectBackward>)
# tensor([-0.7508, -0.6387], grad_fn=<SelectBackward>)
# tensor([-0.7645, -0.6265], grad_fn=<SelectBackward>)
# tensor([-0.7043, -0.6821], grad_fn=<SelectBackward>)
# tensor([-0.7444, -0.6444], grad_fn=<SelectBackward>)
# tensor([-0.7568, -0.6333], grad_fn=<SelectBackward>)
# tensor([-0.7472, -0.6419], grad_fn=<SelectBackward>)
# tensor([-0.7924, -0.6028], grad_fn=<SelectBackward>)
# tensor([-0.7819, -0.6116], grad_fn=<SelectBackward>)
# tensor([-0.7947, -0.6010], grad_fn=<SelectBackward>)
# tensor([-0.7801, -0.6132], grad_fn=<SelectBackward>)
# tensor([-0.7847, -0.6093], grad_fn=<SelectBackward>)
# tensor([-0.7473, -0.6418], grad_fn=<SelectBackward>)
# tensor([-0.7699, -0.6219], grad_fn=<SelectBackward>)
# tensor([-0.7323, -0.6555], grad_fn=<SelectBackward>)
# tensor([-0.7527, -0.6369], grad_fn=<SelectBackward>)
# tensor([-0.7591, -0.6312], grad_fn=<SelectBackward>)
# tensor([-0.7845, -0.6094], grad_fn=<SelectBackward>)
# tensor([-0.7185, -0.6684], grad_fn=<SelectBackward>)
# tensor([-0.7414, -0.6471], grad_fn=<SelectBackward>)
# tensor([-0.7719, -0.6201], grad_fn=<SelectBackward>)
# tensor([-0.7655, -0.6257], grad_fn=<SelectBackward>)
# tensor([-0.7386, -0.6497], grad_fn=<SelectBackward>)
# tensor([-0.7905, -0.6044], grad_fn=<SelectBackward>)
# tensor([-0.7635, -0.6274], grad_fn=<SelectBackward>)
# tensor([-0.7714, -0.6206], grad_fn=<SelectBackward>)
# tensor([-0.7394, -0.6489], grad_fn=<SelectBackward>)
# tensor([-0.7399, -0.6485], grad_fn=<SelectBackward>)
# tensor([-0.7358, -0.6522], grad_fn=<SelectBackward>)
# tensor([-0.7536, -0.6361], grad_fn=<SelectBackward>)
# tensor([-0.7770, -0.6158], grad_fn=<SelectBackward>)
# tensor([-0.7538, -0.6360], grad_fn=<SelectBackward>)
# tensor([-0.7610, -0.6296], grad_fn=<SelectBackward>)
# tensor([-0.7636, -0.6273], grad_fn=<SelectBackward>)
# tensor([-0.7478, -0.6414], grad_fn=<SelectBackward>)
# tensor([-0.7776, -0.6153], grad_fn=<SelectBackward>)
# tensor([-0.7753, -0.6172], grad_fn=<SelectBackward>)
# tensor([-0.7389, -0.6494], grad_fn=<SelectBackward>)
# tensor([-0.7586, -0.6317], grad_fn=<SelectBackward>)
# tensor([-0.7415, -0.6470], grad_fn=<SelectBackward>)
# tensor([-0.7478, -0.6413], grad_fn=<SelectBackward>)
# tensor([-0.7614, -0.6293], grad_fn=<SelectBackward>)
# tensor([-0.7655, -0.6257], grad_fn=<SelectBackward>)
# tensor([-0.7430, -0.6457], grad_fn=<SelectBackward>)
# tensor([-0.7647, -0.6263], grad_fn=<SelectBackward>)
# tensor([-0.7534, -0.6363], grad_fn=<SelectBackward>)
# tensor([-0.7968, -0.5993], grad_fn=<SelectBackward>)
# tensor([-0.7818, -0.6118], grad_fn=<SelectBackward>)
# tensor([-0.7744, -0.6180], grad_fn=<SelectBackward>)
# tensor([-0.7694, -0.6223], grad_fn=<SelectBackward>)
# tensor([-0.7765, -0.6162], grad_fn=<SelectBackward>)
# tensor([-0.7640, -0.6270], grad_fn=<SelectBackward>)
# tensor([-0.7509, -0.6386], grad_fn=<SelectBackward>)
# tensor([-0.7388, -0.6495], grad_fn=<SelectBackward>)
# tensor([-0.7750, -0.6175], grad_fn=<SelectBackward>)
# tensor([-0.7509, -0.6385], grad_fn=<SelectBackward>)
# tensor([-0.7821, -0.6115], grad_fn=<SelectBackward>)
# tensor([-0.7529, -0.6367], grad_fn=<SelectBackward>)
# tensor([-0.7594, -0.6310], grad_fn=<SelectBackward>)
# tensor([-0.7563, -0.6337], grad_fn=<SelectBackward>)
# tensor([-0.7622, -0.6285], grad_fn=<SelectBackward>)
# tensor([-0.7635, -0.6275], grad_fn=<SelectBackward>)
# tensor([-0.7374, -0.6507], grad_fn=<SelectBackward>)
# tensor([-0.7753, -0.6173], grad_fn=<SelectBackward>)
# tensor([-0.7919, -0.6033], grad_fn=<SelectBackward>)
# tensor([-0.7702, -0.6216], grad_fn=<SelectBackward>)
# tensor([-0.7443, -0.6445], grad_fn=<SelectBackward>)
# tensor([-0.7453, -0.6436], grad_fn=<SelectBackward>)
# tensor([-0.7804, -0.6129], grad_fn=<SelectBackward>)
# tensor([-0.7650, -0.6261], grad_fn=<SelectBackward>)
# tensor([-0.7540, -0.6358], grad_fn=<SelectBackward>)
# tensor([-0.7293, -0.6582], grad_fn=<SelectBackward>)
# tensor([-0.7831, -0.6106], grad_fn=<SelectBackward>)
# tensor([-0.7809, -0.6125], grad_fn=<SelectBackward>)
# tensor([-0.7720, -0.6201], grad_fn=<SelectBackward>)
# tensor([-0.7849, -0.6091], grad_fn=<SelectBackward>)
# tensor([-0.7733, -0.6190], grad_fn=<SelectBackward>)
# tensor([-0.7800, -0.6133], grad_fn=<SelectBackward>)
# tensor([-0.7387, -0.6496], grad_fn=<SelectBackward>)
# tensor([-0.7829, -0.6108], grad_fn=<SelectBackward>)
# tensor([-0.7433, -0.6454], grad_fn=<SelectBackward>)
# tensor([-0.7583, -0.6320], grad_fn=<SelectBackward>)
# tensor([-0.7675, -0.6240], grad_fn=<SelectBackward>)
# tensor([-0.7966, -0.5994], grad_fn=<SelectBackward>)
# tensor([-0.7181, -0.6688], grad_fn=<SelectBackward>)
# tensor([-0.7224, -0.6647], grad_fn=<SelectBackward>)
# tensor([-0.7338, -0.6541], grad_fn=<SelectBackward>)
# tensor([-0.7463, -0.6427], grad_fn=<SelectBackward>)
# tensor([-0.7803, -0.6130], grad_fn=<SelectBackward>)
# tensor([-0.7366, -0.6515], grad_fn=<SelectBackward>)
# tensor([-0.7309, -0.6568], grad_fn=<SelectBackward>)
# tensor([-0.7762, -0.6164], grad_fn=<SelectBackward>)
# tensor([-0.7215, -0.6656], grad_fn=<SelectBackward>)
# tensor([-0.7289, -0.6586], grad_fn=<SelectBackward>)
# tensor([-0.7422, -0.6464], grad_fn=<SelectBackward>)
# tensor([-0.7430, -0.6456], grad_fn=<SelectBackward>)
# tensor([-0.7947, -0.6009], grad_fn=<SelectBackward>)
# tensor([-0.7628, -0.6280], grad_fn=<SelectBackward>)
# tensor([-0.7323, -0.6555], grad_fn=<SelectBackward>)
# tensor([-0.7783, -0.6147], grad_fn=<SelectBackward>)
# tensor([-0.7625, -0.6283], grad_fn=<SelectBackward>)
# tensor([-0.7520, -0.6375], grad_fn=<SelectBackward>)
# tensor([-0.8014, -0.5955], grad_fn=<SelectBackward>)
# tensor([-0.7575, -0.6327], grad_fn=<SelectBackward>)
# tensor([-0.7435, -0.6452], grad_fn=<SelectBackward>)
# tensor([-0.7563, -0.6337], grad_fn=<SelectBackward>)
# tensor([-0.7453, -0.6435], grad_fn=<SelectBackward>)
# tensor([-0.7338, -0.6541], grad_fn=<SelectBackward>)
# tensor([-0.7548, -0.6351], grad_fn=<SelectBackward>)
# tensor([-0.7528, -0.6368], grad_fn=<SelectBackward>)
# tensor([-0.7720, -0.6200], grad_fn=<SelectBackward>)
# tensor([-0.7688, -0.6228], grad_fn=<SelectBackward>)
# tensor([-0.7835, -0.6103], grad_fn=<SelectBackward>)
# tensor([-0.7777, -0.6152], grad_fn=<SelectBackward>)
# tensor([-0.7808, -0.6126], grad_fn=<SelectBackward>)
# tensor([-0.7884, -0.6062], grad_fn=<SelectBackward>)
# tensor([-0.7513, -0.6382], grad_fn=<SelectBackward>)
# tensor([-0.7489, -0.6403], grad_fn=<SelectBackward>)
# tensor([-0.7614, -0.6293], grad_fn=<SelectBackward>)
# tensor([-0.7243, -0.6629], grad_fn=<SelectBackward>)
# tensor([-0.7511, -0.6384], grad_fn=<SelectBackward>)
# tensor([-0.7332, -0.6547], grad_fn=<SelectBackward>)
# tensor([-0.7589, -0.6314], grad_fn=<SelectBackward>)
# tensor([-0.7460, -0.6429], grad_fn=<SelectBackward>)
# tensor([-0.7339, -0.6540], grad_fn=<SelectBackward>)
# tensor([-0.7418, -0.6467], grad_fn=<SelectBackward>)
# tensor([-0.7543, -0.6355], grad_fn=<SelectBackward>)
# tensor([-0.7641, -0.6269], grad_fn=<SelectBackward>)
# tensor([-0.7436, -0.6451], grad_fn=<SelectBackward>)
# tensor([-0.7812, -0.6122], grad_fn=<SelectBackward>)
# tensor([-0.7916, -0.6035], grad_fn=<SelectBackward>)
# tensor([-0.7426, -0.6460], grad_fn=<SelectBackward>)
# tensor([-0.7620, -0.6287], grad_fn=<SelectBackward>)
# tensor([-0.7488, -0.6404], grad_fn=<SelectBackward>)
# tensor([-0.7230, -0.6641], grad_fn=<SelectBackward>)
# tensor([-0.7435, -0.6452], grad_fn=<SelectBackward>)
# tensor([-0.7762, -0.6165], grad_fn=<SelectBackward>)
# tensor([-0.7602, -0.6303], grad_fn=<SelectBackward>)
# tensor([-0.7338, -0.6541], grad_fn=<SelectBackward>)
# tensor([-0.7669, -0.6244], grad_fn=<SelectBackward>)
# tensor([-0.7858, -0.6084], grad_fn=<SelectBackward>)
# tensor([-0.7611, -0.6295], grad_fn=<SelectBackward>)
# tensor([-0.7698, -0.6220], grad_fn=<SelectBackward>)
# tensor([-0.7232, -0.6640], grad_fn=<SelectBackward>)
# tensor([-0.7350, -0.6530], grad_fn=<SelectBackward>)
# tensor([-0.7671, -0.6243], grad_fn=<SelectBackward>)
# tensor([-0.7566, -0.6335], grad_fn=<SelectBackward>)
# tensor([-0.7368, -0.6513], grad_fn=<SelectBackward>)
# tensor([-0.7530, -0.6367], grad_fn=<SelectBackward>)
# tensor([-0.7487, -0.6405], grad_fn=<SelectBackward>)
# tensor([-0.7827, -0.6110], grad_fn=<SelectBackward>)
# tensor([-0.7492, -0.6401], grad_fn=<SelectBackward>)
# tensor([-0.7685, -0.6231], grad_fn=<SelectBackward>)
# tensor([-0.7709, -0.6210], grad_fn=<SelectBackward>)
# tensor([-0.7676, -0.6238], grad_fn=<SelectBackward>)
# tensor([-0.7399, -0.6485], grad_fn=<SelectBackward>)
# tensor([-0.7939, -0.6017], grad_fn=<SelectBackward>)
# tensor([-0.7715, -0.6204], grad_fn=<SelectBackward>)
# tensor([-0.7459, -0.6431], grad_fn=<SelectBackward>)
# tensor([-0.7920, -0.6032], grad_fn=<SelectBackward>)
# tensor([-0.7746, -0.6178], grad_fn=<SelectBackward>)
# tensor([-0.7567, -0.6334], grad_fn=<SelectBackward>)
# tensor([-0.7496, -0.6397], grad_fn=<SelectBackward>)
# tensor([-0.7390, -0.6493], grad_fn=<SelectBackward>)
# tensor([-0.7554, -0.6345], grad_fn=<SelectBackward>)
# tensor([-0.7856, -0.6085], grad_fn=<SelectBackward>)
# tensor([-0.7719, -0.6201], grad_fn=<SelectBackward>)
# tensor([-0.7715, -0.6205], grad_fn=<SelectBackward>)
# tensor([-0.7759, -0.6167], grad_fn=<SelectBackward>)
# tensor([-0.7701, -0.6217], grad_fn=<SelectBackward>)
# tensor([-0.7668, -0.6245], grad_fn=<SelectBackward>)
# tensor([-0.6906, -0.6957], grad_fn=<SelectBackward>)
# tensor([-0.7504, -0.6390], grad_fn=<SelectBackward>)
# tensor([-0.7582, -0.6321], grad_fn=<SelectBackward>)
# tensor([-0.7523, -0.6373], grad_fn=<SelectBackward>)
# tensor([-0.7730, -0.6192], grad_fn=<SelectBackward>)
# tensor([-0.7478, -0.6413], grad_fn=<SelectBackward>)
# tensor([-0.7742, -0.6182], grad_fn=<SelectBackward>)
# tensor([-0.7629, -0.6279], grad_fn=<SelectBackward>)
# tensor([-0.7199, -0.6671], grad_fn=<SelectBackward>)
# tensor([-0.7464, -0.6426], grad_fn=<SelectBackward>)
# tensor([-0.7321, -0.6556], grad_fn=<SelectBackward>)
# tensor([-0.7312, -0.6565], grad_fn=<SelectBackward>)
# tensor([-0.7907, -0.6042], grad_fn=<SelectBackward>)
# tensor([-0.7784, -0.6146], grad_fn=<SelectBackward>)
# tensor([-0.7420, -0.6465], grad_fn=<SelectBackward>)
# tensor([-0.7420, -0.6466], grad_fn=<SelectBackward>)
# tensor([-0.7389, -0.6494], grad_fn=<SelectBackward>)
# tensor([-0.7536, -0.6362], grad_fn=<SelectBackward>)
# tensor([-0.7484, -0.6407], grad_fn=<SelectBackward>)
# tensor([-0.7817, -0.6118], grad_fn=<SelectBackward>)
# tensor([-0.7794, -0.6138], grad_fn=<SelectBackward>)
# tensor([-0.7491, -0.6402], grad_fn=<SelectBackward>)
# tensor([-0.7635, -0.6275], grad_fn=<SelectBackward>)
# tensor([-0.7635, -0.6274], grad_fn=<SelectBackward>)
# tensor([-0.7423, -0.6463], grad_fn=<SelectBackward>)
# tensor([-0.7892, -0.6055], grad_fn=<SelectBackward>)
# tensor([-0.7546, -0.6352], grad_fn=<SelectBackward>)
# tensor([-0.7660, -0.6253], grad_fn=<SelectBackward>)
# tensor([-0.7795, -0.6137], grad_fn=<SelectBackward>)
# tensor([-0.7598, -0.6307], grad_fn=<SelectBackward>)
# tensor([-0.7548, -0.6351], grad_fn=<SelectBackward>)
# tensor([-0.7746, -0.6178], grad_fn=<SelectBackward>)
# tensor([-0.7479, -0.6413], grad_fn=<SelectBackward>)
# tensor([-0.7460, -0.6429], grad_fn=<SelectBackward>)
# tensor([-0.7692, -0.6225], grad_fn=<SelectBackward>)
# tensor([-0.7475, -0.6416], grad_fn=<SelectBackward>)
# tensor([-0.7737, -0.6186], grad_fn=<SelectBackward>)
# tensor([-0.7404, -0.6480], grad_fn=<SelectBackward>)
# tensor([-0.7506, -0.6388], grad_fn=<SelectBackward>)
# tensor([-0.7545, -0.6353], grad_fn=<SelectBackward>)
# tensor([-0.7747, -0.6178], grad_fn=<SelectBackward>)
# tensor([-0.7614, -0.6292], grad_fn=<SelectBackward>)
# tensor([-0.7335, -0.6543], grad_fn=<SelectBackward>)
# tensor([-0.7351, -0.6529], grad_fn=<SelectBackward>)
# tensor([-0.7858, -0.6083], grad_fn=<SelectBackward>)
# tensor([-0.7481, -0.6410], grad_fn=<SelectBackward>)
# tensor([-0.7348, -0.6532], grad_fn=<SelectBackward>)
# tensor([-0.7432, -0.6455], grad_fn=<SelectBackward>)
# tensor([-0.7756, -0.6170], grad_fn=<SelectBackward>)
# tensor([-0.7513, -0.6382], grad_fn=<SelectBackward>)
# tensor([-0.7726, -0.6196], grad_fn=<SelectBackward>)
# tensor([-0.7702, -0.6216], grad_fn=<SelectBackward>)
# tensor([-0.7394, -0.6489], grad_fn=<SelectBackward>)
# tensor([-0.7426, -0.6460], grad_fn=<SelectBackward>)
# tensor([-0.7644, -0.6267], grad_fn=<SelectBackward>)
# tensor([-0.7393, -0.6490], grad_fn=<SelectBackward>)
# tensor([-0.8091, -0.5893], grad_fn=<SelectBackward>)
# tensor([-0.7311, -0.6566], grad_fn=<SelectBackward>)
# tensor([-0.7531, -0.6366], grad_fn=<SelectBackward>)
# tensor([-0.7512, -0.6383], grad_fn=<SelectBackward>)
# tensor([-0.7364, -0.6517], grad_fn=<SelectBackward>)
# tensor([-0.7448, -0.6440], grad_fn=<SelectBackward>)
# tensor([-0.7677, -0.6238], grad_fn=<SelectBackward>)
# tensor([-0.7376, -0.6506], grad_fn=<SelectBackward>)
# tensor([-0.7471, -0.6420], grad_fn=<SelectBackward>)
# tensor([-0.7248, -0.6625], grad_fn=<SelectBackward>)
# tensor([-0.7591, -0.6313], grad_fn=<SelectBackward>)
# tensor([-0.7603, -0.6302], grad_fn=<SelectBackward>)
# tensor([-0.7683, -0.6233], grad_fn=<SelectBackward>)
# tensor([-0.7723, -0.6198], grad_fn=<SelectBackward>)
# tensor([-0.7698, -0.6220], grad_fn=<SelectBackward>)
# tensor([-0.7165, -0.6703], grad_fn=<SelectBackward>)
# tensor([-0.7394, -0.6490], grad_fn=<SelectBackward>)
# tensor([-0.7257, -0.6616], grad_fn=<SelectBackward>)
# tensor([-0.7575, -0.6327], grad_fn=<SelectBackward>)
# tensor([-0.7321, -0.6556], grad_fn=<SelectBackward>)
# tensor([-0.7622, -0.6286], grad_fn=<SelectBackward>)
# tensor([-0.7467, -0.6424], grad_fn=<SelectBackward>)
# tensor([-0.7319, -0.6558], grad_fn=<SelectBackward>)
# tensor([-0.7473, -0.6418], grad_fn=<SelectBackward>)
# tensor([-0.7585, -0.6318], grad_fn=<SelectBackward>)
# tensor([-0.7508, -0.6386], grad_fn=<SelectBackward>)
# tensor([-0.7680, -0.6235], grad_fn=<SelectBackward>)
# tensor([-0.7934, -0.6020], grad_fn=<SelectBackward>)
# tensor([-0.7356, -0.6524], grad_fn=<SelectBackward>)
# tensor([-0.7610, -0.6296], grad_fn=<SelectBackward>)
# tensor([-0.7487, -0.6405], grad_fn=<SelectBackward>)
# tensor([-0.7593, -0.6311], grad_fn=<SelectBackward>)
# tensor([-0.7576, -0.6326], grad_fn=<SelectBackward>)
# tensor([-0.7876, -0.6069], grad_fn=<SelectBackward>)
# tensor([-0.7639, -0.6271], grad_fn=<SelectBackward>)
# tensor([-0.7431, -0.6455], grad_fn=<SelectBackward>)
# tensor([-0.7437, -0.6451], grad_fn=<SelectBackward>)
# tensor([-0.7495, -0.6398], grad_fn=<SelectBackward>)
# tensor([-0.7696, -0.6222], grad_fn=<SelectBackward>)
# tensor([-0.7382, -0.6500], grad_fn=<SelectBackward>)
# tensor([-0.7612, -0.6294], grad_fn=<SelectBackward>)
# tensor([-0.7406, -0.6479], grad_fn=<SelectBackward>)
# tensor([-0.7487, -0.6406], grad_fn=<SelectBackward>)
# tensor([-0.7571, -0.6330], grad_fn=<SelectBackward>)
# tensor([-0.7808, -0.6125], grad_fn=<SelectBackward>)
# tensor([-0.7453, -0.6435], grad_fn=<SelectBackward>)
# tensor([-0.7421, -0.6465], grad_fn=<SelectBackward>)
# tensor([-0.7738, -0.6186], grad_fn=<SelectBackward>)
# tensor([-0.7730, -0.6192], grad_fn=<SelectBackward>)
# tensor([-0.7390, -0.6493], grad_fn=<SelectBackward>)
# tensor([-0.7441, -0.6446], grad_fn=<SelectBackward>)
# tensor([-0.7253, -0.6620], grad_fn=<SelectBackward>)
# tensor([-0.7914, -0.6037], grad_fn=<SelectBackward>)
# tensor([-0.7278, -0.6596], grad_fn=<SelectBackward>)
# tensor([-0.7454, -0.6435], grad_fn=<SelectBackward>)
# tensor([-0.7808, -0.6126], grad_fn=<SelectBackward>)
# tensor([-0.7420, -0.6466], grad_fn=<SelectBackward>)
# tensor([-0.7238, -0.6634], grad_fn=<SelectBackward>)
# tensor([-0.7522, -0.6374], grad_fn=<SelectBackward>)
# tensor([-0.7545, -0.6354], grad_fn=<SelectBackward>)
# tensor([-0.7488, -0.6404], grad_fn=<SelectBackward>)
# tensor([-0.7362, -0.6518], grad_fn=<SelectBackward>)
# tensor([-0.7418, -0.6468], grad_fn=<SelectBackward>)
# tensor([-0.7129, -0.6738], grad_fn=<SelectBackward>)
# tensor([-0.7493, -0.6399], grad_fn=<SelectBackward>)
# tensor([-0.7771, -0.6157], grad_fn=<SelectBackward>)
# tensor([-0.7964, -0.5995], grad_fn=<SelectBackward>)
# tensor([-0.7468, -0.6422], grad_fn=<SelectBackward>)
# tensor([-0.7901, -0.6048], grad_fn=<SelectBackward>)
# tensor([-0.7749, -0.6175], grad_fn=<SelectBackward>)
# tensor([-0.7469, -0.6421], grad_fn=<SelectBackward>)
# tensor([-0.7468, -0.6423], grad_fn=<SelectBackward>)
# tensor([-0.7652, -0.6259], grad_fn=<SelectBackward>)
# tensor([-0.7811, -0.6123], grad_fn=<SelectBackward>)
# tensor([-0.7188, -0.6681], grad_fn=<SelectBackward>)
# tensor([-0.7641, -0.6269], grad_fn=<SelectBackward>)
# tensor([-0.7566, -0.6335], grad_fn=<SelectBackward>)
# tensor([-0.7694, -0.6223], grad_fn=<SelectBackward>)
# tensor([-0.7419, -0.6466], grad_fn=<SelectBackward>)
# tensor([-0.7750, -0.6175], grad_fn=<SelectBackward>)
# tensor([-0.7429, -0.6458], grad_fn=<SelectBackward>)
# tensor([-0.7857, -0.6084], grad_fn=<SelectBackward>)
# tensor([-0.7658, -0.6254], grad_fn=<SelectBackward>)
# tensor([-0.7325, -0.6553], grad_fn=<SelectBackward>)
# tensor([-0.7614, -0.6293], grad_fn=<SelectBackward>)
# tensor([-0.7358, -0.6522], grad_fn=<SelectBackward>)
# tensor([-0.7743, -0.6181], grad_fn=<SelectBackward>)
# tensor([-0.7447, -0.6441], grad_fn=<SelectBackward>)
# tensor([-0.7357, -0.6523], grad_fn=<SelectBackward>)
# tensor([-0.7745, -0.6179], grad_fn=<SelectBackward>)
# tensor([-0.7290, -0.6586], grad_fn=<SelectBackward>)
# tensor([-0.7622, -0.6286], grad_fn=<SelectBackward>)
# tensor([-0.7360, -0.6520], grad_fn=<SelectBackward>)
# tensor([-0.7708, -0.6211], grad_fn=<SelectBackward>)
# tensor([-0.7517, -0.6378], grad_fn=<SelectBackward>)
# tensor([-0.7478, -0.6413], grad_fn=<SelectBackward>)
# tensor([-0.7367, -0.6514], grad_fn=<SelectBackward>)
# tensor([-0.7656, -0.6256], grad_fn=<SelectBackward>)
# tensor([-0.7523, -0.6373], grad_fn=<SelectBackward>)
# tensor([-0.7381, -0.6501], grad_fn=<SelectBackward>)
# tensor([-0.7563, -0.6338], grad_fn=<SelectBackward>)
# tensor([-0.7493, -0.6399], grad_fn=<SelectBackward>)
# tensor([-0.7556, -0.6343], grad_fn=<SelectBackward>)
# tensor([-0.7389, -0.6494], grad_fn=<SelectBackward>)
# tensor([-0.7554, -0.6346], grad_fn=<SelectBackward>)
# tensor([-0.7435, -0.6452], grad_fn=<SelectBackward>)
# tensor([-0.7192, -0.6678], grad_fn=<SelectBackward>)
# tensor([-0.7615, -0.6292], grad_fn=<SelectBackward>)
# tensor([-0.7310, -0.6567], grad_fn=<SelectBackward>)
# tensor([-0.7723, -0.6198], grad_fn=<SelectBackward>)
# tensor([-0.7332, -0.6547], grad_fn=<SelectBackward>)
# tensor([-0.7353, -0.6527], grad_fn=<SelectBackward>)
# tensor([-0.7477, -0.6415], grad_fn=<SelectBackward>)
# tensor([-0.7374, -0.6508], grad_fn=<SelectBackward>)
# tensor([-0.7641, -0.6269], grad_fn=<SelectBackward>)
# tensor([-0.7417, -0.6469], grad_fn=<SelectBackward>)
# tensor([-0.7641, -0.6269], grad_fn=<SelectBackward>)
# tensor([-0.7399, -0.6485], grad_fn=<SelectBackward>)
# tensor([-0.7760, -0.6167], grad_fn=<SelectBackward>)
# tensor([-0.7728, -0.6193], grad_fn=<SelectBackward>)
# tensor([-0.7901, -0.6048], grad_fn=<SelectBackward>)
# tensor([-0.7129, -0.6738], grad_fn=<SelectBackward>)
# tensor([-0.7457, -0.6432], grad_fn=<SelectBackward>)
# tensor([-0.7353, -0.6527], grad_fn=<SelectBackward>)
# tensor([-0.7482, -0.6410], grad_fn=<SelectBackward>)
# tensor([-0.7376, -0.6506], grad_fn=<SelectBackward>)
# tensor([-0.7717, -0.6203], grad_fn=<SelectBackward>)
# tensor([-0.7697, -0.6221], grad_fn=<SelectBackward>)
# tensor([-0.7803, -0.6130], grad_fn=<SelectBackward>)
# tensor([-0.7809, -0.6125], grad_fn=<SelectBackward>)
# tensor([-0.7521, -0.6375], grad_fn=<SelectBackward>)
# tensor([-0.7431, -0.6455], grad_fn=<SelectBackward>)
# tensor([-0.7515, -0.6380], grad_fn=<SelectBackward>)
# tensor([-0.7684, -0.6232], grad_fn=<SelectBackward>)
# tensor([-0.7831, -0.6107], grad_fn=<SelectBackward>)
# tensor([-0.7627, -0.6281], grad_fn=<SelectBackward>)
# tensor([-0.7378, -0.6504], grad_fn=<SelectBackward>)
# tensor([-0.7588, -0.6316], grad_fn=<SelectBackward>)
# tensor([-0.7972, -0.5989], grad_fn=<SelectBackward>)
# tensor([-0.7761, -0.6166], grad_fn=<SelectBackward>)
# tensor([-0.7345, -0.6534], grad_fn=<SelectBackward>)
# tensor([-0.7384, -0.6499], grad_fn=<SelectBackward>)
# tensor([-0.7676, -0.6239], grad_fn=<SelectBackward>)
# tensor([-0.7715, -0.6205], grad_fn=<SelectBackward>)
# tensor([-0.7501, -0.6392], grad_fn=<SelectBackward>)
# tensor([-0.7645, -0.6265], grad_fn=<SelectBackward>)
# tensor([-0.7841, -0.6097], grad_fn=<SelectBackward>)
# tensor([-0.7577, -0.6325], grad_fn=<SelectBackward>)
# tensor([-0.7338, -0.6541], grad_fn=<SelectBackward>)
# tensor([-0.7248, -0.6624], grad_fn=<SelectBackward>)
# tensor([-0.7388, -0.6495], grad_fn=<SelectBackward>)
# tensor([-0.7698, -0.6219], grad_fn=<SelectBackward>)
# tensor([-0.7415, -0.6470], grad_fn=<SelectBackward>)
# tensor([-0.7478, -0.6413], grad_fn=<SelectBackward>)
# tensor([-0.7874, -0.6070], grad_fn=<SelectBackward>)
# tensor([-0.7684, -0.6232], grad_fn=<SelectBackward>)
# tensor([-0.7422, -0.6464], grad_fn=<SelectBackward>)
# tensor([-0.7639, -0.6271], grad_fn=<SelectBackward>)
# tensor([-0.7386, -0.6497], grad_fn=<SelectBackward>)
# tensor([-0.7722, -0.6199], grad_fn=<SelectBackward>)
# tensor([-0.7628, -0.6280], grad_fn=<SelectBackward>)
# tensor([-0.7617, -0.6290], grad_fn=<SelectBackward>)
# tensor([-0.7880, -0.6065], grad_fn=<SelectBackward>)
# tensor([-0.7713, -0.6207], grad_fn=<SelectBackward>)
# tensor([-0.7814, -0.6121], grad_fn=<SelectBackward>)
# tensor([-0.7497, -0.6396], grad_fn=<SelectBackward>)
# tensor([-0.7344, -0.6535], grad_fn=<SelectBackward>)
# tensor([-0.7174, -0.6695], grad_fn=<SelectBackward>)
# tensor([-0.7736, -0.6187], grad_fn=<SelectBackward>)
# tensor([-0.7332, -0.6546], grad_fn=<SelectBackward>)
# tensor([-0.7630, -0.6279], grad_fn=<SelectBackward>)
# tensor([-0.7379, -0.6503], grad_fn=<SelectBackward>)
# tensor([-0.7882, -0.6063], grad_fn=<SelectBackward>)
# tensor([-0.7423, -0.6463], grad_fn=<SelectBackward>)
# tensor([-0.7335, -0.6543], grad_fn=<SelectBackward>)
# tensor([-0.7704, -0.6214], grad_fn=<SelectBackward>)
# tensor([-0.7656, -0.6256], grad_fn=<SelectBackward>)
# tensor([-0.7630, -0.6279], grad_fn=<SelectBackward>)
# tensor([-0.7615, -0.6291], grad_fn=<SelectBackward>)
# tensor([-0.7290, -0.6586], grad_fn=<SelectBackward>)
# tensor([-0.7904, -0.6045], grad_fn=<SelectBackward>)
# tensor([-0.7349, -0.6531], grad_fn=<SelectBackward>)
# tensor([-0.7779, -0.6150], grad_fn=<SelectBackward>)
# tensor([-0.7451, -0.6437], grad_fn=<SelectBackward>)
# tensor([-0.7424, -0.6462], grad_fn=<SelectBackward>)
# tensor([-0.7453, -0.6436], grad_fn=<SelectBackward>)
# tensor([-0.7449, -0.6440], grad_fn=<SelectBackward>)
# tensor([-0.7479, -0.6413], grad_fn=<SelectBackward>)
# tensor([-0.7615, -0.6292], grad_fn=<SelectBackward>)
# tensor([-0.7401, -0.6483], grad_fn=<SelectBackward>)
# tensor([-0.7897, -0.6051], grad_fn=<SelectBackward>)
# tensor([-0.7540, -0.6358], grad_fn=<SelectBackward>)
# tensor([-0.7517, -0.6378], grad_fn=<SelectBackward>)
# tensor([-0.7430, -0.6457], grad_fn=<SelectBackward>)
# tensor([-0.7737, -0.6186], grad_fn=<SelectBackward>)
# tensor([-0.7800, -0.6133], grad_fn=<SelectBackward>)
# tensor([-0.7474, -0.6417], grad_fn=<SelectBackward>)
# tensor([-0.7787, -0.6144], grad_fn=<SelectBackward>)
# tensor([-0.7206, -0.6664], grad_fn=<SelectBackward>)
# tensor([-0.7225, -0.6646], grad_fn=<SelectBackward>)
# tensor([-0.7763, -0.6163], grad_fn=<SelectBackward>)
# tensor([-0.7518, -0.6377], grad_fn=<SelectBackward>)
# tensor([-0.7311, -0.6566], grad_fn=<SelectBackward>)
# tensor([-0.7874, -0.6070], grad_fn=<SelectBackward>)
# tensor([-0.7643, -0.6267], grad_fn=<SelectBackward>)
# tensor([-0.7194, -0.6676], grad_fn=<SelectBackward>)
# tensor([-0.7258, -0.6615], grad_fn=<SelectBackward>)
# tensor([-0.7723, -0.6198], grad_fn=<SelectBackward>)
# tensor([-0.7594, -0.6310], grad_fn=<SelectBackward>)
# tensor([-0.7959, -0.6000], grad_fn=<SelectBackward>)
# tensor([-0.7459, -0.6431], grad_fn=<SelectBackward>)
# tensor([-0.7785, -0.6145], grad_fn=<SelectBackward>)
# tensor([-0.7530, -0.6366], grad_fn=<SelectBackward>)
# tensor([-0.7270, -0.6604], grad_fn=<SelectBackward>)
# tensor([-0.7258, -0.6615], grad_fn=<SelectBackward>)
# tensor([-0.7425, -0.6461], grad_fn=<SelectBackward>)
# tensor([-0.7707, -0.6212], grad_fn=<SelectBackward>)
# tensor([-0.7477, -0.6414], grad_fn=<SelectBackward>)
# tensor([-0.7456, -0.6433], grad_fn=<SelectBackward>)
# tensor([-0.7763, -0.6164], grad_fn=<SelectBackward>)
# tensor([-0.7521, -0.6375], grad_fn=<SelectBackward>)
# tensor([-0.7303, -0.6574], grad_fn=<SelectBackward>)
# tensor([-0.7511, -0.6384], grad_fn=<SelectBackward>)
# tensor([-0.7799, -0.6134], grad_fn=<SelectBackward>)
# tensor([-0.7309, -0.6568], grad_fn=<SelectBackward>)
# tensor([-0.7296, -0.6580], grad_fn=<SelectBackward>)
# tensor([-0.7483, -0.6408], grad_fn=<SelectBackward>)
# tensor([-0.7697, -0.6220], grad_fn=<SelectBackward>)
# tensor([-0.7339, -0.6540], grad_fn=<SelectBackward>)
# tensor([-0.7707, -0.6212], grad_fn=<SelectBackward>)
# tensor([-0.7239, -0.6633], grad_fn=<SelectBackward>)
# tensor([-0.7687, -0.6229], grad_fn=<SelectBackward>)
# tensor([-0.7464, -0.6426], grad_fn=<SelectBackward>)
# tensor([-0.7195, -0.6674], grad_fn=<SelectBackward>)
# tensor([-0.7664, -0.6249], grad_fn=<SelectBackward>)
# tensor([-0.7342, -0.6537], grad_fn=<SelectBackward>)
# tensor([-0.7212, -0.6659], grad_fn=<SelectBackward>)
# tensor([-0.7368, -0.6513], grad_fn=<SelectBackward>)
# tensor([-0.7783, -0.6147], grad_fn=<SelectBackward>)
# tensor([-0.7399, -0.6484], grad_fn=<SelectBackward>)
# tensor([-0.7414, -0.6471], grad_fn=<SelectBackward>)
# tensor([-0.7431, -0.6455], grad_fn=<SelectBackward>)
# tensor([-0.7822, -0.6114], grad_fn=<SelectBackward>)
# tensor([-0.7685, -0.6231], grad_fn=<SelectBackward>)
# tensor([-0.7582, -0.6321], grad_fn=<SelectBackward>)
# tensor([-0.7479, -0.6412], grad_fn=<SelectBackward>)
# tensor([-0.7376, -0.6506], grad_fn=<SelectBackward>)
# tensor([-0.7456, -0.6433], grad_fn=<SelectBackward>)
# tensor([-0.7368, -0.6513], grad_fn=<SelectBackward>)
# tensor([-0.7604, -0.6301], grad_fn=<SelectBackward>)
# tensor([-0.7915, -0.6036], grad_fn=<SelectBackward>)
# tensor([-0.7834, -0.6104], grad_fn=<SelectBackward>)
# tensor([-0.7835, -0.6103], grad_fn=<SelectBackward>)
# tensor([-0.7651, -0.6260], grad_fn=<SelectBackward>)
# tensor([-0.7528, -0.6368], grad_fn=<SelectBackward>)
# tensor([-0.7386, -0.6497], grad_fn=<SelectBackward>)
# tensor([-0.7238, -0.6634], grad_fn=<SelectBackward>)
# tensor([-0.7700, -0.6218], grad_fn=<SelectBackward>)
# tensor([-0.7316, -0.6561], grad_fn=<SelectBackward>)
# tensor([-0.7475, -0.6416], grad_fn=<SelectBackward>)
# tensor([-0.7426, -0.6460], grad_fn=<SelectBackward>)
# tensor([-0.7254, -0.6619], grad_fn=<SelectBackward>)
# tensor([-0.7683, -0.6233], grad_fn=<SelectBackward>)
# tensor([-0.7308, -0.6568], grad_fn=<SelectBackward>)
# tensor([-0.7302, -0.6574], grad_fn=<SelectBackward>)
# tensor([-0.7330, -0.6548], grad_fn=<SelectBackward>)
# tensor([-0.7526, -0.6371], grad_fn=<SelectBackward>)
# tensor([-0.7417, -0.6468], grad_fn=<SelectBackward>)
# tensor([-0.7352, -0.6528], grad_fn=<SelectBackward>)
# tensor([-0.7513, -0.6382], grad_fn=<SelectBackward>)
# tensor([-0.7840, -0.6098], grad_fn=<SelectBackward>)
# tensor([-0.7367, -0.6515], grad_fn=<SelectBackward>)
# tensor([-0.7406, -0.6479], grad_fn=<SelectBackward>)
# tensor([-0.7743, -0.6181], grad_fn=<SelectBackward>)
# tensor([-0.7382, -0.6501], grad_fn=<SelectBackward>)
# tensor([-0.7377, -0.6505], grad_fn=<SelectBackward>)
# tensor([-0.7284, -0.6591], grad_fn=<SelectBackward>)
# tensor([-0.7367, -0.6514], grad_fn=<SelectBackward>)
# tensor([-0.7152, -0.6716], grad_fn=<SelectBackward>)
# tensor([-0.7381, -0.6501], grad_fn=<SelectBackward>)
# tensor([-0.7412, -0.6473], grad_fn=<SelectBackward>)
# tensor([-0.7415, -0.6471], grad_fn=<SelectBackward>)
# tensor([-0.7670, -0.6244], grad_fn=<SelectBackward>)
# tensor([-0.7560, -0.6340], grad_fn=<SelectBackward>)
# tensor([-0.7662, -0.6251], grad_fn=<SelectBackward>)
# tensor([-0.7407, -0.6477], grad_fn=<SelectBackward>)
# tensor([-0.7328, -0.6550], grad_fn=<SelectBackward>)
# tensor([-0.7206, -0.6664], grad_fn=<SelectBackward>)
# tensor([-0.7663, -0.6249], grad_fn=<SelectBackward>)
# tensor([-0.7588, -0.6316], grad_fn=<SelectBackward>)
# tensor([-0.7874, -0.6070], grad_fn=<SelectBackward>)
# tensor([-0.7398, -0.6485], grad_fn=<SelectBackward>)
# tensor([-0.7647, -0.6264], grad_fn=<SelectBackward>)
# tensor([-0.7607, -0.6298], grad_fn=<SelectBackward>)
# tensor([-0.7235, -0.6637], grad_fn=<SelectBackward>)
# tensor([-0.7267, -0.6606], grad_fn=<SelectBackward>)
# tensor([-0.7797, -0.6135], grad_fn=<SelectBackward>)
# tensor([-0.7388, -0.6495], grad_fn=<SelectBackward>)
# ...
# tensor([-3.2246, -0.0406], grad_fn=<SelectBackward>)
# tensor([-3.1724, -0.0428], grad_fn=<SelectBackward>)
# tensor([-1.1403, -0.3852], grad_fn=<SelectBackward>)
# tensor([-0.2180, -1.6305], grad_fn=<SelectBackward>)
# tensor([-3.0762, -0.0472], grad_fn=<SelectBackward>)
# tensor([-0.3091, -1.3248], grad_fn=<SelectBackward>)
# tensor([-0.8281, -0.5743], grad_fn=<SelectBackward>)
# tensor([-0.3477, -1.2253], grad_fn=<SelectBackward>)
# tensor([-2.0892, -0.1321], grad_fn=<SelectBackward>)
# tensor([-0.0477, -3.0656], grad_fn=<SelectBackward>)
# tensor([-0.0993, -2.3584], grad_fn=<SelectBackward>)
# tensor([-0.0280, -3.5881], grad_fn=<SelectBackward>)
# tensor([-0.0869, -2.4858], grad_fn=<SelectBackward>)
# tensor([-2.7008, -0.0695], grad_fn=<SelectBackward>)
# tensor([-2.3845, -0.0967], grad_fn=<SelectBackward>)
# tensor([-3.2775, -0.0385], grad_fn=<SelectBackward>)
# tensor([-0.0515, -2.9926], grad_fn=<SelectBackward>)
# tensor([-0.2885, -1.3839], grad_fn=<SelectBackward>)
# tensor([-3.4500, -0.0323], grad_fn=<SelectBackward>)
# tensor([-2.6859, -0.0706], grad_fn=<SelectBackward>)
# tensor([-3.3810, -0.0346], grad_fn=<SelectBackward>)
# tensor([-0.0418, -3.1951], grad_fn=<SelectBackward>)
# tensor([-0.3717, -1.1697], grad_fn=<SelectBackward>)
# tensor([-0.0252, -3.6917], grad_fn=<SelectBackward>)
# tensor([-2.2283, -0.1140], grad_fn=<SelectBackward>)
# tensor([-3.3354, -0.0362], grad_fn=<SelectBackward>)
# tensor([-0.1947, -1.7321], grad_fn=<SelectBackward>)
# tensor([-0.0504, -3.0128], grad_fn=<SelectBackward>)
# tensor([-3.3965, -0.0341], grad_fn=<SelectBackward>)
# tensor([-3.7724, -0.0233], grad_fn=<SelectBackward>)
# tensor([-0.0692, -2.7050], grad_fn=<SelectBackward>)
# tensor([-0.1297, -2.1069], grad_fn=<SelectBackward>)
# tensor([-2.4700, -0.0884], grad_fn=<SelectBackward>)
# tensor([-2.6630, -0.0723], grad_fn=<SelectBackward>)
# tensor([-0.0715, -2.6736], grad_fn=<SelectBackward>)
# tensor([-0.0646, -2.7718], grad_fn=<SelectBackward>)
# tensor([-2.5603, -0.0804], grad_fn=<SelectBackward>)
# tensor([-0.0326, -3.4404], grad_fn=<SelectBackward>)
# tensor([-2.3965, -0.0954], grad_fn=<SelectBackward>)
# tensor([-2.8309, -0.0608], grad_fn=<SelectBackward>)
# tensor([-0.0572, -2.8898], grad_fn=<SelectBackward>)
# tensor([-0.0829, -2.5309], grad_fn=<SelectBackward>)
# tensor([-3.2205, -0.0408], grad_fn=<SelectBackward>)
# tensor([-0.0588, -2.8628], grad_fn=<SelectBackward>)
# tensor([-0.0491, -3.0374], grad_fn=<SelectBackward>)
# tensor([-0.0311, -3.4874], grad_fn=<SelectBackward>)
# tensor([-0.0912, -2.4404], grad_fn=<SelectBackward>)
# tensor([-0.1308, -2.0989], grad_fn=<SelectBackward>)
# tensor([-0.1054, -2.3027], grad_fn=<SelectBackward>)
# tensor([-3.2025, -0.0415], grad_fn=<SelectBackward>)
# tensor([-0.5822, -0.8179], grad_fn=<SelectBackward>)
# tensor([-0.0844, -2.5146], grad_fn=<SelectBackward>)
# tensor([-0.1065, -2.2924], grad_fn=<SelectBackward>)
# tensor([-0.0289, -3.5579], grad_fn=<SelectBackward>)
# tensor([-3.3121, -0.0371], grad_fn=<SelectBackward>)
# tensor([-1.4636, -0.2632], grad_fn=<SelectBackward>)
# tensor([-3.3492, -0.0357], grad_fn=<SelectBackward>)
# tensor([-2.9441, -0.0541], grad_fn=<SelectBackward>)
# tensor([-3.4294, -0.0329], grad_fn=<SelectBackward>)
# tensor([-0.0493, -3.0353], grad_fn=<SelectBackward>)
# tensor([-2.0376, -0.1397], grad_fn=<SelectBackward>)
# tensor([-3.0183, -0.0501], grad_fn=<SelectBackward>)
# tensor([-3.0431, -0.0489], grad_fn=<SelectBackward>)
# tensor([-0.0930, -2.4213], grad_fn=<SelectBackward>)
# tensor([-2.8084, -0.0622], grad_fn=<SelectBackward>)
# tensor([-0.5922, -0.8054], grad_fn=<SelectBackward>)
# tensor([-2.8106, -0.0621], grad_fn=<SelectBackward>)
# tensor([-3.5649, -0.0287], grad_fn=<SelectBackward>)
# tensor([-0.1727, -1.8416], grad_fn=<SelectBackward>)
# tensor([-0.0581, -2.8748], grad_fn=<SelectBackward>)
# tensor([-0.1407, -2.0305], grad_fn=<SelectBackward>)
# tensor([-0.0421, -3.1891], grad_fn=<SelectBackward>)
# tensor([-2.0682, -0.1351], grad_fn=<SelectBackward>)
# tensor([-0.1323, -2.0883], grad_fn=<SelectBackward>)
# tensor([-0.0764, -2.6095], grad_fn=<SelectBackward>)
# tensor([-2.9267, -0.0551], grad_fn=<SelectBackward>)
# tensor([-1.8469, -0.1717], grad_fn=<SelectBackward>)
# tensor([-0.1069, -2.2892], grad_fn=<SelectBackward>)
# tensor([-2.3899, -0.0961], grad_fn=<SelectBackward>)
# tensor([-2.2772, -0.1082], grad_fn=<SelectBackward>)
# tensor([-3.1303, -0.0447], grad_fn=<SelectBackward>)
# tensor([-0.0751, -2.6256], grad_fn=<SelectBackward>)
# tensor([-0.8863, -0.5313], grad_fn=<SelectBackward>)
# tensor([-0.7188, -0.6682], grad_fn=<SelectBackward>)
# tensor([-0.0679, -2.7241], grad_fn=<SelectBackward>)
# tensor([-2.4372, -0.0915], grad_fn=<SelectBackward>)
# tensor([-0.0406, -3.2231], grad_fn=<SelectBackward>)
# tensor([-0.1051, -2.3049], grad_fn=<SelectBackward>)
# tensor([-0.0488, -3.0434], grad_fn=<SelectBackward>)
# tensor([-0.1099, -2.2623], grad_fn=<SelectBackward>)
# tensor([-2.7014, -0.0695], grad_fn=<SelectBackward>)
# tensor([-0.3195, -1.2966], grad_fn=<SelectBackward>)
# tensor([-0.0273, -3.6138], grad_fn=<SelectBackward>)
# tensor([-3.0964, -0.0463], grad_fn=<SelectBackward>)
# tensor([-0.0837, -2.5223], grad_fn=<SelectBackward>)
# tensor([-0.0265, -3.6443], grad_fn=<SelectBackward>)
# tensor([-3.2281, -0.0404], grad_fn=<SelectBackward>)
# tensor([-1.5935, -0.2272], grad_fn=<SelectBackward>)
# tensor([-3.1812, -0.0424], grad_fn=<SelectBackward>)
# tensor([-0.8566, -0.5527], grad_fn=<SelectBackward>)
# tensor([-1.6374, -0.2163], grad_fn=<SelectBackward>)
# tensor([-0.1009, -2.3436], grad_fn=<SelectBackward>)
# tensor([-3.2200, -0.0408], grad_fn=<SelectBackward>)
# tensor([-2.2442, -0.1121], grad_fn=<SelectBackward>)
# tensor([-2.3614, -0.0990], grad_fn=<SelectBackward>)
# tensor([-2.1458, -0.1244], grad_fn=<SelectBackward>)
# tensor([-3.3227, -0.0367], grad_fn=<SelectBackward>)
# tensor([-0.5093, -0.9185], grad_fn=<SelectBackward>)
# tensor([-2.6296, -0.0748], grad_fn=<SelectBackward>)
# tensor([-0.0901, -2.4519], grad_fn=<SelectBackward>)
# tensor([-3.0173, -0.0502], grad_fn=<SelectBackward>)
# tensor([-0.0634, -2.7896], grad_fn=<SelectBackward>)
# tensor([-1.7451, -0.1919], grad_fn=<SelectBackward>)
# tensor([-0.2649, -1.4580], grad_fn=<SelectBackward>)
# tensor([-0.0371, -3.3132], grad_fn=<SelectBackward>)
# tensor([-2.4412, -0.0911], grad_fn=<SelectBackward>)
# tensor([-0.0656, -2.7573], grad_fn=<SelectBackward>)
# tensor([-0.2597, -1.4752], grad_fn=<SelectBackward>)
# tensor([-2.7790, -0.0641], grad_fn=<SelectBackward>)
# tensor([-1.0722, -0.4190], grad_fn=<SelectBackward>)
# tensor([-0.1965, -1.7239], grad_fn=<SelectBackward>)
# tensor([-0.0481, -3.0585], grad_fn=<SelectBackward>)
# tensor([-0.0562, -2.9068], grad_fn=<SelectBackward>)
# tensor([-0.7450, -0.6438], grad_fn=<SelectBackward>)
# tensor([-3.2627, -0.0390], grad_fn=<SelectBackward>)
# tensor([-0.0550, -2.9273], grad_fn=<SelectBackward>)
# tensor([-0.7460, -0.6429], grad_fn=<SelectBackward>)
# tensor([-0.1543, -1.9451], grad_fn=<SelectBackward>)
# tensor([-0.2156, -1.6400], grad_fn=<SelectBackward>)
# tensor([-0.0714, -2.6754], grad_fn=<SelectBackward>)
# tensor([-0.1602, -1.9102], grad_fn=<SelectBackward>)
# tensor([-2.3538, -0.0998], grad_fn=<SelectBackward>)
# tensor([-0.0653, -2.7615], grad_fn=<SelectBackward>)
# tensor([-2.5600, -0.0805], grad_fn=<SelectBackward>)
# tensor([-2.6798, -0.0710], grad_fn=<SelectBackward>)
# tensor([-3.5684, -0.0286], grad_fn=<SelectBackward>)
# tensor([-3.6126, -0.0274], grad_fn=<SelectBackward>)
# tensor([-0.0626, -2.8015], grad_fn=<SelectBackward>)
# tensor([-2.4213, -0.0930], grad_fn=<SelectBackward>)
# tensor([-0.0842, -2.5167], grad_fn=<SelectBackward>)
# tensor([-1.9642, -0.1511], grad_fn=<SelectBackward>)
# tensor([-0.0419, -3.1923], grad_fn=<SelectBackward>)
# tensor([-2.9825, -0.0520], grad_fn=<SelectBackward>)
# tensor([-2.9324, -0.0547], grad_fn=<SelectBackward>)
# tensor([-2.3986, -0.0952], grad_fn=<SelectBackward>)
# tensor([-3.1285, -0.0448], grad_fn=<SelectBackward>)
# tensor([-0.0491, -3.0382], grad_fn=<SelectBackward>)
# tensor([-0.0420, -3.1915], grad_fn=<SelectBackward>)
# tensor([-1.9314, -0.1566], grad_fn=<SelectBackward>)
# tensor([-2.5529, -0.0811], grad_fn=<SelectBackward>)
# tensor([-3.2949, -0.0378], grad_fn=<SelectBackward>)
# tensor([-3.0162, -0.0502], grad_fn=<SelectBackward>)
# tensor([-1.1033, -0.4031], grad_fn=<SelectBackward>)
# tensor([-0.0544, -2.9379], grad_fn=<SelectBackward>)
# tensor([-1.6105, -0.2229], grad_fn=<SelectBackward>)
# tensor([-0.0645, -2.7731], grad_fn=<SelectBackward>)
# tensor([-0.0845, -2.5126], grad_fn=<SelectBackward>)
# tensor([-0.0400, -3.2397], grad_fn=<SelectBackward>)
# tensor([-0.0609, -2.8290], grad_fn=<SelectBackward>)
# tensor([-0.0742, -2.6384], grad_fn=<SelectBackward>)
# tensor([-0.2953, -1.3637], grad_fn=<SelectBackward>)
# tensor([-3.3646, -0.0352], grad_fn=<SelectBackward>)
# tensor([-2.9838, -0.0519], grad_fn=<SelectBackward>)
# tensor([-2.9827, -0.0520], grad_fn=<SelectBackward>)
# tensor([-0.0294, -3.5404], grad_fn=<SelectBackward>)
# tensor([-3.8445, -0.0216], grad_fn=<SelectBackward>)
# tensor([-3.1651, -0.0431], grad_fn=<SelectBackward>)
# tensor([-0.0436, -3.1554], grad_fn=<SelectBackward>)
# tensor([-0.0972, -2.3796], grad_fn=<SelectBackward>)
# tensor([-0.7624, -0.6284], grad_fn=<SelectBackward>)
# tensor([-2.5419, -0.0820], grad_fn=<SelectBackward>)
# tensor([-2.8652, -0.0587], grad_fn=<SelectBackward>)
# tensor([-0.1261, -2.1333], grad_fn=<SelectBackward>)
# tensor([-2.7232, -0.0679], grad_fn=<SelectBackward>)
# tensor([-3.0849, -0.0468], grad_fn=<SelectBackward>)
# tensor([-1.4318, -0.2730], grad_fn=<SelectBackward>)
# tensor([-2.8934, -0.0570], grad_fn=<SelectBackward>)
# tensor([-3.2149, -0.0410], grad_fn=<SelectBackward>)
# tensor([-3.5955, -0.0278], grad_fn=<SelectBackward>)
# tensor([-0.0609, -2.8283], grad_fn=<SelectBackward>)
# tensor([-0.0474, -3.0733], grad_fn=<SelectBackward>)
# tensor([-0.0953, -2.3983], grad_fn=<SelectBackward>)
# tensor([-0.3355, -1.2553], grad_fn=<SelectBackward>)
# tensor([-0.0321, -3.4537], grad_fn=<SelectBackward>)
# tensor([-3.0990, -0.0461], grad_fn=<SelectBackward>)
# tensor([-3.5247, -0.0299], grad_fn=<SelectBackward>)
# tensor([-0.0404, -3.2292], grad_fn=<SelectBackward>)
# tensor([-0.1487, -1.9794], grad_fn=<SelectBackward>)
# tensor([-0.0359, -3.3442], grad_fn=<SelectBackward>)
# tensor([-2.9244, -0.0552], grad_fn=<SelectBackward>)
# tensor([-2.7716, -0.0646], grad_fn=<SelectBackward>)
# tensor([-0.0718, -2.6701], grad_fn=<SelectBackward>)
# tensor([-0.1998, -1.7088], grad_fn=<SelectBackward>)
# tensor([-0.5264, -0.8934], grad_fn=<SelectBackward>)
# tensor([-0.0685, -2.7148], grad_fn=<SelectBackward>)
# tensor([-0.0405, -3.2270], grad_fn=<SelectBackward>)
# tensor([-3.3193, -0.0369], grad_fn=<SelectBackward>)
# tensor([-0.0748, -2.6304], grad_fn=<SelectBackward>)
# tensor([-0.0318, -3.4647], grad_fn=<SelectBackward>)
# tensor([-0.0586, -2.8654], grad_fn=<SelectBackward>)
# tensor([-3.4213, -0.0332], grad_fn=<SelectBackward>)
# tensor([-3.2471, -0.0397], grad_fn=<SelectBackward>)
# tensor([-0.5388, -0.8758], grad_fn=<SelectBackward>)
# tensor([-0.0445, -3.1355], grad_fn=<SelectBackward>)
# tensor([-0.0436, -3.1541], grad_fn=<SelectBackward>)
# tensor([-1.9692, -0.1503], grad_fn=<SelectBackward>)
# tensor([-0.0650, -2.7655], grad_fn=<SelectBackward>)
# tensor([-0.3621, -1.1914], grad_fn=<SelectBackward>)
# tensor([-0.0615, -2.8197], grad_fn=<SelectBackward>)
# tensor([-0.1034, -2.3200], grad_fn=<SelectBackward>)
# tensor([-3.1802, -0.0425], grad_fn=<SelectBackward>)
# tensor([-2.9571, -0.0534], grad_fn=<SelectBackward>)
# tensor([-2.0189, -0.1425], grad_fn=<SelectBackward>)
# tensor([-1.3702, -0.2931], grad_fn=<SelectBackward>)
# tensor([-2.5319, -0.0828], grad_fn=<SelectBackward>)
# tensor([-0.0752, -2.6253], grad_fn=<SelectBackward>)
# tensor([-0.0536, -2.9530], grad_fn=<SelectBackward>)
# tensor([-1.6833, -0.2055], grad_fn=<SelectBackward>)
# tensor([-3.0784, -0.0471], grad_fn=<SelectBackward>)
# tensor([-2.0255, -0.1415], grad_fn=<SelectBackward>)
# tensor([-3.1456, -0.0440], grad_fn=<SelectBackward>)
# tensor([-0.1470, -1.9898], grad_fn=<SelectBackward>)
# tensor([-0.0956, -2.3946], grad_fn=<SelectBackward>)
# tensor([-0.0525, -2.9738], grad_fn=<SelectBackward>)
# tensor([-0.0448, -3.1288], grad_fn=<SelectBackward>)
# tensor([-3.5688, -0.0286], grad_fn=<SelectBackward>)
# tensor([-2.3536, -0.0999], grad_fn=<SelectBackward>)
# tensor([-0.3197, -1.2959], grad_fn=<SelectBackward>)
# tensor([-0.0903, -2.4493], grad_fn=<SelectBackward>)
# tensor([-0.3891, -1.1322], grad_fn=<SelectBackward>)
# tensor([-0.0349, -3.3739], grad_fn=<SelectBackward>)
# tensor([-0.0564, -2.9030], grad_fn=<SelectBackward>)
# tensor([-2.6931, -0.0701], grad_fn=<SelectBackward>)
# tensor([-0.0633, -2.7920], grad_fn=<SelectBackward>)
# tensor([-3.3217, -0.0368], grad_fn=<SelectBackward>)
# tensor([-0.1434, -2.0130], grad_fn=<SelectBackward>)
# tensor([-2.8731, -0.0582], grad_fn=<SelectBackward>)
# tensor([-0.8102, -0.5884], grad_fn=<SelectBackward>)
# tensor([-0.0472, -3.0765], grad_fn=<SelectBackward>)
# tensor([-0.0350, -3.3709], grad_fn=<SelectBackward>)
# tensor([-2.6284, -0.0749], grad_fn=<SelectBackward>)
# tensor([-0.1822, -1.7922], grad_fn=<SelectBackward>)
# tensor([-0.0494, -3.0318], grad_fn=<SelectBackward>)
# tensor([-0.1015, -2.3382], grad_fn=<SelectBackward>)
# tensor([-3.1755, -0.0427], grad_fn=<SelectBackward>)
# tensor([-2.7723, -0.0646], grad_fn=<SelectBackward>)
# tensor([-0.0976, -2.3757], grad_fn=<SelectBackward>)
# tensor([-3.8177, -0.0222], grad_fn=<SelectBackward>)
# tensor([-3.0087, -0.0506], grad_fn=<SelectBackward>)
# tensor([-0.0485, -3.0508], grad_fn=<SelectBackward>)
# tensor([-1.7032, -0.2010], grad_fn=<SelectBackward>)
# tensor([-0.0544, -2.9384], grad_fn=<SelectBackward>)
# tensor([-0.2007, -1.7046], grad_fn=<SelectBackward>)
# tensor([-0.6562, -0.7315], grad_fn=<SelectBackward>)
# tensor([-3.5231, -0.0300], grad_fn=<SelectBackward>)
# tensor([-3.2447, -0.0398], grad_fn=<SelectBackward>)
# tensor([-3.4271, -0.0330], grad_fn=<SelectBackward>)
# tensor([-0.0899, -2.4541], grad_fn=<SelectBackward>)
# tensor([-0.0528, -2.9672], grad_fn=<SelectBackward>)
# tensor([-0.1082, -2.2770], grad_fn=<SelectBackward>)
# tensor([-0.4799, -0.9646], grad_fn=<SelectBackward>)
# tensor([-0.0742, -2.6384], grad_fn=<SelectBackward>)
# tensor([-1.6286, -0.2184], grad_fn=<SelectBackward>)
# tensor([-0.0289, -3.5586], grad_fn=<SelectBackward>)
# tensor([-0.0644, -2.7742], grad_fn=<SelectBackward>)
# tensor([-0.0531, -2.9613], grad_fn=<SelectBackward>)
# tensor([-2.8963, -0.0568], grad_fn=<SelectBackward>)
# tensor([-3.0064, -0.0507], grad_fn=<SelectBackward>)
# tensor([-0.0499, -3.0224], grad_fn=<SelectBackward>)
# tensor([-2.8562, -0.0592], grad_fn=<SelectBackward>)
# tensor([-3.2475, -0.0396], grad_fn=<SelectBackward>)
# tensor([-0.0785, -2.5836], grad_fn=<SelectBackward>)
# tensor([-0.0455, -3.1118], grad_fn=<SelectBackward>)
# tensor([-3.1732, -0.0428], grad_fn=<SelectBackward>)
# tensor([-2.9262, -0.0551], grad_fn=<SelectBackward>)
# tensor([-3.5415, -0.0294], grad_fn=<SelectBackward>)
# tensor([-0.1554, -1.9383], grad_fn=<SelectBackward>)
# tensor([-0.0568, -2.8965], grad_fn=<SelectBackward>)
# tensor([-0.0568, -2.8961], grad_fn=<SelectBackward>)
# tensor([-0.9855, -0.4672], grad_fn=<SelectBackward>)
# tensor([-0.0687, -2.7126], grad_fn=<SelectBackward>)
# tensor([-0.1162, -2.2102], grad_fn=<SelectBackward>)
# tensor([-0.0422, -3.1859], grad_fn=<SelectBackward>)
# tensor([-0.4055, -1.0986], grad_fn=<SelectBackward>)
# tensor([-3.2503, -0.0395], grad_fn=<SelectBackward>)
# tensor([-0.2767, -1.4199], grad_fn=<SelectBackward>)
# tensor([-0.0672, -2.7336], grad_fn=<SelectBackward>)
# tensor([-0.1038, -2.3167], grad_fn=<SelectBackward>)
# tensor([-0.0481, -3.0592], grad_fn=<SelectBackward>)
# tensor([-1.1095, -0.4001], grad_fn=<SelectBackward>)
# tensor([-3.7560, -0.0237], grad_fn=<SelectBackward>)
# tensor([-3.6599, -0.0261], grad_fn=<SelectBackward>)
# tensor([-0.6115, -0.7821], grad_fn=<SelectBackward>)
# tensor([-0.0436, -3.1554], grad_fn=<SelectBackward>)
# tensor([-1.6195, -0.2207], grad_fn=<SelectBackward>)
# tensor([-1.3332, -0.3060], grad_fn=<SelectBackward>)
# tensor([-3.3702, -0.0350], grad_fn=<SelectBackward>)
# tensor([-0.0424, -3.1824], grad_fn=<SelectBackward>)
# tensor([-0.0985, -2.3669], grad_fn=<SelectBackward>)
# tensor([-0.0994, -2.3580], grad_fn=<SelectBackward>)
# tensor([-3.6616, -0.0260], grad_fn=<SelectBackward>)

# %%
trained_model(vocab.sentence_to_tensor("this is a sentence", c2i))
# Out:
# tensor([-2.5913, -0.0779], grad_fn=<SelectBackward>)
# tensor([-2.5913, -0.0779], grad_fn=<SelectBackward>)

# %%
(np.exp(-2.5913))
# Out:
# 0.074922577397689

# %%
trained_model(vocab.sentence_to_tensor("quien estas", c2i))
# Out:
# tensor([-0.2926, -1.3717], grad_fn=<SelectBackward>)
# tensor([-0.2926, -1.3717], grad_fn=<SelectBackward>)

# %%
lang_id.predict_one(trained_model, "this is a sentence", c2i, i2l)
# Out:
# tensor([-2.5913, -0.0779], grad_fn=<SelectBackward>)
# False
# 'eng'

# %%
lang_id.predict_one(trained_model, "quien estas", c2i, i2l)
# Out:
# tensor([-0.2926, -1.3717], grad_fn=<SelectBackward>)
# False
# 'spa'

# %% [markdown]
# Now that we've got a trained model, it's time to evaluate its performance.
#
# * **Deliverable 2.3:** Complete the `eval_acc()` function in `hw3_utils.lang_id`. Note that PyTorch `Tensor` objects have an `argmax()` function!
# * **Test:** `nosetests tests/test_lang_id.py:test_d2_3_eval_acc`

# %%
reload(lang_id);

# %%
acc, y_hat = lang_id.eval_acc(trained_model, bi_text_test, c2i, i2c, l2i, i2l)
print(f"Accuracy: {acc}")
# Out:
# tensor([-0.0482, -3.0571], grad_fn=<SelectBackward>)
# tensor([-3.8526, -0.0215], grad_fn=<SelectBackward>)
# tensor([-2.4991, -0.0857], grad_fn=<SelectBackward>)
# tensor([-3.1070, -0.0458], grad_fn=<SelectBackward>)
# tensor([-0.0492, -3.0366], grad_fn=<SelectBackward>)
# tensor([-0.0317, -3.4667], grad_fn=<SelectBackward>)
# tensor([-1.7218, -0.1969], grad_fn=<SelectBackward>)
# tensor([-0.2792, -1.4123], grad_fn=<SelectBackward>)
# tensor([-0.0536, -2.9524], grad_fn=<SelectBackward>)
# tensor([-3.2439, -0.0398], grad_fn=<SelectBackward>)
# tensor([-3.5670, -0.0286], grad_fn=<SelectBackward>)
# tensor([-1.7638, -0.1880], grad_fn=<SelectBackward>)
# tensor([-0.7504, -0.6390], grad_fn=<SelectBackward>)
# tensor([-0.1764, -1.8219], grad_fn=<SelectBackward>)
# tensor([-0.0474, -3.0733], grad_fn=<SelectBackward>)
# tensor([-3.2077, -0.0413], grad_fn=<SelectBackward>)
# tensor([-0.0336, -3.4107], grad_fn=<SelectBackward>)
# tensor([-0.0491, -3.0383], grad_fn=<SelectBackward>)
# tensor([-2.4025, -0.0949], grad_fn=<SelectBackward>)
# tensor([-3.1603, -0.0433], grad_fn=<SelectBackward>)
# tensor([-3.4120, -0.0335], grad_fn=<SelectBackward>)
# tensor([-2.5923, -0.0778], grad_fn=<SelectBackward>)
# tensor([-0.2289, -1.5868], grad_fn=<SelectBackward>)
# tensor([-0.0505, -3.0106], grad_fn=<SelectBackward>)
# tensor([-2.7517, -0.0659], grad_fn=<SelectBackward>)
# tensor([-0.1208, -2.1737], grad_fn=<SelectBackward>)
# tensor([-0.2759, -1.4225], grad_fn=<SelectBackward>)
# tensor([-0.5909, -0.8070], grad_fn=<SelectBackward>)
# tensor([-0.6106, -0.7832], grad_fn=<SelectBackward>)
# tensor([-1.6579, -0.2114], grad_fn=<SelectBackward>)
# tensor([-2.1404, -0.1251], grad_fn=<SelectBackward>)
# tensor([-0.0589, -2.8613], grad_fn=<SelectBackward>)
# tensor([-0.0322, -3.4512], grad_fn=<SelectBackward>)
# tensor([-0.3932, -1.1236], grad_fn=<SelectBackward>)
# tensor([-0.0365, -3.3296], grad_fn=<SelectBackward>)
# tensor([-0.1086, -2.2739], grad_fn=<SelectBackward>)
# tensor([-0.0420, -3.1901], grad_fn=<SelectBackward>)
# tensor([-2.9350, -0.0546], grad_fn=<SelectBackward>)
# tensor([-0.0582, -2.8729], grad_fn=<SelectBackward>)
# tensor([-0.1145, -2.2239], grad_fn=<SelectBackward>)
# tensor([-0.1980, -1.7168], grad_fn=<SelectBackward>)
# tensor([-0.0805, -2.5598], grad_fn=<SelectBackward>)
# tensor([-2.7602, -0.0654], grad_fn=<SelectBackward>)
# tensor([-1.6694, -0.2087], grad_fn=<SelectBackward>)
# tensor([-0.0606, -2.8344], grad_fn=<SelectBackward>)
# tensor([-0.0697, -2.6977], grad_fn=<SelectBackward>)
# tensor([-1.2297, -0.3458], grad_fn=<SelectBackward>)
# tensor([-0.3031, -1.3414], grad_fn=<SelectBackward>)
# tensor([-0.1196, -2.1824], grad_fn=<SelectBackward>)
# tensor([-3.2057, -0.0414], grad_fn=<SelectBackward>)
# tensor([-0.0452, -3.1202], grad_fn=<SelectBackward>)
# tensor([-0.0407, -3.2216], grad_fn=<SelectBackward>)
# tensor([-0.0582, -2.8720], grad_fn=<SelectBackward>)
# tensor([-0.0508, -3.0048], grad_fn=<SelectBackward>)
# tensor([-3.3857, -0.0344], grad_fn=<SelectBackward>)
# tensor([-0.3442, -1.2336], grad_fn=<SelectBackward>)
# tensor([-3.6784, -0.0256], grad_fn=<SelectBackward>)
# tensor([-0.0971, -2.3798], grad_fn=<SelectBackward>)
# tensor([-0.2664, -1.4531], grad_fn=<SelectBackward>)
# tensor([-0.0317, -3.4682], grad_fn=<SelectBackward>)
# tensor([-1.5025, -0.2518], grad_fn=<SelectBackward>)
# tensor([-0.0445, -3.1337], grad_fn=<SelectBackward>)
# tensor([-0.0590, -2.8594], grad_fn=<SelectBackward>)
# tensor([-0.0744, -2.6354], grad_fn=<SelectBackward>)
# tensor([-2.8328, -0.0607], grad_fn=<SelectBackward>)
# tensor([-1.4152, -0.2782], grad_fn=<SelectBackward>)
# tensor([-0.8352, -0.5688], grad_fn=<SelectBackward>)
# tensor([-0.1621, -1.8996], grad_fn=<SelectBackward>)
# tensor([-0.1357, -2.0641], grad_fn=<SelectBackward>)
# tensor([-0.4041, -1.1013], grad_fn=<SelectBackward>)
# tensor([-3.0002, -0.0511], grad_fn=<SelectBackward>)
# tensor([-2.7631, -0.0652], grad_fn=<SelectBackward>)
# tensor([-3.4766, -0.0314], grad_fn=<SelectBackward>)
# tensor([-0.0458, -3.1056], grad_fn=<SelectBackward>)
# tensor([-0.0417, -3.1979], grad_fn=<SelectBackward>)
# tensor([-2.1996, -0.1175], grad_fn=<SelectBackward>)
# tensor([-0.1055, -2.3012], grad_fn=<SelectBackward>)
# tensor([-2.9149, -0.0557], grad_fn=<SelectBackward>)
# tensor([-1.7886, -0.1829], grad_fn=<SelectBackward>)
# tensor([-2.4361, -0.0916], grad_fn=<SelectBackward>)
# tensor([-0.1220, -2.1641], grad_fn=<SelectBackward>)
# tensor([-3.2480, -0.0396], grad_fn=<SelectBackward>)
# tensor([-0.7119, -0.6748], grad_fn=<SelectBackward>)
# tensor([-0.0934, -2.4168], grad_fn=<SelectBackward>)
# tensor([-0.0374, -3.3059], grad_fn=<SelectBackward>)
# tensor([-0.1236, -2.1517], grad_fn=<SelectBackward>)
# tensor([-3.5219, -0.0300], grad_fn=<SelectBackward>)
# tensor([-2.7412, -0.0667], grad_fn=<SelectBackward>)
# tensor([-3.6849, -0.0254], grad_fn=<SelectBackward>)
# tensor([-0.0660, -2.7510], grad_fn=<SelectBackward>)
# tensor([-0.7736, -0.6187], grad_fn=<SelectBackward>)
# tensor([-0.3812, -1.1491], grad_fn=<SelectBackward>)
# tensor([-0.1354, -2.0668], grad_fn=<SelectBackward>)
# tensor([-2.7317, -0.0673], grad_fn=<SelectBackward>)
# tensor([-0.2858, -1.3921], grad_fn=<SelectBackward>)
# tensor([-0.0322, -3.4519], grad_fn=<SelectBackward>)
# tensor([-0.2783, -1.4151], grad_fn=<SelectBackward>)
# tensor([-0.0252, -3.6928], grad_fn=<SelectBackward>)
# tensor([-0.0473, -3.0742], grad_fn=<SelectBackward>)
# tensor([-0.1570, -1.9289], grad_fn=<SelectBackward>)
# tensor([-0.0431, -3.1652], grad_fn=<SelectBackward>)
# tensor([-3.6123, -0.0274], grad_fn=<SelectBackward>)
# tensor([-1.2270, -0.3469], grad_fn=<SelectBackward>)
# tensor([-0.2067, -1.6780], grad_fn=<SelectBackward>)
# tensor([-2.7453, -0.0664], grad_fn=<SelectBackward>)
# tensor([-3.1494, -0.0438], grad_fn=<SelectBackward>)
# tensor([-0.1606, -1.9083], grad_fn=<SelectBackward>)
# tensor([-0.0744, -2.6351], grad_fn=<SelectBackward>)
# tensor([-0.0454, -3.1153], grad_fn=<SelectBackward>)
# tensor([-2.9967, -0.0512], grad_fn=<SelectBackward>)
# tensor([-0.0271, -3.6226], grad_fn=<SelectBackward>)
# tensor([-3.3431, -0.0360], grad_fn=<SelectBackward>)
# tensor([-3.5026, -0.0306], grad_fn=<SelectBackward>)
# tensor([-0.0389, -3.2658], grad_fn=<SelectBackward>)
# tensor([-0.1230, -2.1564], grad_fn=<SelectBackward>)
# tensor([-0.0318, -3.4636], grad_fn=<SelectBackward>)
# tensor([-2.2101, -0.1162], grad_fn=<SelectBackward>)
# tensor([-0.0530, -2.9641], grad_fn=<SelectBackward>)
# tensor([-2.0259, -0.1414], grad_fn=<SelectBackward>)
# tensor([-2.6525, -0.0731], grad_fn=<SelectBackward>)
# tensor([-0.3191, -1.2975], grad_fn=<SelectBackward>)
# tensor([-0.3069, -1.3309], grad_fn=<SelectBackward>)
# tensor([-1.5448, -0.2400], grad_fn=<SelectBackward>)
# tensor([-3.0049, -0.0508], grad_fn=<SelectBackward>)
# tensor([-2.6705, -0.0717], grad_fn=<SelectBackward>)
# tensor([-3.0855, -0.0468], grad_fn=<SelectBackward>)
# tensor([-1.9467, -0.1540], grad_fn=<SelectBackward>)
# tensor([-3.3540, -0.0356], grad_fn=<SelectBackward>)
# tensor([-0.0683, -2.7185], grad_fn=<SelectBackward>)
# tensor([-0.0566, -2.8998], grad_fn=<SelectBackward>)
# tensor([-2.9078, -0.0561], grad_fn=<SelectBackward>)
# tensor([-0.0911, -2.4413], grad_fn=<SelectBackward>)
# tensor([-3.0819, -0.0470], grad_fn=<SelectBackward>)
# tensor([-0.0854, -2.5033], grad_fn=<SelectBackward>)
# tensor([-0.2939, -1.3678], grad_fn=<SelectBackward>)
# tensor([-1.7355, -0.1940], grad_fn=<SelectBackward>)
# tensor([-2.3398, -0.1013], grad_fn=<SelectBackward>)
# tensor([-0.3869, -1.1368], grad_fn=<SelectBackward>)
# tensor([-0.0565, -2.9010], grad_fn=<SelectBackward>)
# tensor([-0.0387, -3.2705], grad_fn=<SelectBackward>)
# tensor([-0.0479, -3.0633], grad_fn=<SelectBackward>)
# tensor([-0.2585, -1.4792], grad_fn=<SelectBackward>)
# tensor([-3.5664, -0.0287], grad_fn=<SelectBackward>)
# tensor([-3.2573, -0.0393], grad_fn=<SelectBackward>)
# tensor([-2.9175, -0.0556], grad_fn=<SelectBackward>)
# tensor([-0.1252, -2.1397], grad_fn=<SelectBackward>)
# tensor([-1.0445, -0.4336], grad_fn=<SelectBackward>)
# tensor([-0.2023, -1.6974], grad_fn=<SelectBackward>)
# tensor([-2.3129, -0.1042], grad_fn=<SelectBackward>)
# tensor([-3.3914, -0.0342], grad_fn=<SelectBackward>)
# tensor([-2.5620, -0.0803], grad_fn=<SelectBackward>)
# tensor([-0.3360, -1.2540], grad_fn=<SelectBackward>)
# tensor([-3.2945, -0.0378], grad_fn=<SelectBackward>)
# tensor([-0.8499, -0.5577], grad_fn=<SelectBackward>)
# tensor([-0.0810, -2.5534], grad_fn=<SelectBackward>)
# tensor([-2.6377, -0.0742], grad_fn=<SelectBackward>)
# tensor([-3.1192, -0.0452], grad_fn=<SelectBackward>)
# tensor([-0.0586, -2.8667], grad_fn=<SelectBackward>)
# tensor([-1.8419, -0.1726], grad_fn=<SelectBackward>)
# tensor([-2.0812, -0.1333], grad_fn=<SelectBackward>)
# tensor([-0.0806, -2.5582], grad_fn=<SelectBackward>)
# tensor([-3.2983, -0.0376], grad_fn=<SelectBackward>)
# tensor([-0.1521, -1.9584], grad_fn=<SelectBackward>)
# tensor([-3.7239, -0.0244], grad_fn=<SelectBackward>)
# tensor([-2.7179, -0.0683], grad_fn=<SelectBackward>)
# tensor([-0.5842, -0.8154], grad_fn=<SelectBackward>)
# tensor([-0.0750, -2.6277], grad_fn=<SelectBackward>)
# tensor([-0.1515, -1.9622], grad_fn=<SelectBackward>)
# tensor([-3.6711, -0.0258], grad_fn=<SelectBackward>)
# tensor([-1.4407, -0.2702], grad_fn=<SelectBackward>)
# tensor([-3.0604, -0.0480], grad_fn=<SelectBackward>)
# tensor([-0.1868, -1.7696], grad_fn=<SelectBackward>)
# tensor([-0.0635, -2.7890], grad_fn=<SelectBackward>)
# tensor([-3.6908, -0.0253], grad_fn=<SelectBackward>)
# tensor([-0.9313, -0.5009], grad_fn=<SelectBackward>)
# tensor([-3.3669, -0.0351], grad_fn=<SelectBackward>)
# tensor([-0.1072, -2.2861], grad_fn=<SelectBackward>)
# tensor([-0.2179, -1.6306], grad_fn=<SelectBackward>)
# tensor([-0.2874, -1.3873], grad_fn=<SelectBackward>)
# tensor([-2.9262, -0.0551], grad_fn=<SelectBackward>)
# tensor([-1.6548, -0.2121], grad_fn=<SelectBackward>)
# tensor([-3.2569, -0.0393], grad_fn=<SelectBackward>)
# tensor([-2.6962, -0.0698], grad_fn=<SelectBackward>)
# tensor([-0.0708, -2.6835], grad_fn=<SelectBackward>)
# tensor([-0.0560, -2.9095], grad_fn=<SelectBackward>)
# tensor([-1.8263, -0.1756], grad_fn=<SelectBackward>)
# tensor([-0.2522, -1.5008], grad_fn=<SelectBackward>)
# tensor([-2.8102, -0.0621], grad_fn=<SelectBackward>)
# tensor([-0.7498, -0.6395], grad_fn=<SelectBackward>)
# tensor([-0.0738, -2.6434], grad_fn=<SelectBackward>)
# tensor([-3.4277, -0.0330], grad_fn=<SelectBackward>)
# tensor([-3.2690, -0.0388], grad_fn=<SelectBackward>)
# tensor([-3.6677, -0.0259], grad_fn=<SelectBackward>)
# tensor([-0.0302, -3.5158], grad_fn=<SelectBackward>)
# tensor([-2.9904, -0.0516], grad_fn=<SelectBackward>)
# tensor([-0.0459, -3.1049], grad_fn=<SelectBackward>)
# tensor([-1.7819, -0.1843], grad_fn=<SelectBackward>)
# tensor([-0.8677, -0.5446], grad_fn=<SelectBackward>)
# tensor([-3.4632, -0.0318], grad_fn=<SelectBackward>)
# tensor([-0.0648, -2.7685], grad_fn=<SelectBackward>)
# tensor([-1.3008, -0.3179], grad_fn=<SelectBackward>)
# tensor([-1.7432, -0.1923], grad_fn=<SelectBackward>)
# tensor([-0.0655, -2.7587], grad_fn=<SelectBackward>)
# tensor([-3.3200, -0.0368], grad_fn=<SelectBackward>)
# tensor([-0.0515, -2.9912], grad_fn=<SelectBackward>)
# tensor([-3.4422, -0.0325], grad_fn=<SelectBackward>)
# tensor([-0.0408, -3.2189], grad_fn=<SelectBackward>)
# tensor([-2.3936, -0.0957], grad_fn=<SelectBackward>)
# tensor([-0.0900, -2.4530], grad_fn=<SelectBackward>)
# tensor([-2.5890, -0.0781], grad_fn=<SelectBackward>)
# tensor([-2.2129, -0.1158], grad_fn=<SelectBackward>)
# tensor([-0.0598, -2.8472], grad_fn=<SelectBackward>)
# tensor([-0.0328, -3.4350], grad_fn=<SelectBackward>)
# tensor([-3.6075, -0.0275], grad_fn=<SelectBackward>)
# tensor([-1.6162, -0.2215], grad_fn=<SelectBackward>)
# tensor([-0.0387, -3.2714], grad_fn=<SelectBackward>)
# tensor([-0.6640, -0.7232], grad_fn=<SelectBackward>)
# tensor([-3.3191, -0.0369], grad_fn=<SelectBackward>)
# tensor([-0.5560, -0.8521], grad_fn=<SelectBackward>)
# tensor([-0.9469, -0.4909], grad_fn=<SelectBackward>)
# tensor([-3.0399, -0.0490], grad_fn=<SelectBackward>)
# tensor([-0.0335, -3.4126], grad_fn=<SelectBackward>)
# tensor([-0.2793, -1.4120], grad_fn=<SelectBackward>)
# tensor([-0.0346, -3.3798], grad_fn=<SelectBackward>)
# tensor([-0.0418, -3.1964], grad_fn=<SelectBackward>)
# tensor([-3.5122, -0.0303], grad_fn=<SelectBackward>)
# tensor([-3.0028, -0.0509], grad_fn=<SelectBackward>)
# tensor([-0.0359, -3.3442], grad_fn=<SelectBackward>)
# tensor([-2.2964, -0.1061], grad_fn=<SelectBackward>)
# tensor([-2.6410, -0.0740], grad_fn=<SelectBackward>)
# tensor([-0.0398, -3.2444], grad_fn=<SelectBackward>)
# tensor([-0.1470, -1.9898], grad_fn=<SelectBackward>)
# tensor([-0.2954, -1.3634], grad_fn=<SelectBackward>)
# tensor([-2.0916, -0.1318], grad_fn=<SelectBackward>)
# tensor([-3.4169, -0.0334], grad_fn=<SelectBackward>)
# tensor([-1.4410, -0.2701], grad_fn=<SelectBackward>)
# tensor([-1.4961, -0.2536], grad_fn=<SelectBackward>)
# tensor([-0.5776, -0.8238], grad_fn=<SelectBackward>)
# tensor([-2.3921, -0.0959], grad_fn=<SelectBackward>)
# tensor([-0.0327, -3.4357], grad_fn=<SelectBackward>)
# tensor([-1.3660, -0.2946], grad_fn=<SelectBackward>)
# tensor([-3.3874, -0.0344], grad_fn=<SelectBackward>)
# tensor([-1.7766, -0.1854], grad_fn=<SelectBackward>)
# tensor([-0.3539, -1.2104], grad_fn=<SelectBackward>)
# tensor([-0.0742, -2.6382], grad_fn=<SelectBackward>)
# tensor([-0.1068, -2.2896], grad_fn=<SelectBackward>)
# tensor([-1.2848, -0.3239], grad_fn=<SelectBackward>)
# tensor([-3.0754, -0.0473], grad_fn=<SelectBackward>)
# tensor([-0.0880, -2.4745], grad_fn=<SelectBackward>)
# tensor([-0.0474, -3.0720], grad_fn=<SelectBackward>)
# tensor([-0.2269, -1.5946], grad_fn=<SelectBackward>)
# tensor([-0.0378, -3.2930], grad_fn=<SelectBackward>)
# tensor([-2.7139, -0.0686], grad_fn=<SelectBackward>)
# tensor([-2.6664, -0.0720], grad_fn=<SelectBackward>)
# tensor([-0.3679, -1.1783], grad_fn=<SelectBackward>)
# tensor([-0.1146, -2.2229], grad_fn=<SelectBackward>)
# tensor([-2.3518, -0.1000], grad_fn=<SelectBackward>)
# tensor([-1.2069, -0.3554], grad_fn=<SelectBackward>)
# tensor([-0.5139, -0.9117], grad_fn=<SelectBackward>)
# tensor([-0.1452, -2.0016], grad_fn=<SelectBackward>)
# tensor([-0.2190, -1.6263], grad_fn=<SelectBackward>)
# tensor([-1.4066, -0.2810], grad_fn=<SelectBackward>)
# tensor([-0.0706, -2.6856], grad_fn=<SelectBackward>)
# tensor([-3.3037, -0.0374], grad_fn=<SelectBackward>)
# tensor([-0.1559, -1.9357], grad_fn=<SelectBackward>)
# tensor([-2.7607, -0.0653], grad_fn=<SelectBackward>)
# tensor([-3.0785, -0.0471], grad_fn=<SelectBackward>)
# tensor([-0.0450, -3.1245], grad_fn=<SelectBackward>)
# tensor([-2.8146, -0.0618], grad_fn=<SelectBackward>)
# tensor([-0.0396, -3.2488], grad_fn=<SelectBackward>)
# tensor([-2.3005, -0.1056], grad_fn=<SelectBackward>)
# tensor([-0.1353, -2.0673], grad_fn=<SelectBackward>)
# tensor([-3.5812, -0.0282], grad_fn=<SelectBackward>)
# tensor([-0.1091, -2.2695], grad_fn=<SelectBackward>)
# tensor([-0.1774, -1.8167], grad_fn=<SelectBackward>)
# tensor([-0.0457, -3.1090], grad_fn=<SelectBackward>)
# tensor([-0.0526, -2.9715], grad_fn=<SelectBackward>)
# tensor([-0.1100, -2.2615], grad_fn=<SelectBackward>)
# tensor([-0.1359, -2.0632], grad_fn=<SelectBackward>)
# tensor([-0.1651, -1.8827], grad_fn=<SelectBackward>)
# tensor([-2.7055, -0.0692], grad_fn=<SelectBackward>)
# tensor([-0.0691, -2.7067], grad_fn=<SelectBackward>)
# tensor([-3.3671, -0.0351], grad_fn=<SelectBackward>)
# tensor([-0.0527, -2.9701], grad_fn=<SelectBackward>)
# tensor([-0.0783, -2.5862], grad_fn=<SelectBackward>)
# tensor([-1.3340, -0.3057], grad_fn=<SelectBackward>)
# tensor([-0.1022, -2.3313], grad_fn=<SelectBackward>)
# tensor([-1.4707, -0.2611], grad_fn=<SelectBackward>)
# tensor([-1.7247, -0.1963], grad_fn=<SelectBackward>)
# tensor([-0.4131, -1.0836], grad_fn=<SelectBackward>)
# tensor([-0.0253, -3.6880], grad_fn=<SelectBackward>)
# tensor([-2.6781, -0.0712], grad_fn=<SelectBackward>)
# tensor([-0.0282, -3.5839], grad_fn=<SelectBackward>)
# tensor([-0.1809, -1.7987], grad_fn=<SelectBackward>)
# tensor([-0.0502, -3.0160], grad_fn=<SelectBackward>)
# tensor([-2.1766, -0.1204], grad_fn=<SelectBackward>)
# tensor([-0.0309, -3.4930], grad_fn=<SelectBackward>)
# tensor([-2.6726, -0.0716], grad_fn=<SelectBackward>)
# tensor([-2.6034, -0.0769], grad_fn=<SelectBackward>)
# tensor([-3.5587, -0.0289], grad_fn=<SelectBackward>)
# tensor([-0.1036, -2.3182], grad_fn=<SelectBackward>)
# tensor([-1.1691, -0.3720], grad_fn=<SelectBackward>)
# tensor([-0.0372, -3.3106], grad_fn=<SelectBackward>)
# tensor([-3.3340, -0.0363], grad_fn=<SelectBackward>)
# tensor([-0.2109, -1.6599], grad_fn=<SelectBackward>)
# tensor([-0.0576, -2.8824], grad_fn=<SelectBackward>)
# tensor([-0.0458, -3.1053], grad_fn=<SelectBackward>)
# tensor([-2.1439, -0.1247], grad_fn=<SelectBackward>)
# tensor([-0.0821, -2.5408], grad_fn=<SelectBackward>)
# tensor([-0.0658, -2.7539], grad_fn=<SelectBackward>)
# tensor([-0.0366, -3.3258], grad_fn=<SelectBackward>)
# tensor([-0.5302, -0.8879], grad_fn=<SelectBackward>)
# tensor([-0.0531, -2.9612], grad_fn=<SelectBackward>)
# tensor([-3.4798, -0.0313], grad_fn=<SelectBackward>)
# tensor([-3.3287, -0.0365], grad_fn=<SelectBackward>)
# tensor([-3.3921, -0.0342], grad_fn=<SelectBackward>)
# tensor([-0.4940, -0.9421], grad_fn=<SelectBackward>)
# tensor([-0.0465, -3.0923], grad_fn=<SelectBackward>)
# tensor([-0.0517, -2.9888], grad_fn=<SelectBackward>)
# tensor([-0.0792, -2.5748], grad_fn=<SelectBackward>)
# tensor([-2.4985, -0.0858], grad_fn=<SelectBackward>)
# tensor([-2.3149, -0.1040], grad_fn=<SelectBackward>)
# tensor([-2.6420, -0.0739], grad_fn=<SelectBackward>)
# tensor([-1.8486, -0.1713], grad_fn=<SelectBackward>)
# tensor([-0.0832, -2.5282], grad_fn=<SelectBackward>)
# tensor([-0.0360, -3.3428], grad_fn=<SelectBackward>)
# tensor([-2.1117, -0.1290], grad_fn=<SelectBackward>)
# tensor([-0.0476, -3.0683], grad_fn=<SelectBackward>)
# tensor([-0.3546, -1.2087], grad_fn=<SelectBackward>)
# tensor([-2.8356, -0.0605], grad_fn=<SelectBackward>)
# tensor([-1.9485, -0.1537], grad_fn=<SelectBackward>)
# tensor([-2.4985, -0.0858], grad_fn=<SelectBackward>)
# tensor([-2.8680, -0.0585], grad_fn=<SelectBackward>)
# tensor([-0.3402, -1.2436], grad_fn=<SelectBackward>)
# tensor([-0.0351, -3.3663], grad_fn=<SelectBackward>)
# tensor([-1.4496, -0.2674], grad_fn=<SelectBackward>)
# tensor([-0.0705, -2.6878], grad_fn=<SelectBackward>)
# tensor([-0.1860, -1.7735], grad_fn=<SelectBackward>)
# tensor([-0.1173, -2.2013], grad_fn=<SelectBackward>)
# tensor([-0.5745, -0.8278], grad_fn=<SelectBackward>)
# tensor([-1.6015, -0.2251], grad_fn=<SelectBackward>)
# tensor([-0.0327, -3.4353], grad_fn=<SelectBackward>)
# tensor([-2.9995, -0.0511], grad_fn=<SelectBackward>)
# tensor([-1.0320, -0.4405], grad_fn=<SelectBackward>)
# tensor([-0.0322, -3.4507], grad_fn=<SelectBackward>)
# tensor([-3.3489, -0.0358], grad_fn=<SelectBackward>)
# tensor([-0.1574, -1.9267], grad_fn=<SelectBackward>)
# tensor([-0.0875, -2.4793], grad_fn=<SelectBackward>)
# tensor([-0.1039, -2.3155], grad_fn=<SelectBackward>)
# tensor([-0.0379, -3.2911], grad_fn=<SelectBackward>)
# tensor([-3.0001, -0.0511], grad_fn=<SelectBackward>)
# tensor([-0.1090, -2.2703], grad_fn=<SelectBackward>)
# tensor([-2.3381, -0.1015], grad_fn=<SelectBackward>)
# tensor([-0.0418, -3.1950], grad_fn=<SelectBackward>)
# tensor([-0.0499, -3.0222], grad_fn=<SelectBackward>)
# tensor([-0.1331, -2.0824], grad_fn=<SelectBackward>)
# tensor([-0.1849, -1.7791], grad_fn=<SelectBackward>)
# tensor([-1.9352, -0.1559], grad_fn=<SelectBackward>)
# tensor([-2.8480, -0.0597], grad_fn=<SelectBackward>)
# tensor([-0.0263, -3.6527], grad_fn=<SelectBackward>)
# tensor([-0.1297, -2.1069], grad_fn=<SelectBackward>)
# tensor([-1.9478, -0.1538], grad_fn=<SelectBackward>)
# tensor([-3.1230, -0.0450], grad_fn=<SelectBackward>)
# tensor([-0.0614, -2.8215], grad_fn=<SelectBackward>)
# tensor([-2.1226, -0.1275], grad_fn=<SelectBackward>)
# tensor([-0.0443, -3.1398], grad_fn=<SelectBackward>)
# tensor([-0.0301, -3.5193], grad_fn=<SelectBackward>)
# tensor([-0.0403, -3.2308], grad_fn=<SelectBackward>)
# tensor([-0.0579, -2.8777], grad_fn=<SelectBackward>)
# tensor([-0.1842, -1.7826], grad_fn=<SelectBackward>)
# tensor([-0.0381, -3.2877], grad_fn=<SelectBackward>)
# tensor([-0.1865, -1.7710], grad_fn=<SelectBackward>)
# tensor([-3.4259, -0.0331], grad_fn=<SelectBackward>)
# tensor([-3.4821, -0.0312], grad_fn=<SelectBackward>)
# tensor([-3.5824, -0.0282], grad_fn=<SelectBackward>)
# tensor([-2.9431, -0.0541], grad_fn=<SelectBackward>)
# tensor([-3.6476, -0.0264], grad_fn=<SelectBackward>)
# tensor([-0.0319, -3.4600], grad_fn=<SelectBackward>)
# tensor([-2.8821, -0.0576], grad_fn=<SelectBackward>)
# tensor([-0.1306, -2.1004], grad_fn=<SelectBackward>)
# tensor([-0.0687, -2.7117], grad_fn=<SelectBackward>)
# tensor([-0.3997, -1.1102], grad_fn=<SelectBackward>)
# tensor([-0.1242, -2.1473], grad_fn=<SelectBackward>)
# tensor([-2.4695, -0.0884], grad_fn=<SelectBackward>)
# tensor([-1.0651, -0.4226], grad_fn=<SelectBackward>)
# tensor([-3.4305, -0.0329], grad_fn=<SelectBackward>)
# tensor([-0.2624, -1.4663], grad_fn=<SelectBackward>)
# tensor([-0.4668, -0.9862], grad_fn=<SelectBackward>)
# tensor([-0.0533, -2.9584], grad_fn=<SelectBackward>)
# tensor([-2.0449, -0.1386], grad_fn=<SelectBackward>)
# tensor([-0.3338, -1.2594], grad_fn=<SelectBackward>)
# tensor([-3.2204, -0.0408], grad_fn=<SelectBackward>)
# tensor([-3.4183, -0.0333], grad_fn=<SelectBackward>)
# tensor([-0.0857, -2.4995], grad_fn=<SelectBackward>)
# tensor([-0.3710, -1.1714], grad_fn=<SelectBackward>)
# tensor([-0.0439, -3.1472], grad_fn=<SelectBackward>)
# tensor([-0.1210, -2.1718], grad_fn=<SelectBackward>)
# tensor([-0.1018, -2.3350], grad_fn=<SelectBackward>)
# tensor([-0.1246, -2.1445], grad_fn=<SelectBackward>)
# tensor([-2.4738, -0.0880], grad_fn=<SelectBackward>)
# tensor([-3.4033, -0.0338], grad_fn=<SelectBackward>)
# tensor([-0.1138, -2.2296], grad_fn=<SelectBackward>)
# tensor([-1.3938, -0.2852], grad_fn=<SelectBackward>)
# tensor([-0.1438, -2.0102], grad_fn=<SelectBackward>)
# tensor([-3.4954, -0.0308], grad_fn=<SelectBackward>)
# tensor([-3.4385, -0.0326], grad_fn=<SelectBackward>)
# tensor([-0.1450, -2.0025], grad_fn=<SelectBackward>)
# tensor([-2.6430, -0.0738], grad_fn=<SelectBackward>)
# tensor([-3.4848, -0.0311], grad_fn=<SelectBackward>)
# tensor([-0.6684, -0.7185], grad_fn=<SelectBackward>)
# tensor([-2.1406, -0.1251], grad_fn=<SelectBackward>)
# tensor([-0.0654, -2.7593], grad_fn=<SelectBackward>)
# tensor([-1.5280, -0.2446], grad_fn=<SelectBackward>)
# tensor([-2.7561, -0.0657], grad_fn=<SelectBackward>)
# tensor([-2.6448, -0.0737], grad_fn=<SelectBackward>)
# tensor([-3.2810, -0.0383], grad_fn=<SelectBackward>)
# tensor([-0.1343, -2.0743], grad_fn=<SelectBackward>)
# tensor([-3.3885, -0.0343], grad_fn=<SelectBackward>)
# tensor([-3.2499, -0.0395], grad_fn=<SelectBackward>)
# tensor([-0.1761, -1.8235], grad_fn=<SelectBackward>)
# tensor([-0.0747, -2.6309], grad_fn=<SelectBackward>)
# tensor([-0.0524, -2.9758], grad_fn=<SelectBackward>)
# tensor([-0.0574, -2.8868], grad_fn=<SelectBackward>)
# tensor([-1.2827, -0.3247], grad_fn=<SelectBackward>)
# tensor([-0.0527, -2.9698], grad_fn=<SelectBackward>)
# tensor([-3.5595, -0.0289], grad_fn=<SelectBackward>)
# tensor([-0.0697, -2.6988], grad_fn=<SelectBackward>)
# tensor([-3.6474, -0.0264], grad_fn=<SelectBackward>)
# tensor([-0.0325, -3.4422], grad_fn=<SelectBackward>)
# tensor([-0.1295, -2.1080], grad_fn=<SelectBackward>)
# tensor([-2.4628, -0.0890], grad_fn=<SelectBackward>)
# tensor([-2.6435, -0.0738], grad_fn=<SelectBackward>)
# tensor([-3.3491, -0.0357], grad_fn=<SelectBackward>)
# tensor([-3.1559, -0.0435], grad_fn=<SelectBackward>)
# tensor([-0.0336, -3.4105], grad_fn=<SelectBackward>)
# tensor([-0.3256, -1.2806], grad_fn=<SelectBackward>)
# tensor([-0.1186, -2.1906], grad_fn=<SelectBackward>)
# tensor([-3.0006, -0.0510], grad_fn=<SelectBackward>)
# tensor([-2.5792, -0.0789], grad_fn=<SelectBackward>)
# tensor([-3.3874, -0.0344], grad_fn=<SelectBackward>)
# tensor([-0.0323, -3.4486], grad_fn=<SelectBackward>)
# tensor([-2.9727, -0.0525], grad_fn=<SelectBackward>)
# tensor([-0.0845, -2.5125], grad_fn=<SelectBackward>)
# tensor([-0.3219, -1.2902], grad_fn=<SelectBackward>)
# tensor([-0.0421, -3.1891], grad_fn=<SelectBackward>)
# tensor([-0.0706, -2.6855], grad_fn=<SelectBackward>)
# tensor([-3.1199, -0.0452], grad_fn=<SelectBackward>)
# tensor([-2.5447, -0.0817], grad_fn=<SelectBackward>)
# tensor([-3.6105, -0.0274], grad_fn=<SelectBackward>)
# tensor([-0.1511, -1.9642], grad_fn=<SelectBackward>)
# tensor([-3.5930, -0.0279], grad_fn=<SelectBackward>)
# tensor([-0.0852, -2.5046], grad_fn=<SelectBackward>)
# tensor([-0.1370, -2.0553], grad_fn=<SelectBackward>)
# tensor([-3.3537, -0.0356], grad_fn=<SelectBackward>)
# tensor([-1.2282, -0.3465], grad_fn=<SelectBackward>)
# tensor([-0.1628, -1.8958], grad_fn=<SelectBackward>)
# tensor([-0.0464, -3.0943], grad_fn=<SelectBackward>)
# tensor([-3.3740, -0.0349], grad_fn=<SelectBackward>)
# tensor([-0.0306, -3.5027], grad_fn=<SelectBackward>)
# tensor([-2.3806, -0.0971], grad_fn=<SelectBackward>)
# tensor([-0.0652, -2.7630], grad_fn=<SelectBackward>)
# tensor([-0.1583, -1.9215], grad_fn=<SelectBackward>)
# tensor([-0.2540, -1.4948], grad_fn=<SelectBackward>)
# tensor([-0.0421, -3.1879], grad_fn=<SelectBackward>)
# tensor([-0.0622, -2.8080], grad_fn=<SelectBackward>)
# tensor([-0.0411, -3.2116], grad_fn=<SelectBackward>)
# tensor([-3.5529, -0.0291], grad_fn=<SelectBackward>)
# tensor([-0.5631, -0.8426], grad_fn=<SelectBackward>)
# tensor([-2.4026, -0.0948], grad_fn=<SelectBackward>)
# tensor([-0.0486, -3.0481], grad_fn=<SelectBackward>)
# tensor([-1.6525, -0.2127], grad_fn=<SelectBackward>)
# tensor([-3.4215, -0.0332], grad_fn=<SelectBackward>)
# tensor([-1.1378, -0.3864], grad_fn=<SelectBackward>)
# tensor([-0.0964, -2.3869], grad_fn=<SelectBackward>)
# tensor([-2.4382, -0.0914], grad_fn=<SelectBackward>)
# tensor([-3.3292, -0.0365], grad_fn=<SelectBackward>)
# tensor([-2.4864, -0.0869], grad_fn=<SelectBackward>)
# tensor([-0.0529, -2.9661], grad_fn=<SelectBackward>)
# tensor([-0.2747, -1.4263], grad_fn=<SelectBackward>)
# tensor([-2.4112, -0.0940], grad_fn=<SelectBackward>)
# tensor([-0.0464, -3.0929], grad_fn=<SelectBackward>)
# tensor([-2.9874, -0.0517], grad_fn=<SelectBackward>)
# tensor([-0.0573, -2.8881], grad_fn=<SelectBackward>)
# tensor([-2.1051, -0.1299], grad_fn=<SelectBackward>)
# tensor([-1.8536, -0.1704], grad_fn=<SelectBackward>)
# tensor([-2.8146, -0.0618], grad_fn=<SelectBackward>)
# tensor([-3.0772, -0.0472], grad_fn=<SelectBackward>)
# tensor([-2.2854, -0.1073], grad_fn=<SelectBackward>)
# tensor([-3.4226, -0.0332], grad_fn=<SelectBackward>)
# tensor([-2.7596, -0.0654], grad_fn=<SelectBackward>)
# tensor([-0.0289, -3.5591], grad_fn=<SelectBackward>)
# tensor([-2.8672, -0.0585], grad_fn=<SelectBackward>)
# tensor([-1.7645, -0.1879], grad_fn=<SelectBackward>)
# tensor([-2.9852, -0.0518], grad_fn=<SelectBackward>)
# tensor([-2.8999, -0.0566], grad_fn=<SelectBackward>)
# tensor([-0.4505, -1.0141], grad_fn=<SelectBackward>)
# tensor([-0.1413, -2.0269], grad_fn=<SelectBackward>)
# tensor([-3.3518, -0.0356], grad_fn=<SelectBackward>)
# tensor([-0.0501, -3.0196], grad_fn=<SelectBackward>)
# tensor([-3.2954, -0.0378], grad_fn=<SelectBackward>)
# tensor([-3.2174, -0.0409], grad_fn=<SelectBackward>)
# tensor([-0.0448, -3.1283], grad_fn=<SelectBackward>)
# tensor([-0.1589, -1.9179], grad_fn=<SelectBackward>)
# tensor([-3.0433, -0.0489], grad_fn=<SelectBackward>)
# tensor([-2.4256, -0.0926], grad_fn=<SelectBackward>)
# tensor([-0.0757, -2.6190], grad_fn=<SelectBackward>)
# tensor([-2.4621, -0.0891], grad_fn=<SelectBackward>)
# tensor([-3.6633, -0.0260], grad_fn=<SelectBackward>)
# tensor([-3.2710, -0.0387], grad_fn=<SelectBackward>)
# tensor([-2.5759, -0.0791], grad_fn=<SelectBackward>)
# tensor([-0.1267, -2.1289], grad_fn=<SelectBackward>)
# tensor([-0.1825, -1.7908], grad_fn=<SelectBackward>)
# tensor([-1.0349, -0.4389], grad_fn=<SelectBackward>)
# tensor([-2.9116, -0.0559], grad_fn=<SelectBackward>)
# tensor([-0.0940, -2.4111], grad_fn=<SelectBackward>)
# tensor([-2.2665, -0.1095], grad_fn=<SelectBackward>)
# tensor([-0.5690, -0.8349], grad_fn=<SelectBackward>)
# tensor([-1.9276, -0.1572], grad_fn=<SelectBackward>)
# tensor([-3.4418, -0.0325], grad_fn=<SelectBackward>)
# tensor([-2.5154, -0.0843], grad_fn=<SelectBackward>)
# tensor([-0.0916, -2.4353], grad_fn=<SelectBackward>)
# tensor([-0.0643, -2.7760], grad_fn=<SelectBackward>)
# tensor([-0.2451, -1.5261], grad_fn=<SelectBackward>)
# tensor([-2.5122, -0.0846], grad_fn=<SelectBackward>)
# tensor([-0.0382, -3.2835], grad_fn=<SelectBackward>)
# tensor([-0.0677, -2.7261], grad_fn=<SelectBackward>)
# tensor([-0.7246, -0.6626], grad_fn=<SelectBackward>)
# tensor([-3.4882, -0.0310], grad_fn=<SelectBackward>)
# tensor([-3.7285, -0.0243], grad_fn=<SelectBackward>)
# tensor([-3.0914, -0.0465], grad_fn=<SelectBackward>)
# tensor([-0.6326, -0.7575], grad_fn=<SelectBackward>)
# tensor([-3.4312, -0.0329], grad_fn=<SelectBackward>)
# tensor([-3.5630, -0.0288], grad_fn=<SelectBackward>)
# tensor([-2.6817, -0.0709], grad_fn=<SelectBackward>)
# tensor([-3.1537, -0.0436], grad_fn=<SelectBackward>)
# tensor([-1.9386, -0.1554], grad_fn=<SelectBackward>)
# tensor([-1.9344, -0.1561], grad_fn=<SelectBackward>)
# tensor([-1.9880, -0.1473], grad_fn=<SelectBackward>)
# tensor([-0.2343, -1.5662], grad_fn=<SelectBackward>)
# tensor([-0.0398, -3.2431], grad_fn=<SelectBackward>)
# tensor([-0.0913, -2.4387], grad_fn=<SelectBackward>)
# tensor([-3.0350, -0.0493], grad_fn=<SelectBackward>)
# tensor([-0.7941, -0.6015], grad_fn=<SelectBackward>)
# tensor([-1.6848, -0.2052], grad_fn=<SelectBackward>)
# tensor([-0.5398, -0.8743], grad_fn=<SelectBackward>)
# tensor([-2.5310, -0.0829], grad_fn=<SelectBackward>)
# tensor([-2.9999, -0.0511], grad_fn=<SelectBackward>)
# tensor([-0.4779, -0.9677], grad_fn=<SelectBackward>)
# tensor([-1.3622, -0.2958], grad_fn=<SelectBackward>)
# tensor([-0.1167, -2.2060], grad_fn=<SelectBackward>)
# tensor([-2.3981, -0.0953], grad_fn=<SelectBackward>)
# tensor([-1.6149, -0.2218], grad_fn=<SelectBackward>)
# tensor([-0.0422, -3.1864], grad_fn=<SelectBackward>)
# tensor([-0.0453, -3.1169], grad_fn=<SelectBackward>)
# tensor([-1.0300, -0.4416], grad_fn=<SelectBackward>)
# tensor([-0.1243, -2.1466], grad_fn=<SelectBackward>)
# tensor([-0.0519, -2.9834], grad_fn=<SelectBackward>)
# tensor([-3.3462, -0.0359], grad_fn=<SelectBackward>)
# tensor([-0.0334, -3.4163], grad_fn=<SelectBackward>)
# tensor([-0.2460, -1.5229], grad_fn=<SelectBackward>)
# tensor([-3.4605, -0.0319], grad_fn=<SelectBackward>)
# tensor([-0.0813, -2.5505], grad_fn=<SelectBackward>)
# tensor([-0.2967, -1.3597], grad_fn=<SelectBackward>)
# tensor([-0.5246, -0.8959], grad_fn=<SelectBackward>)
# tensor([-1.9137, -0.1596], grad_fn=<SelectBackward>)
# tensor([-3.4964, -0.0308], grad_fn=<SelectBackward>)
# tensor([-3.0291, -0.0496], grad_fn=<SelectBackward>)
# tensor([-3.4576, -0.0320], grad_fn=<SelectBackward>)
# tensor([-0.0970, -2.3808], grad_fn=<SelectBackward>)
# tensor([-3.3916, -0.0342], grad_fn=<SelectBackward>)
# tensor([-2.4084, -0.0943], grad_fn=<SelectBackward>)
# tensor([-0.0851, -2.5062], grad_fn=<SelectBackward>)
# tensor([-3.3302, -0.0364], grad_fn=<SelectBackward>)
# tensor([-2.2751, -0.1085], grad_fn=<SelectBackward>)
# tensor([-2.6568, -0.0728], grad_fn=<SelectBackward>)
# tensor([-3.1239, -0.0450], grad_fn=<SelectBackward>)
# tensor([-2.2284, -0.1140], grad_fn=<SelectBackward>)
# tensor([-0.0442, -3.1401], grad_fn=<SelectBackward>)
# tensor([-0.0554, -2.9203], grad_fn=<SelectBackward>)
# tensor([-0.0399, -3.2416], grad_fn=<SelectBackward>)
# tensor([-0.0422, -3.1863], grad_fn=<SelectBackward>)
# tensor([-1.4318, -0.2730], grad_fn=<SelectBackward>)
# tensor([-2.3588, -0.0993], grad_fn=<SelectBackward>)
# tensor([-2.4921, -0.0864], grad_fn=<SelectBackward>)
# tensor([-0.0342, -3.3917], grad_fn=<SelectBackward>)
# tensor([-3.3008, -0.0375], grad_fn=<SelectBackward>)
# tensor([-2.7680, -0.0648], grad_fn=<SelectBackward>)
# tensor([-1.2521, -0.3367], grad_fn=<SelectBackward>)
# tensor([-0.7262, -0.6611], grad_fn=<SelectBackward>)
# tensor([-1.3754, -0.2913], grad_fn=<SelectBackward>)
# tensor([-2.1005, -0.1306], grad_fn=<SelectBackward>)
# tensor([-0.0868, -2.4872], grad_fn=<SelectBackward>)
# tensor([-0.0600, -2.8429], grad_fn=<SelectBackward>)
# tensor([-1.4343, -0.2722], grad_fn=<SelectBackward>)
# tensor([-1.6899, -0.2040], grad_fn=<SelectBackward>)
# tensor([-3.2747, -0.0386], grad_fn=<SelectBackward>)
# tensor([-0.2152, -1.6417], grad_fn=<SelectBackward>)
# tensor([-3.1282, -0.0448], grad_fn=<SelectBackward>)
# tensor([-2.5611, -0.0804], grad_fn=<SelectBackward>)
# tensor([-3.5602, -0.0288], grad_fn=<SelectBackward>)
# tensor([-0.2066, -1.6786], grad_fn=<SelectBackward>)
# tensor([-0.0387, -3.2716], grad_fn=<SelectBackward>)
# tensor([-0.1832, -1.7872], grad_fn=<SelectBackward>)
# tensor([-0.8418, -0.5638], grad_fn=<SelectBackward>)
# tensor([-0.0983, -2.3685], grad_fn=<SelectBackward>)
# tensor([-0.0687, -2.7116], grad_fn=<SelectBackward>)
# tensor([-0.1521, -1.9583], grad_fn=<SelectBackward>)
# tensor([-1.0046, -0.4560], grad_fn=<SelectBackward>)
# tensor([-3.3178, -0.0369], grad_fn=<SelectBackward>)
# tensor([-2.6042, -0.0768], grad_fn=<SelectBackward>)
# tensor([-3.6088, -0.0275], grad_fn=<SelectBackward>)
# tensor([-0.5846, -0.8149], grad_fn=<SelectBackward>)
# tensor([-0.2224, -1.6124], grad_fn=<SelectBackward>)
# tensor([-3.3871, -0.0344], grad_fn=<SelectBackward>)
# tensor([-0.0701, -2.6932], grad_fn=<SelectBackward>)
# tensor([-2.7309, -0.0674], grad_fn=<SelectBackward>)
# tensor([-0.0555, -2.9189], grad_fn=<SelectBackward>)
# tensor([-3.5748, -0.0284], grad_fn=<SelectBackward>)
# tensor([-1.4340, -0.2723], grad_fn=<SelectBackward>)
# tensor([-0.0749, -2.6288], grad_fn=<SelectBackward>)
# tensor([-0.0373, -3.3082], grad_fn=<SelectBackward>)
# tensor([-0.4209, -1.0685], grad_fn=<SelectBackward>)
# tensor([-1.8887, -0.1640], grad_fn=<SelectBackward>)
# tensor([-0.0449, -3.1249], grad_fn=<SelectBackward>)
# tensor([-0.0445, -3.1354], grad_fn=<SelectBackward>)
# tensor([-0.1056, -2.3000], grad_fn=<SelectBackward>)
# tensor([-2.8935, -0.0570], grad_fn=<SelectBackward>)
# tensor([-2.9944, -0.0514], grad_fn=<SelectBackward>)
# tensor([-0.0625, -2.8036], grad_fn=<SelectBackward>)
# tensor([-3.1570, -0.0435], grad_fn=<SelectBackward>)
# tensor([-3.4431, -0.0325], grad_fn=<SelectBackward>)
# tensor([-3.1428, -0.0441], grad_fn=<SelectBackward>)
# tensor([-3.4745, -0.0315], grad_fn=<SelectBackward>)
# tensor([-3.3752, -0.0348], grad_fn=<SelectBackward>)
# tensor([-0.0412, -3.2095], grad_fn=<SelectBackward>)
# tensor([-0.1672, -1.8712], grad_fn=<SelectBackward>)
# tensor([-2.4974, -0.0859], grad_fn=<SelectBackward>)
# tensor([-3.3254, -0.0366], grad_fn=<SelectBackward>)
# tensor([-1.5878, -0.2286], grad_fn=<SelectBackward>)
# tensor([-1.2970, -0.3193], grad_fn=<SelectBackward>)
# tensor([-0.4488, -1.0172], grad_fn=<SelectBackward>)
# tensor([-0.4290, -1.0532], grad_fn=<SelectBackward>)
# tensor([-0.0274, -3.6107], grad_fn=<SelectBackward>)
# tensor([-3.1214, -0.0451], grad_fn=<SelectBackward>)
# tensor([-0.0381, -3.2869], grad_fn=<SelectBackward>)
# tensor([-3.2439, -0.0398], grad_fn=<SelectBackward>)
# tensor([-1.7741, -0.1859], grad_fn=<SelectBackward>)
# tensor([-0.0257, -3.6752], grad_fn=<SelectBackward>)
# tensor([-0.0616, -2.8171], grad_fn=<SelectBackward>)
# tensor([-0.0254, -3.6847], grad_fn=<SelectBackward>)
# tensor([-3.1867, -0.0422], grad_fn=<SelectBackward>)
# tensor([-0.7537, -0.6360], grad_fn=<SelectBackward>)
# tensor([-0.9784, -0.4714], grad_fn=<SelectBackward>)
# tensor([-1.0502, -0.4306], grad_fn=<SelectBackward>)
# tensor([-3.3332, -0.0363], grad_fn=<SelectBackward>)
# tensor([-0.2392, -1.5476], grad_fn=<SelectBackward>)
# tensor([-2.1346, -0.1259], grad_fn=<SelectBackward>)
# tensor([-2.4687, -0.0885], grad_fn=<SelectBackward>)
# tensor([-0.1786, -1.8107], grad_fn=<SelectBackward>)
# tensor([-0.2210, -1.6179], grad_fn=<SelectBackward>)
# tensor([-3.5170, -0.0301], grad_fn=<SelectBackward>)
# tensor([-0.2235, -1.6080], grad_fn=<SelectBackward>)
# tensor([-2.8868, -0.0574], grad_fn=<SelectBackward>)
# tensor([-0.2507, -1.5061], grad_fn=<SelectBackward>)
# tensor([-3.2680, -0.0388], grad_fn=<SelectBackward>)
# tensor([-0.0663, -2.7472], grad_fn=<SelectBackward>)
# tensor([-0.1392, -2.0408], grad_fn=<SelectBackward>)
# tensor([-0.0285, -3.5737], grad_fn=<SelectBackward>)
# tensor([-2.7613, -0.0653], grad_fn=<SelectBackward>)
# tensor([-2.7454, -0.0664], grad_fn=<SelectBackward>)
# tensor([-0.0324, -3.4465], grad_fn=<SelectBackward>)
# tensor([-2.6202, -0.0756], grad_fn=<SelectBackward>)
# tensor([-0.0570, -2.8930], grad_fn=<SelectBackward>)
# tensor([-2.9778, -0.0522], grad_fn=<SelectBackward>)
# tensor([-0.5837, -0.8160], grad_fn=<SelectBackward>)
# tensor([-3.8122, -0.0223], grad_fn=<SelectBackward>)
# tensor([-2.5808, -0.0787], grad_fn=<SelectBackward>)
# tensor([-3.0903, -0.0466], grad_fn=<SelectBackward>)
# tensor([-2.0225, -0.1419], grad_fn=<SelectBackward>)
# tensor([-0.1331, -2.0825], grad_fn=<SelectBackward>)
# tensor([-3.0748, -0.0473], grad_fn=<SelectBackward>)
# tensor([-2.0966, -0.1311], grad_fn=<SelectBackward>)
# tensor([-1.0014, -0.4579], grad_fn=<SelectBackward>)
# tensor([-3.1241, -0.0450], grad_fn=<SelectBackward>)
# tensor([-2.7784, -0.0642], grad_fn=<SelectBackward>)
# tensor([-0.0440, -3.1462], grad_fn=<SelectBackward>)
# tensor([-0.0416, -3.2011], grad_fn=<SelectBackward>)
# tensor([-0.0307, -3.4979], grad_fn=<SelectBackward>)
# tensor([-3.2430, -0.0398], grad_fn=<SelectBackward>)
# tensor([-0.0529, -2.9660], grad_fn=<SelectBackward>)
# tensor([-0.0988, -2.3634], grad_fn=<SelectBackward>)
# tensor([-2.1985, -0.1176], grad_fn=<SelectBackward>)
# tensor([-3.2902, -0.0380], grad_fn=<SelectBackward>)
# tensor([-3.0208, -0.0500], grad_fn=<SelectBackward>)
# tensor([-0.0890, -2.4631], grad_fn=<SelectBackward>)
# tensor([-1.9471, -0.1540], grad_fn=<SelectBackward>)
# tensor([-2.4981, -0.0858], grad_fn=<SelectBackward>)
# tensor([-0.1293, -2.1094], grad_fn=<SelectBackward>)
# tensor([-0.0349, -3.3737], grad_fn=<SelectBackward>)
# tensor([-0.3385, -1.2478], grad_fn=<SelectBackward>)
# tensor([-0.0859, -2.4972], grad_fn=<SelectBackward>)
# tensor([-0.0923, -2.4285], grad_fn=<SelectBackward>)
# tensor([-1.0539, -0.4286], grad_fn=<SelectBackward>)
# tensor([-3.5935, -0.0279], grad_fn=<SelectBackward>)
# tensor([-0.0615, -2.8200], grad_fn=<SelectBackward>)
# tensor([-3.5227, -0.0300], grad_fn=<SelectBackward>)
# tensor([-3.2860, -0.0381], grad_fn=<SelectBackward>)
# tensor([-0.0354, -3.3584], grad_fn=<SelectBackward>)
# tensor([-2.3609, -0.0991], grad_fn=<SelectBackward>)
# tensor([-0.1329, -2.0837], grad_fn=<SelectBackward>)
# tensor([-2.2347, -0.1132], grad_fn=<SelectBackward>)
# tensor([-1.6626, -0.2103], grad_fn=<SelectBackward>)
# tensor([-2.9949, -0.0513], grad_fn=<SelectBackward>)
# tensor([-0.0909, -2.4431], grad_fn=<SelectBackward>)
# tensor([-0.4391, -1.0346], grad_fn=<SelectBackward>)
# tensor([-0.0367, -3.3236], grad_fn=<SelectBackward>)
# tensor([-0.0786, -2.5824], grad_fn=<SelectBackward>)
# tensor([-3.1015, -0.0460], grad_fn=<SelectBackward>)
# tensor([-0.0261, -3.6574], grad_fn=<SelectBackward>)
# tensor([-0.0287, -3.5659], grad_fn=<SelectBackward>)
# tensor([-3.0890, -0.0466], grad_fn=<SelectBackward>)
# tensor([-0.0415, -3.2025], grad_fn=<SelectBackward>)
# tensor([-0.1758, -1.8249], grad_fn=<SelectBackward>)
# tensor([-2.5749, -0.0792], grad_fn=<SelectBackward>)
# tensor([-0.6654, -0.7217], grad_fn=<SelectBackward>)
# tensor([-3.6576, -0.0261], grad_fn=<SelectBackward>)
# tensor([-3.5023, -0.0306], grad_fn=<SelectBackward>)
# tensor([-0.0553, -2.9232], grad_fn=<SelectBackward>)
# tensor([-2.8084, -0.0622], grad_fn=<SelectBackward>)
# tensor([-0.0538, -2.9493], grad_fn=<SelectBackward>)
# tensor([-1.8902, -0.1637], grad_fn=<SelectBackward>)
# tensor([-3.1780, -0.0426], grad_fn=<SelectBackward>)
# tensor([-0.1278, -2.1207], grad_fn=<SelectBackward>)
# tensor([-2.2931, -0.1064], grad_fn=<SelectBackward>)
# tensor([-2.8484, -0.0597], grad_fn=<SelectBackward>)
# tensor([-0.0348, -3.3746], grad_fn=<SelectBackward>)
# tensor([-0.0500, -3.0200], grad_fn=<SelectBackward>)
# tensor([-0.0742, -2.6380], grad_fn=<SelectBackward>)
# tensor([-0.1361, -2.0617], grad_fn=<SelectBackward>)
# tensor([-0.2454, -1.5251], grad_fn=<SelectBackward>)
# tensor([-3.7009, -0.0250], grad_fn=<SelectBackward>)
# tensor([-2.4448, -0.0907], grad_fn=<SelectBackward>)
# tensor([-3.2551, -0.0393], grad_fn=<SelectBackward>)
# tensor([-0.0449, -3.1265], grad_fn=<SelectBackward>)
# tensor([-3.0040, -0.0509], grad_fn=<SelectBackward>)
# tensor([-0.0718, -2.6693], grad_fn=<SelectBackward>)
# tensor([-0.0805, -2.5596], grad_fn=<SelectBackward>)
# tensor([-3.6042, -0.0276], grad_fn=<SelectBackward>)
# tensor([-0.3208, -1.2930], grad_fn=<SelectBackward>)
# tensor([-2.4179, -0.0933], grad_fn=<SelectBackward>)
# tensor([-3.2918, -0.0379], grad_fn=<SelectBackward>)
# tensor([-3.0674, -0.0477], grad_fn=<SelectBackward>)
# tensor([-2.5447, -0.0817], grad_fn=<SelectBackward>)
# tensor([-0.9556, -0.4855], grad_fn=<SelectBackward>)
# tensor([-0.1796, -1.8055], grad_fn=<SelectBackward>)
# tensor([-0.3032, -1.3412], grad_fn=<SelectBackward>)
# tensor([-0.0629, -2.7971], grad_fn=<SelectBackward>)
# tensor([-0.1984, -1.7152], grad_fn=<SelectBackward>)
# tensor([-3.6212, -0.0271], grad_fn=<SelectBackward>)
# tensor([-0.0454, -3.1147], grad_fn=<SelectBackward>)
# tensor([-0.9413, -0.4945], grad_fn=<SelectBackward>)
# tensor([-1.6488, -0.2135], grad_fn=<SelectBackward>)
# tensor([-3.2987, -0.0376], grad_fn=<SelectBackward>)
# tensor([-0.5061, -0.9235], grad_fn=<SelectBackward>)
# tensor([-0.0976, -2.3753], grad_fn=<SelectBackward>)
# tensor([-1.9280, -0.1572], grad_fn=<SelectBackward>)
# tensor([-0.0276, -3.6053], grad_fn=<SelectBackward>)
# tensor([-0.4656, -0.9882], grad_fn=<SelectBackward>)
# tensor([-1.2534, -0.3362], grad_fn=<SelectBackward>)
# tensor([-0.0434, -3.1593], grad_fn=<SelectBackward>)
# tensor([-0.2991, -1.3529], grad_fn=<SelectBackward>)
# tensor([-0.0393, -3.2569], grad_fn=<SelectBackward>)
# tensor([-0.0584, -2.8693], grad_fn=<SelectBackward>)
# tensor([-2.6980, -0.0697], grad_fn=<SelectBackward>)
# tensor([-0.2719, -1.4351], grad_fn=<SelectBackward>)
# tensor([-0.0682, -2.7193], grad_fn=<SelectBackward>)
# tensor([-0.0749, -2.6294], grad_fn=<SelectBackward>)
# tensor([-0.0804, -2.5604], grad_fn=<SelectBackward>)
# tensor([-0.0562, -2.9070], grad_fn=<SelectBackward>)
# tensor([-2.4582, -0.0895], grad_fn=<SelectBackward>)
# tensor([-0.0274, -3.6126], grad_fn=<SelectBackward>)
# tensor([-0.0385, -3.2760], grad_fn=<SelectBackward>)
# tensor([-2.9855, -0.0518], grad_fn=<SelectBackward>)
# tensor([-0.0468, -3.0843], grad_fn=<SelectBackward>)
# tensor([-3.0335, -0.0493], grad_fn=<SelectBackward>)
# tensor([-2.2708, -0.1090], grad_fn=<SelectBackward>)
# tensor([-2.6813, -0.0709], grad_fn=<SelectBackward>)
# tensor([-1.1828, -0.3659], grad_fn=<SelectBackward>)
# tensor([-0.0347, -3.3793], grad_fn=<SelectBackward>)
# tensor([-3.0506, -0.0485], grad_fn=<SelectBackward>)
# tensor([-2.7402, -0.0667], grad_fn=<SelectBackward>)
# tensor([-2.6537, -0.0730], grad_fn=<SelectBackward>)
# tensor([-0.0946, -2.4050], grad_fn=<SelectBackward>)
# tensor([-2.9564, -0.0534], grad_fn=<SelectBackward>)
# tensor([-0.1942, -1.7343], grad_fn=<SelectBackward>)
# tensor([-0.1282, -2.1173], grad_fn=<SelectBackward>)
# tensor([-1.8918, -0.1635], grad_fn=<SelectBackward>)
# tensor([-0.2597, -1.4754], grad_fn=<SelectBackward>)
# tensor([-0.1468, -1.9913], grad_fn=<SelectBackward>)
# tensor([-0.0241, -3.7370], grad_fn=<SelectBackward>)
# tensor([-0.2060, -1.6813], grad_fn=<SelectBackward>)
# tensor([-3.0609, -0.0480], grad_fn=<SelectBackward>)
# tensor([-1.2107, -0.3538], grad_fn=<SelectBackward>)
# tensor([-0.0497, -3.0271], grad_fn=<SelectBackward>)
# tensor([-0.0359, -3.3445], grad_fn=<SelectBackward>)
# tensor([-0.1299, -2.1050], grad_fn=<SelectBackward>)
# tensor([-0.1768, -1.8200], grad_fn=<SelectBackward>)
# tensor([-0.0440, -3.1446], grad_fn=<SelectBackward>)
# tensor([-0.8863, -0.5313], grad_fn=<SelectBackward>)
# tensor([-2.8302, -0.0608], grad_fn=<SelectBackward>)
# tensor([-2.4591, -0.0894], grad_fn=<SelectBackward>)
# tensor([-0.0509, -3.0036], grad_fn=<SelectBackward>)
# tensor([-2.9729, -0.0525], grad_fn=<SelectBackward>)
# tensor([-3.2156, -0.0410], grad_fn=<SelectBackward>)
# tensor([-0.0775, -2.5965], grad_fn=<SelectBackward>)
# tensor([-0.1830, -1.7885], grad_fn=<SelectBackward>)
# tensor([-0.0356, -3.3541], grad_fn=<SelectBackward>)
# tensor([-0.0428, -3.1726], grad_fn=<SelectBackward>)
# tensor([-0.7866, -0.6077], grad_fn=<SelectBackward>)
# tensor([-2.0390, -0.1394], grad_fn=<SelectBackward>)
# tensor([-0.0738, -2.6427], grad_fn=<SelectBackward>)
# tensor([-3.2781, -0.0384], grad_fn=<SelectBackward>)
# tensor([-0.0764, -2.6101], grad_fn=<SelectBackward>)
# tensor([-0.0335, -3.4141], grad_fn=<SelectBackward>)
# tensor([-3.1764, -0.0426], grad_fn=<SelectBackward>)
# tensor([-0.1261, -2.1334], grad_fn=<SelectBackward>)
# tensor([-0.1655, -1.8801], grad_fn=<SelectBackward>)
# tensor([-2.0867, -0.1325], grad_fn=<SelectBackward>)
# tensor([-2.4420, -0.0910], grad_fn=<SelectBackward>)
# tensor([-2.5784, -0.0789], grad_fn=<SelectBackward>)
# tensor([-2.2380, -0.1128], grad_fn=<SelectBackward>)
# tensor([-0.0372, -3.3104], grad_fn=<SelectBackward>)
# tensor([-0.2156, -1.6403], grad_fn=<SelectBackward>)
# tensor([-3.3907, -0.0343], grad_fn=<SelectBackward>)
# tensor([-0.0487, -3.0473], grad_fn=<SelectBackward>)
# tensor([-3.7657, -0.0234], grad_fn=<SelectBackward>)
# tensor([-0.1175, -2.1994], grad_fn=<SelectBackward>)
# tensor([-0.2675, -1.4496], grad_fn=<SelectBackward>)
# tensor([-0.1745, -1.8319], grad_fn=<SelectBackward>)
# tensor([-3.1073, -0.0458], grad_fn=<SelectBackward>)
# tensor([-2.1047, -0.1300], grad_fn=<SelectBackward>)
# tensor([-0.0288, -3.5633], grad_fn=<SelectBackward>)
# tensor([-0.2500, -1.5088], grad_fn=<SelectBackward>)
# tensor([-3.4894, -0.0310], grad_fn=<SelectBackward>)
# tensor([-2.9711, -0.0526], grad_fn=<SelectBackward>)
# tensor([-0.0388, -3.2674], grad_fn=<SelectBackward>)
# tensor([-2.6608, -0.0725], grad_fn=<SelectBackward>)
# tensor([-3.1432, -0.0441], grad_fn=<SelectBackward>)
# tensor([-0.0442, -3.1411], grad_fn=<SelectBackward>)
# tensor([-0.8958, -0.5247], grad_fn=<SelectBackward>)
# tensor([-0.0589, -2.8617], grad_fn=<SelectBackward>)
# tensor([-0.0350, -3.3692], grad_fn=<SelectBackward>)
# tensor([-0.1101, -2.2610], grad_fn=<SelectBackward>)
# tensor([-0.0488, -3.0442], grad_fn=<SelectBackward>)
# tensor([-2.8616, -0.0589], grad_fn=<SelectBackward>)
# tensor([-0.0289, -3.5574], grad_fn=<SelectBackward>)
# tensor([-0.2476, -1.5173], grad_fn=<SelectBackward>)
# tensor([-0.2194, -1.6245], grad_fn=<SelectBackward>)
# tensor([-2.4405, -0.0911], grad_fn=<SelectBackward>)
# tensor([-0.0299, -3.5232], grad_fn=<SelectBackward>)
# tensor([-0.0377, -3.2961], grad_fn=<SelectBackward>)
# tensor([-3.1572, -0.0435], grad_fn=<SelectBackward>)
# tensor([-3.5196, -0.0301], grad_fn=<SelectBackward>)
# tensor([-3.4090, -0.0336], grad_fn=<SelectBackward>)
# tensor([-0.0358, -3.3484], grad_fn=<SelectBackward>)
# tensor([-0.0654, -2.7595], grad_fn=<SelectBackward>)
# tensor([-3.2888, -0.0380], grad_fn=<SelectBackward>)
# tensor([-0.0386, -3.2747], grad_fn=<SelectBackward>)
# tensor([-3.7590, -0.0236], grad_fn=<SelectBackward>)
# tensor([-0.0565, -2.9016], grad_fn=<SelectBackward>)
# tensor([-0.0407, -3.2207], grad_fn=<SelectBackward>)
# tensor([-3.2220, -0.0407], grad_fn=<SelectBackward>)
# tensor([-3.2804, -0.0383], grad_fn=<SelectBackward>)
# tensor([-0.0497, -3.0262], grad_fn=<SelectBackward>)
# tensor([-2.7145, -0.0685], grad_fn=<SelectBackward>)
# tensor([-3.5208, -0.0300], grad_fn=<SelectBackward>)
# tensor([-0.0625, -2.8038], grad_fn=<SelectBackward>)
# tensor([-0.1115, -2.2494], grad_fn=<SelectBackward>)
# tensor([-0.0434, -3.1596], grad_fn=<SelectBackward>)
# tensor([-0.0939, -2.4120], grad_fn=<SelectBackward>)
# tensor([-2.0551, -0.1371], grad_fn=<SelectBackward>)
# tensor([-0.0542, -2.9412], grad_fn=<SelectBackward>)
# tensor([-0.0388, -3.2678], grad_fn=<SelectBackward>)
# tensor([-0.0461, -3.1008], grad_fn=<SelectBackward>)
# tensor([-3.0778, -0.0472], grad_fn=<SelectBackward>)
# tensor([-0.0526, -2.9718], grad_fn=<SelectBackward>)
# tensor([-2.8538, -0.0594], grad_fn=<SelectBackward>)
# tensor([-3.4758, -0.0314], grad_fn=<SelectBackward>)
# tensor([-1.9991, -0.1456], grad_fn=<SelectBackward>)
# tensor([-3.4997, -0.0307], grad_fn=<SelectBackward>)
# tensor([-2.7219, -0.0680], grad_fn=<SelectBackward>)
# tensor([-1.9239, -0.1579], grad_fn=<SelectBackward>)
# tensor([-1.9460, -0.1541], grad_fn=<SelectBackward>)
# tensor([-3.3971, -0.0340], grad_fn=<SelectBackward>)
# tensor([-3.1945, -0.0419], grad_fn=<SelectBackward>)
# tensor([-0.0450, -3.1244], grad_fn=<SelectBackward>)
# tensor([-0.0297, -3.5298], grad_fn=<SelectBackward>)
# tensor([-0.7361, -0.6520], grad_fn=<SelectBackward>)
# tensor([-0.7165, -0.6703], grad_fn=<SelectBackward>)
# tensor([-0.4460, -1.0221], grad_fn=<SelectBackward>)
# tensor([-0.0373, -3.3076], grad_fn=<SelectBackward>)
# tensor([-3.2028, -0.0415], grad_fn=<SelectBackward>)
# tensor([-0.0354, -3.3576], grad_fn=<SelectBackward>)
# tensor([-3.2828, -0.0382], grad_fn=<SelectBackward>)
# tensor([-0.0756, -2.6194], grad_fn=<SelectBackward>)
# ...
# tensor([-0.0990, -2.3618], grad_fn=<SelectBackward>)
# tensor([-0.6330, -0.7571], grad_fn=<SelectBackward>)
# tensor([-2.9968, -0.0512], grad_fn=<SelectBackward>)
# tensor([-0.2892, -1.3818], grad_fn=<SelectBackward>)
# tensor([-3.5007, -0.0306], grad_fn=<SelectBackward>)
# tensor([-3.1010, -0.0460], grad_fn=<SelectBackward>)
# tensor([-0.2273, -1.5929], grad_fn=<SelectBackward>)
# tensor([-3.2690, -0.0388], grad_fn=<SelectBackward>)
# tensor([-0.0321, -3.4537], grad_fn=<SelectBackward>)
# tensor([-2.3188, -0.1036], grad_fn=<SelectBackward>)
# tensor([-3.7353, -0.0242], grad_fn=<SelectBackward>)
# tensor([-0.2505, -1.5070], grad_fn=<SelectBackward>)
# tensor([-2.3713, -0.0980], grad_fn=<SelectBackward>)
# tensor([-0.0487, -3.0457], grad_fn=<SelectBackward>)
# tensor([-0.0259, -3.6666], grad_fn=<SelectBackward>)
# tensor([-2.4802, -0.0874], grad_fn=<SelectBackward>)
# tensor([-0.0562, -2.9062], grad_fn=<SelectBackward>)
# tensor([-2.4103, -0.0941], grad_fn=<SelectBackward>)
# tensor([-3.3736, -0.0349], grad_fn=<SelectBackward>)
# tensor([-0.0819, -2.5432], grad_fn=<SelectBackward>)
# tensor([-3.2985, -0.0376], grad_fn=<SelectBackward>)
# tensor([-0.0426, -3.1775], grad_fn=<SelectBackward>)
# tensor([-0.0378, -3.2954], grad_fn=<SelectBackward>)
# tensor([-0.0792, -2.5749], grad_fn=<SelectBackward>)
# tensor([-0.0432, -3.1642], grad_fn=<SelectBackward>)
# tensor([-0.2161, -1.6379], grad_fn=<SelectBackward>)
# tensor([-0.0581, -2.8740], grad_fn=<SelectBackward>)
# tensor([-1.5336, -0.2430], grad_fn=<SelectBackward>)
# tensor([-3.3339, -0.0363], grad_fn=<SelectBackward>)
# tensor([-0.7563, -0.6337], grad_fn=<SelectBackward>)
# tensor([-3.1843, -0.0423], grad_fn=<SelectBackward>)
# tensor([-0.1011, -2.3421], grad_fn=<SelectBackward>)
# tensor([-3.4539, -0.0321], grad_fn=<SelectBackward>)
# tensor([-0.0521, -2.9807], grad_fn=<SelectBackward>)
# tensor([-2.7752, -0.0644], grad_fn=<SelectBackward>)
# tensor([-0.2083, -1.6711], grad_fn=<SelectBackward>)
# tensor([-2.5947, -0.0776], grad_fn=<SelectBackward>)
# tensor([-0.1318, -2.0917], grad_fn=<SelectBackward>)
# tensor([-0.1018, -2.3355], grad_fn=<SelectBackward>)
# tensor([-0.0497, -3.0270], grad_fn=<SelectBackward>)
# tensor([-2.4438, -0.0908], grad_fn=<SelectBackward>)
# tensor([-0.4048, -1.0999], grad_fn=<SelectBackward>)
# tensor([-0.1050, -2.3057], grad_fn=<SelectBackward>)
# tensor([-0.0332, -3.4215], grad_fn=<SelectBackward>)
# tensor([-1.1925, -0.3616], grad_fn=<SelectBackward>)
# tensor([-0.8931, -0.5266], grad_fn=<SelectBackward>)
# tensor([-2.5146, -0.0844], grad_fn=<SelectBackward>)
# tensor([-2.6869, -0.0705], grad_fn=<SelectBackward>)
# tensor([-1.8884, -0.1641], grad_fn=<SelectBackward>)
# tensor([-0.0438, -3.1491], grad_fn=<SelectBackward>)
# tensor([-0.1052, -2.3040], grad_fn=<SelectBackward>)
# tensor([-0.2492, -1.5116], grad_fn=<SelectBackward>)
# tensor([-0.0465, -3.0915], grad_fn=<SelectBackward>)
# tensor([-0.0468, -3.0862], grad_fn=<SelectBackward>)
# tensor([-0.0446, -3.1317], grad_fn=<SelectBackward>)
# tensor([-0.0533, -2.9586], grad_fn=<SelectBackward>)
# tensor([-0.0455, -3.1135], grad_fn=<SelectBackward>)
# tensor([-0.0303, -3.5121], grad_fn=<SelectBackward>)
# tensor([-3.0516, -0.0484], grad_fn=<SelectBackward>)
# tensor([-0.0652, -2.7625], grad_fn=<SelectBackward>)
# tensor([-1.2378, -0.3425], grad_fn=<SelectBackward>)
# tensor([-0.6564, -0.7313], grad_fn=<SelectBackward>)
# tensor([-0.3738, -1.1652], grad_fn=<SelectBackward>)
# tensor([-0.0554, -2.9211], grad_fn=<SelectBackward>)
# tensor([-2.0796, -0.1335], grad_fn=<SelectBackward>)
# tensor([-0.1577, -1.9250], grad_fn=<SelectBackward>)
# tensor([-3.3088, -0.0372], grad_fn=<SelectBackward>)
# tensor([-2.2931, -0.1064], grad_fn=<SelectBackward>)
# tensor([-2.0455, -0.1385], grad_fn=<SelectBackward>)
# tensor([-0.0288, -3.5631], grad_fn=<SelectBackward>)
# tensor([-0.0789, -2.5782], grad_fn=<SelectBackward>)
# tensor([-0.0748, -2.6304], grad_fn=<SelectBackward>)
# tensor([-3.4016, -0.0339], grad_fn=<SelectBackward>)
# tensor([-1.3529, -0.2991], grad_fn=<SelectBackward>)
# tensor([-3.1403, -0.0442], grad_fn=<SelectBackward>)
# tensor([-2.7266, -0.0677], grad_fn=<SelectBackward>)
# tensor([-0.0655, -2.7590], grad_fn=<SelectBackward>)
# tensor([-0.1495, -1.9746], grad_fn=<SelectBackward>)
# tensor([-3.1659, -0.0431], grad_fn=<SelectBackward>)
# tensor([-3.5285, -0.0298], grad_fn=<SelectBackward>)
# tensor([-0.3317, -1.2648], grad_fn=<SelectBackward>)
# tensor([-0.4936, -0.9426], grad_fn=<SelectBackward>)
# tensor([-1.8307, -0.1747], grad_fn=<SelectBackward>)
# tensor([-2.6654, -0.0721], grad_fn=<SelectBackward>)
# tensor([-0.0631, -2.7945], grad_fn=<SelectBackward>)
# tensor([-0.0365, -3.3287], grad_fn=<SelectBackward>)
# tensor([-0.0653, -2.7607], grad_fn=<SelectBackward>)
# tensor([-1.8095, -0.1788], grad_fn=<SelectBackward>)
# tensor([-0.2219, -1.6146], grad_fn=<SelectBackward>)
# tensor([-0.0369, -3.3171], grad_fn=<SelectBackward>)
# tensor([-0.2197, -1.6235], grad_fn=<SelectBackward>)
# tensor([-0.0294, -3.5405], grad_fn=<SelectBackward>)
# tensor([-1.5330, -0.2432], grad_fn=<SelectBackward>)
# tensor([-2.9022, -0.0565], grad_fn=<SelectBackward>)
# tensor([-3.1912, -0.0420], grad_fn=<SelectBackward>)
# tensor([-3.4616, -0.0319], grad_fn=<SelectBackward>)
# tensor([-1.7397, -0.1931], grad_fn=<SelectBackward>)
# tensor([-0.0409, -3.2163], grad_fn=<SelectBackward>)
# tensor([-3.4064, -0.0337], grad_fn=<SelectBackward>)
# tensor([-3.1786, -0.0425], grad_fn=<SelectBackward>)
# tensor([-3.1799, -0.0425], grad_fn=<SelectBackward>)
# tensor([-0.0371, -3.3114], grad_fn=<SelectBackward>)
# tensor([-3.3607, -0.0353], grad_fn=<SelectBackward>)
# tensor([-0.0703, -2.6894], grad_fn=<SelectBackward>)
# tensor([-2.7511, -0.0660], grad_fn=<SelectBackward>)
# tensor([-0.1773, -1.8174], grad_fn=<SelectBackward>)
# tensor([-0.0279, -3.5940], grad_fn=<SelectBackward>)
# tensor([-3.5306, -0.0297], grad_fn=<SelectBackward>)
# tensor([-0.1640, -1.8888], grad_fn=<SelectBackward>)
# tensor([-0.0681, -2.7202], grad_fn=<SelectBackward>)
# tensor([-2.4470, -0.0905], grad_fn=<SelectBackward>)
# tensor([-2.7005, -0.0695], grad_fn=<SelectBackward>)
# tensor([-0.1977, -1.7180], grad_fn=<SelectBackward>)
# tensor([-0.0427, -3.1742], grad_fn=<SelectBackward>)
# tensor([-2.3610, -0.0991], grad_fn=<SelectBackward>)
# tensor([-3.1355, -0.0445], grad_fn=<SelectBackward>)
# tensor([-0.1010, -2.3425], grad_fn=<SelectBackward>)
# tensor([-0.0554, -2.9202], grad_fn=<SelectBackward>)
# tensor([-0.1424, -2.0197], grad_fn=<SelectBackward>)
# tensor([-0.0652, -2.7624], grad_fn=<SelectBackward>)
# tensor([-0.0653, -2.7619], grad_fn=<SelectBackward>)
# tensor([-3.1438, -0.0441], grad_fn=<SelectBackward>)
# tensor([-1.3900, -0.2865], grad_fn=<SelectBackward>)
# tensor([-3.4503, -0.0323], grad_fn=<SelectBackward>)
# tensor([-1.0741, -0.4180], grad_fn=<SelectBackward>)
# tensor([-0.1116, -2.2484], grad_fn=<SelectBackward>)
# tensor([-0.0417, -3.1989], grad_fn=<SelectBackward>)
# tensor([-0.3449, -1.2321], grad_fn=<SelectBackward>)
# tensor([-0.2482, -1.5152], grad_fn=<SelectBackward>)
# tensor([-0.0251, -3.6981], grad_fn=<SelectBackward>)
# tensor([-3.2646, -0.0390], grad_fn=<SelectBackward>)
# tensor([-0.4139, -1.0820], grad_fn=<SelectBackward>)
# tensor([-2.7749, -0.0644], grad_fn=<SelectBackward>)
# tensor([-0.1220, -2.1645], grad_fn=<SelectBackward>)
# tensor([-0.3210, -1.2925], grad_fn=<SelectBackward>)
# tensor([-2.6442, -0.0737], grad_fn=<SelectBackward>)
# tensor([-1.4379, -0.2711], grad_fn=<SelectBackward>)
# tensor([-0.0325, -3.4428], grad_fn=<SelectBackward>)
# tensor([-0.8332, -0.5703], grad_fn=<SelectBackward>)
# tensor([-3.3196, -0.0368], grad_fn=<SelectBackward>)
# tensor([-0.1053, -2.3035], grad_fn=<SelectBackward>)
# tensor([-0.0374, -3.3049], grad_fn=<SelectBackward>)
# tensor([-0.1728, -1.8408], grad_fn=<SelectBackward>)
# tensor([-2.9475, -0.0539], grad_fn=<SelectBackward>)
# tensor([-3.0751, -0.0473], grad_fn=<SelectBackward>)
# tensor([-2.5029, -0.0854], grad_fn=<SelectBackward>)
# tensor([-3.0939, -0.0464], grad_fn=<SelectBackward>)
# tensor([-3.3564, -0.0355], grad_fn=<SelectBackward>)
# tensor([-0.0361, -3.3392], grad_fn=<SelectBackward>)
# tensor([-0.0384, -3.2790], grad_fn=<SelectBackward>)
# tensor([-0.2367, -1.5570], grad_fn=<SelectBackward>)
# tensor([-1.7362, -0.1938], grad_fn=<SelectBackward>)
# tensor([-1.7042, -0.2008], grad_fn=<SelectBackward>)
# tensor([-2.1811, -0.1198], grad_fn=<SelectBackward>)
# tensor([-0.0366, -3.3257], grad_fn=<SelectBackward>)
# tensor([-0.0885, -2.4691], grad_fn=<SelectBackward>)
# tensor([-0.1504, -1.9687], grad_fn=<SelectBackward>)
# tensor([-1.2484, -0.3382], grad_fn=<SelectBackward>)
# tensor([-0.9424, -0.4938], grad_fn=<SelectBackward>)
# tensor([-0.0604, -2.8361], grad_fn=<SelectBackward>)
# tensor([-0.0482, -3.0558], grad_fn=<SelectBackward>)
# tensor([-2.6300, -0.0748], grad_fn=<SelectBackward>)
# tensor([-0.0742, -2.6376], grad_fn=<SelectBackward>)
# tensor([-3.3768, -0.0348], grad_fn=<SelectBackward>)
# tensor([-3.4236, -0.0331], grad_fn=<SelectBackward>)
# tensor([-2.9061, -0.0562], grad_fn=<SelectBackward>)
# tensor([-0.0712, -2.6782], grad_fn=<SelectBackward>)
# tensor([-0.0482, -3.0573], grad_fn=<SelectBackward>)
# tensor([-1.8085, -0.1790], grad_fn=<SelectBackward>)
# tensor([-3.2911, -0.0379], grad_fn=<SelectBackward>)
# tensor([-2.6887, -0.0704], grad_fn=<SelectBackward>)
# tensor([-1.0324, -0.4403], grad_fn=<SelectBackward>)
# tensor([-3.0679, -0.0476], grad_fn=<SelectBackward>)
# tensor([-0.0318, -3.4656], grad_fn=<SelectBackward>)
# tensor([-0.0373, -3.3085], grad_fn=<SelectBackward>)
# tensor([-0.0977, -2.3742], grad_fn=<SelectBackward>)
# tensor([-0.1645, -1.8859], grad_fn=<SelectBackward>)
# tensor([-0.0569, -2.8940], grad_fn=<SelectBackward>)
# tensor([-0.0455, -3.1135], grad_fn=<SelectBackward>)
# tensor([-0.0501, -3.0187], grad_fn=<SelectBackward>)
# tensor([-2.3560, -0.0996], grad_fn=<SelectBackward>)
# tensor([-3.5462, -0.0293], grad_fn=<SelectBackward>)
# tensor([-2.7334, -0.0672], grad_fn=<SelectBackward>)
# tensor([-0.0710, -2.6801], grad_fn=<SelectBackward>)
# tensor([-2.7828, -0.0639], grad_fn=<SelectBackward>)
# tensor([-3.2760, -0.0385], grad_fn=<SelectBackward>)
# tensor([-3.5947, -0.0279], grad_fn=<SelectBackward>)
# tensor([-3.2496, -0.0396], grad_fn=<SelectBackward>)
# tensor([-0.1892, -1.7579], grad_fn=<SelectBackward>)
# tensor([-0.0684, -2.7168], grad_fn=<SelectBackward>)
# tensor([-0.0309, -3.4936], grad_fn=<SelectBackward>)
# tensor([-3.1019, -0.0460], grad_fn=<SelectBackward>)
# tensor([-3.6174, -0.0272], grad_fn=<SelectBackward>)
# tensor([-2.7996, -0.0628], grad_fn=<SelectBackward>)
# tensor([-0.0600, -2.8427], grad_fn=<SelectBackward>)
# tensor([-3.5365, -0.0295], grad_fn=<SelectBackward>)
# tensor([-2.9393, -0.0544], grad_fn=<SelectBackward>)
# tensor([-0.0729, -2.6549], grad_fn=<SelectBackward>)
# tensor([-3.4410, -0.0326], grad_fn=<SelectBackward>)
# tensor([-1.5442, -0.2401], grad_fn=<SelectBackward>)
# tensor([-1.6124, -0.2224], grad_fn=<SelectBackward>)
# tensor([-2.4494, -0.0903], grad_fn=<SelectBackward>)
# tensor([-2.9480, -0.0539], grad_fn=<SelectBackward>)
# tensor([-0.0593, -2.8543], grad_fn=<SelectBackward>)
# tensor([-0.0745, -2.6335], grad_fn=<SelectBackward>)
# tensor([-0.7554, -0.6345], grad_fn=<SelectBackward>)
# tensor([-0.0342, -3.3923], grad_fn=<SelectBackward>)
# tensor([-0.0360, -3.3419], grad_fn=<SelectBackward>)
# tensor([-0.0902, -2.4507], grad_fn=<SelectBackward>)
# tensor([-3.2241, -0.0406], grad_fn=<SelectBackward>)
# tensor([-0.6824, -0.7040], grad_fn=<SelectBackward>)
# tensor([-3.1431, -0.0441], grad_fn=<SelectBackward>)
# tensor([-1.0995, -0.4050], grad_fn=<SelectBackward>)
# tensor([-2.5603, -0.0804], grad_fn=<SelectBackward>)
# tensor([-2.0689, -0.1350], grad_fn=<SelectBackward>)
# tensor([-0.0569, -2.8955], grad_fn=<SelectBackward>)
# tensor([-3.2173, -0.0409], grad_fn=<SelectBackward>)
# tensor([-2.8303, -0.0608], grad_fn=<SelectBackward>)
# tensor([-1.4051, -0.2815], grad_fn=<SelectBackward>)
# tensor([-0.0282, -3.5840], grad_fn=<SelectBackward>)
# tensor([-0.1696, -1.8582], grad_fn=<SelectBackward>)
# tensor([-0.0343, -3.3885], grad_fn=<SelectBackward>)
# tensor([-0.0357, -3.3497], grad_fn=<SelectBackward>)
# tensor([-0.1869, -1.7693], grad_fn=<SelectBackward>)
# tensor([-0.0698, -2.6973], grad_fn=<SelectBackward>)
# tensor([-0.9467, -0.4911], grad_fn=<SelectBackward>)
# tensor([-0.1241, -2.1479], grad_fn=<SelectBackward>)
# tensor([-2.7706, -0.0647], grad_fn=<SelectBackward>)
# tensor([-0.0356, -3.3535], grad_fn=<SelectBackward>)
# tensor([-0.0704, -2.6892], grad_fn=<SelectBackward>)
# tensor([-2.4617, -0.0891], grad_fn=<SelectBackward>)
# tensor([-0.6509, -0.7372], grad_fn=<SelectBackward>)
# tensor([-2.7947, -0.0631], grad_fn=<SelectBackward>)
# tensor([-0.1053, -2.3031], grad_fn=<SelectBackward>)
# tensor([-0.0447, -3.1292], grad_fn=<SelectBackward>)
# tensor([-0.0392, -3.2589], grad_fn=<SelectBackward>)
# tensor([-0.0444, -3.1374], grad_fn=<SelectBackward>)
# tensor([-2.8164, -0.0617], grad_fn=<SelectBackward>)
# tensor([-0.0915, -2.4363], grad_fn=<SelectBackward>)
# tensor([-0.0452, -3.1183], grad_fn=<SelectBackward>)
# tensor([-0.2815, -1.4051], grad_fn=<SelectBackward>)
# tensor([-3.1931, -0.0419], grad_fn=<SelectBackward>)
# tensor([-0.1191, -2.1868], grad_fn=<SelectBackward>)
# tensor([-3.2880, -0.0380], grad_fn=<SelectBackward>)
# tensor([-0.0349, -3.3716], grad_fn=<SelectBackward>)
# tensor([-0.0779, -2.5915], grad_fn=<SelectBackward>)
# tensor([-3.5065, -0.0305], grad_fn=<SelectBackward>)
# tensor([-3.2519, -0.0395], grad_fn=<SelectBackward>)
# tensor([-0.0541, -2.9445], grad_fn=<SelectBackward>)
# tensor([-0.9174, -0.5101], grad_fn=<SelectBackward>)
# tensor([-2.0905, -0.1320], grad_fn=<SelectBackward>)
# tensor([-1.7598, -0.1888], grad_fn=<SelectBackward>)
# tensor([-2.5159, -0.0842], grad_fn=<SelectBackward>)
# tensor([-2.8482, -0.0597], grad_fn=<SelectBackward>)
# tensor([-3.3809, -0.0346], grad_fn=<SelectBackward>)
# tensor([-0.1038, -2.3169], grad_fn=<SelectBackward>)
# tensor([-3.2236, -0.0406], grad_fn=<SelectBackward>)
# tensor([-3.2899, -0.0380], grad_fn=<SelectBackward>)
# tensor([-1.5203, -0.2467], grad_fn=<SelectBackward>)
# tensor([-0.0971, -2.3803], grad_fn=<SelectBackward>)
# tensor([-0.0329, -3.4311], grad_fn=<SelectBackward>)
# tensor([-3.6735, -0.0257], grad_fn=<SelectBackward>)
# tensor([-0.0422, -3.1864], grad_fn=<SelectBackward>)
# tensor([-3.2880, -0.0380], grad_fn=<SelectBackward>)
# tensor([-1.5116, -0.2492], grad_fn=<SelectBackward>)
# tensor([-2.4210, -0.0930], grad_fn=<SelectBackward>)
# tensor([-0.0463, -3.0953], grad_fn=<SelectBackward>)
# tensor([-0.2428, -1.5344], grad_fn=<SelectBackward>)
# tensor([-0.0369, -3.3191], grad_fn=<SelectBackward>)
# tensor([-0.0510, -3.0019], grad_fn=<SelectBackward>)
# tensor([-0.1550, -1.9407], grad_fn=<SelectBackward>)
# tensor([-0.5463, -0.8653], grad_fn=<SelectBackward>)
# tensor([-0.0548, -2.9306], grad_fn=<SelectBackward>)
# tensor([-0.0429, -3.1712], grad_fn=<SelectBackward>)
# tensor([-1.8849, -0.1647], grad_fn=<SelectBackward>)
# tensor([-0.0744, -2.6352], grad_fn=<SelectBackward>)
# tensor([-2.9828, -0.0520], grad_fn=<SelectBackward>)
# tensor([-0.2677, -1.4487], grad_fn=<SelectBackward>)
# tensor([-1.6304, -0.2180], grad_fn=<SelectBackward>)
# tensor([-0.0323, -3.4474], grad_fn=<SelectBackward>)
# tensor([-3.5143, -0.0302], grad_fn=<SelectBackward>)
# tensor([-2.7682, -0.0648], grad_fn=<SelectBackward>)
# tensor([-0.0746, -2.6329], grad_fn=<SelectBackward>)
# tensor([-2.7931, -0.0632], grad_fn=<SelectBackward>)
# tensor([-0.0931, -2.4203], grad_fn=<SelectBackward>)
# tensor([-3.3644, -0.0352], grad_fn=<SelectBackward>)
# tensor([-0.1378, -2.0501], grad_fn=<SelectBackward>)
# tensor([-3.1294, -0.0447], grad_fn=<SelectBackward>)
# tensor([-0.0387, -3.2701], grad_fn=<SelectBackward>)
# tensor([-0.3032, -1.3410], grad_fn=<SelectBackward>)
# tensor([-0.1120, -2.2448], grad_fn=<SelectBackward>)
# tensor([-1.9863, -0.1476], grad_fn=<SelectBackward>)
# tensor([-0.5351, -0.8810], grad_fn=<SelectBackward>)
# tensor([-3.3719, -0.0349], grad_fn=<SelectBackward>)
# tensor([-0.0384, -3.2794], grad_fn=<SelectBackward>)
# tensor([-0.0716, -2.6724], grad_fn=<SelectBackward>)
# tensor([-3.0098, -0.0506], grad_fn=<SelectBackward>)
# tensor([-3.3380, -0.0362], grad_fn=<SelectBackward>)
# tensor([-3.2161, -0.0409], grad_fn=<SelectBackward>)
# tensor([-2.5796, -0.0788], grad_fn=<SelectBackward>)
# tensor([-0.0321, -3.4546], grad_fn=<SelectBackward>)
# Accuracy: 0.89125

# %% [markdown]
# And what if we run this on a new, _untrained_ model?

# %% [markdown]
# Not sure why it's printing everything above--if you scroll to the bottom you can see my accuracy, 0.89125.

# %%
untrained = lang_id.LangID(
    input_vocab_n=len(c2i), 
    embedding_dims=10,
    hidden_dims=20,
    lstm_layers=1,
    output_class_n=2
)

acc_untrained, y_hat_untrained = lang_id.eval_acc(untrained, bi_text_test, c2i, i2c, l2i, i2l)

print(f"Accuracy: {acc_untrained}")
# Out:
# Accuracy: 0.50475

# %%
# !nosetests tests/test_lang_id.py:test_d2_3_eval_acc
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 18.635s
#
# OK

# %% [markdown]
# As expected, an untrained model gets approximately chance performance.
#
# On our trained model, we were able to achieve 99% accuracy on held-out test data, which is very high accuracy! Let's investigate our hyperparameter settings: how small can we make our embedding and hidden dimensions before performance suffers?
#
# * **Deliverable 2.4:** Turn both the embedding dimensions and the hidden dimensions _waaaaay_ down, to 2 each, and retrain/re-evaluate the model. Save your evaluation results to a CSV file named "deliverable_2.4.csv" with three columns: the sentence itself, the _true_ label, and the _predicted_ label. Also produce a text file named "deliverable_2.4.txt" containing the observed evaluation accuracy and an explanation of what you observe. Why is the number what it is?

# %%
li_small = lang_id.LangID(
    input_vocab_n=len(c2i),#n
    embedding_dims=2,#e
    hidden_dims=2,#h
    lstm_layers=1,
    output_class_n=2 #c
)

small_trained_model = lang_id.train_model(
    model=li_small, 
    n_epochs=1,
    training_data=bi_text_train,
    c2i=c2i, i2c=i2c,
    l2i=l2i, i2l=i2l
)
# Out:
# 0/16000 average per-item loss: 0.00948992371559143
# 1000/16000 average per-item loss: 0.7073841094970703
# 2000/16000 average per-item loss: 0.7125043272972107
# 3000/16000 average per-item loss: 0.699700117111206
# 4000/16000 average per-item loss: 0.6797308921813965
# 5000/16000 average per-item loss: 0.6849128007888794
# 6000/16000 average per-item loss: 0.7138788104057312
# 7000/16000 average per-item loss: 0.6985530257225037
# 8000/16000 average per-item loss: 0.6956017017364502
# 9000/16000 average per-item loss: 0.7064645886421204
# 10000/16000 average per-item loss: 0.6963086724281311
# 11000/16000 average per-item loss: 0.6868247985839844
# 12000/16000 average per-item loss: 0.6817441582679749
# 13000/16000 average per-item loss: 0.686248779296875
# 14000/16000 average per-item loss: 0.6823077201843262
# 15000/16000 average per-item loss: 0.6809884905815125

# %%
acc_trained_small, y_hat_trained_small = lang_id.eval_acc(small_trained_model, bi_text_test, c2i, i2c, l2i, i2l)

print(f"Accuracy: {acc_trained_small}")
# Out:
# Accuracy: 0.609

# %%
y_hat_trained_small
# Out:
# ['spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'eng',
#  'spa',
#  'spa',
#  'spa',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'eng',
#  'spa',
#  'eng',
#  'spa',
#  'eng',
#  ...]

# %% [markdown]
# Reducing the embedding dimension so low means we can't store very much information in it. And, reducing the number of hidden layers... (add to)

# %%
import csv
sentences = list(bi_text_test.sentence)
languages = list(bi_text_test.lang)

with open("deliverable_2.4.csv", "w") as csvfile:
    csvwriter = csv.writer(csvfile, delimiter = ",")
    i = 0
    for i in range(0, len(sentences)):
        csvwriter.writerow(["Sentence"] + ["Actual language"] + ["Predicted language"])
        csvwriter.writerow([sentences[i]]+[languages[i]]+[y_hat_trained_small[i]])
        i+=1

# %% [markdown]
# ### Extending to multinomial classification
#
# Clearly, a simple LSTM classifier works very well for this binary classification problem, even for very low-dimensional networks. What if we try and do multi-class classification? Our model should, in theory, be adaptable to that case. How sensitive is it to our network dimensionality?

# %%
reload(lang_id);

# %%
multi_text = pd.read_csv("data/sentences_multilingual.csv")
multi_text_train, multi_text_test = train_test_split(multi_text, test_size=0.2)

multi_text.groupby('lang').count()
# Out:
#          id  sentence
# lang
# deu   10000     10000
# eng   10000     10000
# fra   10000     10000
# ita   10000     10000
# spa   10000     10000

# %%
multi_text_train.groupby('lang').count()
# Out:
#         id  sentence
# lang
# deu   8061      8061
# eng   7978      7978
# fra   7987      7987
# ita   8052      8052
# spa   7922      7922

# %%
c2i, i2c = vocab.build_vocab(multi_text.sentence.values)
l2i, i2l = vocab.build_label_vocab(multi_text.lang.values)

# %%
multi_class = lang_id.LangID(
    input_vocab_n=len(c2i), 
    embedding_dims=10,
    hidden_dims=20,
    lstm_layers=1,
    output_class_n=5
)

lang_id.train_model(
    model=multi_class, 
    n_epochs=1,
    training_data=multi_text_train,
    c2i=c2i, i2c=i2c,
    l2i=l2i, i2l=i2l
);

print("done")
# Out:
# 0/40000 average per-item loss: 0.014474084600806236
# 1000/40000 average per-item loss: 1.6105462312698364
# 2000/40000 average per-item loss: 1.6024024486541748
# 3000/40000 average per-item loss: 1.6036677360534668
# 4000/40000 average per-item loss: 1.5871168375015259
# 5000/40000 average per-item loss: 1.5886768102645874
# 6000/40000 average per-item loss: 1.5640389919281006
# 7000/40000 average per-item loss: 1.5612711906433105
# 8000/40000 average per-item loss: 1.546626329421997
# 9000/40000 average per-item loss: 1.4976032972335815
# 10000/40000 average per-item loss: 1.4831451177597046
# 11000/40000 average per-item loss: 1.439029335975647
# 12000/40000 average per-item loss: 1.334649920463562
# 13000/40000 average per-item loss: 1.3122918605804443
# 14000/40000 average per-item loss: 1.3447134494781494
# 15000/40000 average per-item loss: 1.3595232963562012
# 16000/40000 average per-item loss: 1.2868869304656982
# 17000/40000 average per-item loss: 1.215528964996338
# 18000/40000 average per-item loss: 1.1757161617279053
# 19000/40000 average per-item loss: 1.0678935050964355
# 20000/40000 average per-item loss: 1.0865756273269653
# 21000/40000 average per-item loss: 1.134079933166504
# 22000/40000 average per-item loss: 1.1391814947128296
# 23000/40000 average per-item loss: 1.0677947998046875
# 24000/40000 average per-item loss: 1.0069479942321777
# 25000/40000 average per-item loss: 0.8633357882499695
# 26000/40000 average per-item loss: 0.9317518472671509
# 27000/40000 average per-item loss: 0.9531993865966797
# 28000/40000 average per-item loss: 1.0281381607055664
# 29000/40000 average per-item loss: 0.8999350666999817
# 30000/40000 average per-item loss: 0.8568710088729858
# 31000/40000 average per-item loss: 0.9660846590995789
# 32000/40000 average per-item loss: 0.994942307472229
# 33000/40000 average per-item loss: 1.0128779411315918
# 34000/40000 average per-item loss: 0.7736960053443909
# 35000/40000 average per-item loss: 0.9033827781677246
# 36000/40000 average per-item loss: 0.7213355898857117
# 37000/40000 average per-item loss: 0.9014807343482971
# 38000/40000 average per-item loss: 0.7069851160049438
# 39000/40000 average per-item loss: 0.7129100561141968
# done

# %% [markdown]
# Now that it's trained, let's evaluate it as before:

# %%
acc_multi, y_hat_multi = lang_id.eval_acc(multi_class, multi_text_test, c2i, i2c, l2i, i2l)

print(f"Accuracy: {acc_multi}")
# Out:
# Accuracy: 0.6961

# %% [markdown]
# For 5-way classification, a single accuracy number is less useful than it is for binary classification. Scikit-Learn has some helpful classes for evaluating classifiers:

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# The `classification_report` function will give us a per-class breakdown of our performance:

# %%
y_multi = multi_text_test.lang.values
print(classification_report(y_multi, y_hat_multi))
# Out:
#               precision    recall  f1-score   support
#
#          deu       0.83      0.84      0.83      1978
#          eng       0.68      0.87      0.76      1996
#          fra       0.69      0.65      0.67      2000
#          ita       0.64      0.70      0.67      2024
#          spa       0.61      0.41      0.49      2002
#
#    micro avg       0.69      0.69      0.69     10000
#    macro avg       0.69      0.69      0.68     10000
# weighted avg       0.69      0.69      0.68     10000

# %% [markdown]
# The `confusion_matrix` function will give us a raw confusion matrix; rows are "truth" and columns are "predictions".

# %%
cm = confusion_matrix(y_multi, y_hat_multi)
cm
# Out:
# array([[1652,  236,   83,    1,    6],
#        [ 137, 1740,   78,   17,   24],
#        [ 181,  251, 1297,   91,  180],
#        [   8,  155,  120, 1422,  319],
#        [  22,  191,  304,  674,  811]])

# %% [markdown]
# The `lang_id` module has a method to make nicer-looking matrices:

# %%
reload(lang_id);

# %%
lang_id.pretty_conf_matrix(cm, ['deu','eng','fra','ita','spa'])

# %% [markdown]
# * **Deliverable 2.5:** Interpret these results. Why is our classifier performing better on some languages than on others? Put your analysis in a file named `deliverable_2.5.txt`.
#
# From here, the rest of this section is up to you. Experiment with different numbers of embedding & hidden dimensions, hidden LSTM layers, etc., and see how high you can get your classification accuracy. Also try training for additional epochs. Does that help?
#
# * **Deliverable 2.6:** Describe at least two additional models that you trained and evaluated, along with their overall and per-class accuracies. What seemed to help the most? Put your discussion in a file named `deliverable_2.6.txt`.

# %%
multi_class = lang_id.LangID(
    input_vocab_n=len(c2i), 
    embedding_dims=15, #increased from 10
    hidden_dims=20,
    lstm_layers=2, #increased from 1
    output_class_n=5
)

lang_id.train_model(
    model=multi_class, 
    n_epochs=1,
    training_data=multi_text_train,
    c2i=c2i, i2c=i2c,
    l2i=l2i, i2l=i2l
);

print("done")
# Out:
# 0/40000 average per-item loss: 0.01749075949192047
# 1000/40000 average per-item loss: 1.6116176843643188
# 2000/40000 average per-item loss: 1.5935090780258179
# 3000/40000 average per-item loss: 1.5938141345977783
# 4000/40000 average per-item loss: 1.5958311557769775
# 5000/40000 average per-item loss: 1.59196138381958
# 6000/40000 average per-item loss: 1.5866905450820923
# 7000/40000 average per-item loss: 1.5304534435272217
# 8000/40000 average per-item loss: 1.4787715673446655
# 9000/40000 average per-item loss: 1.4691815376281738
# 10000/40000 average per-item loss: 1.415826678276062
# 11000/40000 average per-item loss: 1.3138214349746704
# 12000/40000 average per-item loss: 1.2022576332092285
# 13000/40000 average per-item loss: 1.1388710737228394
# 14000/40000 average per-item loss: 1.0600348711013794
# 15000/40000 average per-item loss: 1.0272940397262573
# 16000/40000 average per-item loss: 0.9470607042312622
# 17000/40000 average per-item loss: 1.0135232210159302
# 18000/40000 average per-item loss: 0.8693776726722717
# 19000/40000 average per-item loss: 0.9084654450416565
# 20000/40000 average per-item loss: 0.9642578363418579
# 21000/40000 average per-item loss: 0.746366024017334
# 22000/40000 average per-item loss: 0.8439785838127136
# 23000/40000 average per-item loss: 0.9082018136978149
# 24000/40000 average per-item loss: 0.7144322395324707
# 25000/40000 average per-item loss: 0.7994793653488159
# 26000/40000 average per-item loss: 0.8626392483711243
# 27000/40000 average per-item loss: 0.5790863037109375
# 28000/40000 average per-item loss: 0.6358044147491455
# 29000/40000 average per-item loss: 0.7730143666267395
# 30000/40000 average per-item loss: 0.8059719204902649
# 31000/40000 average per-item loss: 0.6316279768943787
# 32000/40000 average per-item loss: 0.6929315328598022
# 33000/40000 average per-item loss: 0.6724381446838379
# 34000/40000 average per-item loss: 0.6971696615219116
# 35000/40000 average per-item loss: 0.7647817730903625
# 36000/40000 average per-item loss: 0.6826319694519043
# 37000/40000 average per-item loss: 0.7215140461921692
# 38000/40000 average per-item loss: 0.5507646203041077
# 39000/40000 average per-item loss: 0.6255486011505127
# done

# %%
acc_multi, y_hat_multi = lang_id.eval_acc(multi_class, multi_text_test, c2i, i2c, l2i, i2l)

print(f"Accuracy: {acc_multi}")
# Out:
# Accuracy: 0.7614

# %%
y_multi = multi_text_test.lang.values
print(classification_report(y_multi, y_hat_multi))
cm = confusion_matrix(y_multi, y_hat_multi)
lang_id.pretty_conf_matrix(cm, ['deu','eng','fra','ita','spa'])
# Out:
#               precision    recall  f1-score   support
#
#          deu       0.88      0.87      0.88      1939
#          eng       0.83      0.85      0.84      2022
#          fra       0.77      0.86      0.81      2013
#          ita       0.66      0.70      0.68      1948
#          spa       0.65      0.53      0.59      2078
#
#    micro avg       0.76      0.76      0.76     10000
#    macro avg       0.76      0.76      0.76     10000
# weighted avg       0.76      0.76      0.76     10000

# %% [markdown]
# ## Part 3: Language modeling
#
# ### Getting Started
#
# In this part of the assignment, you will build and evaluate a simple LSTM character language model, and then _sample_ from it to generate new text mimicking the training data. The model you will build should follow the general structure outlined in Section 17.1 of the Goldberg text, and use the "teacher-forcing" training method outlined in 17.1.1.
#
# $$ p(\mathbf{w}_n | \mathbf{w}_{1:n-1}) = \operatorname*{softmax} \mathbf{o}^{(n-1)} $$
#
# $$ o = \mathbf{h} \mathbf{W}_o^T + b_o $$
#
# $$ \mathbf{h} = LSTM(\mathbf{x})$$
#
# $$ \mathbf{x}_{1:n-1} = \mathbf{E}[w_1], ... , \mathbf{E}[w_n-1] $$
#
# For this part of the assignment, we will be working with a data set of British place names located in `data/towns_clean.txt`.

# %%
corpus = [l.strip() for l in open('data/towns_clean.txt')]
c2i, i2c = vocab.build_vocab(corpus)

for t in np.random.choice(corpus, size=10):
    print(t)
# Out:
# Minwear
# Hindley
# Nash Street
# Woburn Sands
# Hindolveston
# Llandough
# Shortmoor
# Mill of Kincardine
# Gastard
# The Beeches

# %% [markdown]
# Your network, once trained, will learn to recognize British place names, and will be able to make up new ones.
#
# * **Deliverable 3.1:** Implement the `__init__()`, and `forward()` functions in `hw3_utils.lm.NameGenerator`.
# * **Test:** `nosetests tests/test_lm.py:test_d3_1_setup`
#
# Once you've got these methods set up correctly, the following ought to work (in the sense of producing appropriately-sized output):

# %%
from hw3_utils import lm
reload(lm);

# %%
model = lm.NameGenerator(
    input_vocab_size=len(c2i),
    n_embedding_dims=25,
    n_hidden_dims=50,
    n_lstm_layers=1,
    output_vocab_size=len(c2i)
)

x = vocab.sentence_to_tensor("Test input", c2i, True) # make sure to pad w/ bos/eos symbols
y_hat, lstm_hidden_state = model(x, model.init_hidden())
y_hat.shape # should be 1x12x78 (1 x len("Test input")+2 x len(c2i))
# Out:
# torch.Size([1, 12, 77])

# %% [markdown]
# Each position $i$ along the second dimension of $\hat{y}$ is the model's estimate of $p(x_{i+1} | x_{1:i})$, and is represented as a multinomial probability distribution in log-space (i.e., each of the 78 possible characters is assigned an estimated log-probability of occurring).
#
# By multiplying across (or summing across, in log-space) each of those values, we can calculate the model's estimate of the probability of an input sequence (see Jurafsky & Martin, Chapter 3 if you need refresher on how this works). As a convenience method, I have provided `lm.compute_prob`.

# %%
lm.compute_prob(model, "Test input", c2i)
# Out:
# torch.Size([1, 11, 77])
# torch.Size([1, 11])
# 47.63888931274414

# %%
lm.compute_prob(model, "fdsafsadfa", c2i)
# Out:
# lstm output[-1][0]
# torch.Size([1, 1, 50])
# torch.Size([1, 1, 50])
# torch.Size([1, 11, 77])
# torch.Size([1, 11])
# 47.993499755859375

# %% [markdown]
# This produces _negative log probabilities_. In this case, the model has not yet been trained and so the two sequences are given (very roughly) equivalent probabilities
#
# Note that "out of the box" `compute_prob()` does not _normalize_ the probabilities by sequence length, and as such longer sequences will have lower probabilities on average than shorter sequences, regardless of how plausible they are to the model. If you want to compare the model's estimate of the probabilities of two sequences of different lengths, you must normalize each by the appropriate sequence's length.
#
# Once the model is trained, the estimated probabilities of the two sequences above should be quite different!

# %%
# !nosetests tests/test_lm.py:test_d3_1_setup
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.086s
#
# OK

# %%
y_hat[0][0].exp().sum()
# Out:
# tensor(1.0000, grad_fn=<SumBackward0>)

# %% [markdown]
# ### Training
#
# Note that there are two ways to structure the training of this sort of model.
#
# 1. One character at a time
# 2. In a quasi batched manner
#
# The equations above describe character-at-a-time training- starting from the shortest possible prefix of our sequence $\mathbf{w}$, $\mathbf{w}_{1:1}$, and continuing up through successively longer prefixes until reaching $\mathbf{w}_{1:n-1}$, ask the model to predict the next character, accumulating loss with the negative log-likelihood criterion.
#
# In this scenario, if our input training sentence was _"hello there"_, we would perform a series of forward passes:
#
# $x_1="h"$, $y_1="e"$
#
# $x_2="he"$, $y_2="l"$
#
# $x_3="hel"$, $y_3="l"$
#
# ... and so forth, either doing a call to `backward()` after each prefix $x_i$ or waiting until the end of the sequence to do so.
#
# This way works just fine, and is more or less how we will go about sampling from the model, but it is often more efficient to do a more batched training operation. Note that in the above equations, $\mathbf{o}$ will have dimensionality of $(1, n-1, N_{classes})$- in other words, there will be one set of probability estimates for each time point that we have provided the LSTM. PyTorch's `nn.NLLLoss` class can accept input in this shape, and will automatically compute the average loss across the timepoints (and of course will do so a way that keeps the gradients around for correct backpropagation). Training this way can reduce the total number of computations that we need to do in order to train our model.
#
# In this scenario, we would perform a _single_ forward and backward pass, with input that looked like so:
#
# $x="hello\_ther"$, $y="ello\_there"$
#
# Note that PyTorch is perfectly happy either way: the various `nn.*` classes all expect to be able to be given input in this minibatched format. In the first training strategy, the "batch" size is 1; in the second, it is $n-1$ where $n$ is the length of the training example.
#
# The overall process of training this model will be very similar to how we trained the language ID classifier, so use that as a starting point and modify as needed. For starters, train with the following parameters:
#
# * Number of character embedding dimensions: 25
# * Number of LSTM hidden units: 50
# * Number of LSTM layers: 1
#
# Once your model is trained, you can save it to disk using the `torch.save()` function. This will make it available for the unit test to access.
#
# * **Deliverable 3.2:** Implement the `train()` function in `hw3_utils.lm`. Save a trained model to a file named `deliverable_3.2.mod`.
# * **Test:** `nosetests tests/test_lm.py:test_d3_2_training`

# %%
reload(lm);

# %%
len(corpus)
# Out:
# 48690

# %%
model = lm.NameGenerator(
    input_vocab_size=len(c2i),
    n_embedding_dims=25,
    n_hidden_dims=50,
    n_lstm_layers=1,
    output_vocab_size=len(c2i)
)

# %%
lm.train(model, epochs=2, training_data=corpus, c2i=c2i)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# NameGenerator(
#   (input_lookup): Embedding(77, 25)
#   (lstm): LSTM(25, 50, batch_first=True)
#   (output): Linear(in_features=50, out_features=77, bias=True)
#   (softmax): LogSoftmax()
# )

# %%
lm.compute_prob(model, "Test input", c2i)
# Out:
# tensor([[ 0., 57., 68., 41., 74., 65., 25., 60., 50., 42., 74.]])
# tensor([[57., 68., 41., 74., 65., 25., 60., 50., 42., 74.,  1.]])
# torch.Size([1, 11, 77])
# torch.Size([1, 11])
# 36.35872268676758

# %%
lm.compute_prob(model, "fdsafsadfa", c2i)
# Out:
# tensor([[ 0., 30., 58., 41., 31., 30., 41., 31., 58., 30., 31.]])
# tensor([[30., 58., 41., 31., 30., 41., 31., 58., 30., 31.,  1.]])
# torch.Size([1, 11, 77])
# torch.Size([1, 11])
# 54.165611267089844

# %% [markdown]
# Remember, this is in log-space, so the difference here is substantial. And now let's try giving it an actual town name as input:

# %%
lm.compute_prob(model, "Wavertree", c2i)
# Out:
# tensor([[ 0., 21., 31., 13., 68.,  5., 74.,  5., 68., 68.]])
# tensor([[21., 31., 13., 68.,  5., 74.,  5., 68., 68.,  1.]])
# torch.Size([1, 10, 77])
# torch.Size([1, 10])
# 19.133960723876953

# %%
torch.save(model, "deliverable_3.2.mod")

# %%
# !nosetests tests/test_lm.py:test_d3_2_training
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.592s
#
# OK

# %% [markdown]
# ### Sampling
#
# Now that we've got a language model trained, we can sample from it to generate _new_ names. Follow the general procedure outlined in Goldberg 9.5:
#
# 1. Build an initial history consisting of the `vocab.BOS_SYM` symbol
# 2. Using this history, query the language model, and predict a distribution over next characters
# 3. Sample a character from that distribution
# 4. Concatenate the selected character to make a _new_ history
# 5. Repeat from step 2 until the selected character is `vocab.EOS_SYM` or we hit a maximum length (200 characters, in this assignment).
#
# Once you've implemented sampling, you can generate hilarious and adorable new names!
#
# * **Deliverable 3.3:** Implement the `sample()` function in `hw3_utils.lm`
# * **Test:** `nosetests tests/test_lm.py:test_d3_3_sample`
#
# _Hint_: The `torch.multinomial()` function samples from a multinomial distribution stored in a `Tensor`, but _it requires real-space probabilities_, not log-space. `Tensor`s have a `.exp()` method that you may need to use.

# %%
reload(lm);

# %%
for i in range(10):
    print(lm.sample(model, c2i, i2c))
# Out:
# ['<BOS>', 'C', 'h', 'a', 'd', 'd', 'l', 'e', 'y', '<EOS>']
# ['<BOS>', 'U', 'n', 'c', 'h', 'm', 'i', 'r', 't', 'h', '<EOS>']
# ['<BOS>', 'G', 'o', 'y', 't', 'h', 'o', 'u', 's', 'i', 'n', 'e', '<EOS>']
# ['<BOS>', 'K', 'e', 'e', 's', 'h', 'o', 'l', ' ', 'C', 'r', 'o', 'w', ' ', 'N', 'o', 'o', 'k', '<EOS>']
# ['<BOS>', 'C', 'a', 'y', 'm', 'e', 'r', 's', 'm', 'e', 'e', '<EOS>']
# ['<BOS>', 'W', 'i', 'c', 'k', 'l', 'e', 'y', '<EOS>']
# ['<BOS>', 'C', 'a', 'p', 'p', 'e', 'l', 'd', 'a', 'c', 'h', '<EOS>']
# ['<BOS>', 'W', 'o', 'o', 'd', 'f', 'o', 'r', 'd', '<EOS>']
# ['<BOS>', 'R', 'h', 'o', 's', 't', 'l', 'e', 'y', '<EOS>']
# ['<BOS>', 'G', 'o', 'r', 'r', 'y', 'l', 'e', 'y', '<EOS>']

# %% [markdown]
# ### Improving your model
#
# These generated names should look more like names of towns than random sequences, but they are a little bit rough compared to the names in the data file. Try modifying your training process to go for additional epochs, and see how that changes your sampled sentences. Also, experiment with different model parameters. What happens if you _decrease_ number of hidden dimensions? What about _increasing_ the dimensionality? How about adding more layers to the LSTM?
#
# One useful thing to try: now that the `sample()` function is written, you might try adding some reporting code to your `train()` function: at regular intervals during training (e.g. every 1000 training examples), you could have it print out a few random towns generated from the model at its current state. This way, you can watch the model evolve over time. How many examples does it need to see before it learns that names always start with upper-case letters?
#
# * **Deliverable 3.4:** Write up a short summary of your observations and investigations into model behavior, including examples, and put it in a text file called `deliverable_3.4.txt`.

# %%
many_epochs_model = lm.NameGenerator(
    input_vocab_size=len(c2i),
    n_embedding_dims=25,
    n_hidden_dims=50,
    n_lstm_layers=1,
    output_vocab_size=len(c2i)
)

# %%
lm.train(model, epochs=5, training_data=corpus, c2i=c2i)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000

# %%
with open("deliverable_3.4.txt", "w") as f:
    f.write("When I added additional epochs--5 instead of 2--my sampled names were much more realistic.")
